# %% [markdown]
# # Setup

# %% [markdown]
# A configuração de setup é o processo de preparar e organizar o ambiente para uso. Envolvendo a instalação de bibliotecas e configuração de outros ajustes necessários. O objetivo é criar um ambiente funcional para executar tarefas específicas.

# %% [markdown]
# ## 1.1.Conexão com drive

# %% [markdown]
# Para realizar a análise, padronização e manipulação dos dados é necessário selecionar a base de dados desejada. Neste documento a importação da mesma será feita através do Google Drive e o arquivo está em formato excel (csv).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.2. Instalando as bibliotecas

# %% [markdown]
# **Antes de Importar a base é necessário instalar algumas bibliotecas como:**
# 1. Pandas: é uma biblioteca de análise
# de dados em Python que oferece estruturas de dados e ferramentas para manipulação e análise de dados. Com o Pandas, é possível ler, escrever e manipular dados em diversos formatos, como CSV, Excel, SQL, etc. Ele oferece uma grande quantidade de funcionalidades para trabalhar com dados em Python, incluindo a capacidade de filtrar, agregar, reorganizar e transformar dados de várias maneiras.
#
# 2. TextBlob: é uma biblioteca de processamento de linguagem natural em Python. Ela oferece uma interface simples para tarefas comuns de NLP, como análise de sentimentos, correção ortográfica, extração de frases-chave e classificação de texto. O TextBlob é construído sobre a biblioteca NLTK (Natural Language Toolkit) e oferece uma sintaxe fácil de usar para muitas tarefas de processamento de linguagem natural. É uma biblioteca muito útil para análise de texto em Python.
#
# 3. Emoji: é uma biblioteca Python que permite a conversão de emojis de texto para representações de texto Unicode e vice-versa. Além disso, fornece funções úteis para trabalhar com emojis, como contar o número de emojis em uma string, remover todos os emojis de uma string e substituir cada emoji em uma string por um texto de substituição especificado.
#
# 4. Re: A biblioteca "re" é uma ferramenta para trabalhar com expressões regulares, permitindo a extração e manipulação de informações de forma eficiente.
#
# 5. Unidecode: Unicode é um padrão de codificação de caracteres de forma universal para a representação de caracteres de todas as línguas escritas, bem como símbolos matemáticos, musicais, entre outros.
#
# 6. Enelvo.normaliser: A enelvo.normaliser é uma biblioteca específica para normalização de texto em português. Ela oferece recursos para corrigir erros de digitação, converter abreviações e substituir palavras informais por suas formas mais corretas. A função principal dessa biblioteca é auxiliar na normalização de texto, tornando-o mais padronizado e compreensível.
#
# 7. Numpy (np): A biblioteca numpy fornece estruturas de dados eficientes para manipulação e cálculos numéricos, além de funções matemáticas de alto desempenho.
#
# 8. Sklearn.feature_extraction.text.CountVectorizer: É uma classe do scikit-learn que converte uma coleção de documentos de texto em uma matriz de contagem de tokens. Cada documento é representado por um vetor onde cada elemento é o número de ocorrências de um token específico no documento.
#
# 9. Keras.preprocessing.text.Tokenizer: É uma classe do Keras que é usada para pré-processamento de texto. Ela converte texto em sequências de números inteiros (índices de palavras) ou matrizes esparsas. Também oferece recursos como tokenização, vetorização e indexação de palavras.
#
# 10. Nltk.tokenize.word_tokenize: É uma função do NLTK (Natural Language Toolkit) que divide um texto em uma lista de palavras ou tokens. É uma forma de tokenização que leva em consideração o contexto linguístico para separar as palavras.

# %%
pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 15.0 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.6

# %%
pip install -U emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.5.1.tar.gz (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.3/356.3 kB 29.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.5.1-py2.py3-none-any.whl size=351210 sha256=d2cacd198fd0b28ddfa7b251090a235b771f0f92cff150092b925aea9f51f029
#   Stored in directory: /root/.cache/pip/wheels/51/92/44/e2ef13f803aa08711819357e6de0c5fe67b874671141413565
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.5.1

# %%
# !pip install emoji --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (2.5.1)

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)

# %%
pip install enelvo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting enelvo
#   Downloading enelvo-0.15-py3-none-any.whl (27.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 46.2 MB/s eta 0:00:00
# Requirement already satisfied: editdistance>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from enelvo) (0.6.2)
# Collecting emoji==2.2.0 (from enelvo)
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 22.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gensim>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from enelvo) (4.3.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from enelvo) (1.22.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from enelvo) (0.8.10)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.1.2->enelvo) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.1.2->enelvo) (6.3.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234911 sha256=2eefdbedb770766e45ca72cb9c3b4eb9a7671509c204405129707a739923e877
#   Stored in directory: /root/.cache/pip/wheels/02/3d/88/51a592b9ad17e7899126563698b4e3961983ebe85747228ba6
# Successfully built emoji
# Installing collected packages: emoji, enelvo
#   Attempting uninstall: emoji
#     Found existing installation: emoji 2.5.1
#     Uninstalling emoji-2.5.1:
#       Successfully uninstalled emoji-2.5.1
# Successfully installed emoji-2.2.0 enelvo-0.15

# %%
import pandas as pd
from textblob import TextBlob
import emoji
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
nltk.download('wordnet')
import re
import unidecode
from enelvo.normaliser import Normaliser
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from unidecode import unidecode


import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from nltk.tokenize import word_tokenize
from sklearn.preprocessing import StandardScaler
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

from gensim.models import Word2Vec

# %% [markdown]
# ## 1.3.Lendo CSV

# %%
dfW2Vmodelo2 = pd.read_csv('/content/drive/MyDrive/PROJETO BTG/sentence_vectors2.csv')

# %%
len(dfW2Vmodelo2)
# Out:
# 11415

# %% [markdown]
# A célula de código abaixo é responsável por realizar a leitura e apresentação dos dados carregados da base na etapa anterior.
#
# **dados** - Apresenta a planilha dos comentários das campanhas de marketing do instagram do BTG Pactual

# %% [markdown]
# #Atividade 2 - Modelagem de Redes Neurais Recorrentes (RNN)

# %% [markdown]
#    O método de “rede neural” é um tipo de processamento, chamado aprendizado profundo, que a partir de nós (neurônios) interconectados em uma estrutura em camadas, como um cérebro humano, cria um sistema adaptativo que os computadores usam para aprender com os erros e se aprimorar.
#    Uma rede neural recorrente (RNN) é uma classe de redes neurais que inclui conexões ponderadas dentro de uma camada. Como as RNNs incluem loops, elas podem armazenar informações ao processar novas entradas. Essa memória os torna ideais para tarefas de processamento onde as entradas anteriores devem ser consideradas
#
#  **Referências**
#
# (1) What are Recurrent Neural Networks? | IBM.
#
#  https://www.ibm.com/topics/recurrent-neural-networks.
#
# (2) Recurrent Neural Network (RNN) Tutorial Simplilearn.
#
# https://www.simplilearn.com/tutorials/deep-learning-tutorial/rnn.
#
# (3) Introduction to Recurrent Neural Network - GeeksforGeeks.
#
#  https://www.geeksforgeeks.org/introduction-to-recurrent-neural-network/.

# %% [markdown]
# ## 2.1 - Definição da Função

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split

# %%
def classification_rnn(X_test, y_test):
  # Divisão em conjunto de treinamento e teste
  X_train, X_test, y_train, y_test = train_test_split(X_test, y_test, test_size=0.3, random_state=42)

  # Remodelar os dados de entrada
  X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

  # Definindo o modelo
  model = Sequential()
  model.add(LSTM(units=128, input_shape=(1, X_test.shape[2])))
  model.add(Dense(units=3, activation='softmax'))

  model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

  # Treinar o modelo
  model.fit(X_test, y_test, epochs=10, batch_size=32)

  # Avaliar a precisão do modelo
  _, accuracy = model.evaluate(X_test, y_test)
  print('Acurácia: %.2f%%' % (accuracy * 100))

  # Fazer previsões no conjunto de teste
  y_pred_prob = model.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)

  # Calcular o recall
  recall = recall_score(y_test, y_pred, average='macro')
  print('Recall: %.2f%%' % (recall* 100))

  return model, y_test, y_pred

# %% [markdown]
# ## RNN - Duas categorias e com balanceamento

# %% [markdown]
# ### 2.2 - Teste da Função

# %% [markdown]
# **USANDO DUAS CATEGORIAS E OS DADOS BALANCEADOS**

# %%
"""
# Balanceamento dos dados
df_positive = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 0]
df_negative = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 1]

df_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)

dfrnn_balanced = pd.concat([df_positive_resampled, df_negative])

# Inverter a codificação das classes
dfrnn_balanced['sentimento'] = dfrnn_balanced['sentimento'].map({1: 0, 0: 1})

# Separando os dados em X e y (balanceados)
X = np.array(dfrnn_balanced.drop(['Frase', 'sentimento'], axis=1))
Y = np.array(dfrnn_balanced['sentimento'])

# Chamada da função com os dados balanceados
model, X_test, y_test = classification_rnn(X, Y, num_epochs=20, batch_size=64, learning_rate=0.001, num_hidden_units=128)
"""
# Out:
# "\n# Balanceamento dos dados\ndf_positive = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 0]\ndf_negative = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 1]\n\ndf_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)\n\ndfrnn_balanced = pd.concat([df_positive_resampled, df_negative])\n\n# Inverter a codificação das classes\ndfrnn_balanced['sentimento'] = dfrnn_balanced['sentimento'].map({1: 0, 0: 1})\n\n# Separando os dados em X e y (balanceados)\nX = np.array(dfrnn_balanced.drop(['Frase', 'sentimento'], axis=1))\nY = np.array(dfrnn_balanced['sentimento'])\n\n# Chamada da função com os dados balanceados\nmodel, X_test, y_test = classification_rnn(X, Y, num_epochs=20, batch_size=64, learning_rate=0.001, num_hidden_units=128)\n"

# %% [markdown]
# ### 2.3 - Visualização da Matriz de Confusão de Redes Neurais Recorrentes (RNN)

# %% [markdown]
# **MATRIZ DE CONFUSÃO - USANDO DUAS CATEGORIAS E OS DADOS BALANCEADOS**

# %%
"""
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Previsões no conjunto de teste
y_pred_probs = model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int)

# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Definição dos rótulos das classes
class_labels = ['POSITIVO', 'NEGATIVO']

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusão da Modelagem de Redes Neurais Recorrentes (RNN)')
plt.colorbar()
tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels)
plt.yticks(tick_marks, class_labels)

# Adição dos valores numéricos na matriz
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'), ha='center', va='center',
             color='white' if cm[i, j] > thresh else 'black')

plt.xlabel('Previsão')
plt.ylabel('Valor Real')
plt.tight_layout()
plt.show()
"""
# Out:
# "\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom sklearn.metrics import confusion_matrix\n\n# Previsões no conjunto de teste\ny_pred_probs = model.predict(X_test)\ny_pred = (y_pred_probs > 0.5).astype(int)\n\n# Cálculo da matriz de confusão\ncm = confusion_matrix(y_test, y_pred)\n\n# Definição dos rótulos das classes\nclass_labels = ['POSITIVO', 'NEGATIVO']\n\n# Plot da matriz de confusão\nplt.figure(figsize=(8, 6))\nplt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)\nplt.title('Matriz de Confusão da Modelagem de Redes Neurais Recorrentes (RNN)')\nplt.colorbar()\ntick_marks = np.arange(len(class_labels))\nplt.xticks(tick_marks, class_labels)\nplt.yticks(tick_marks, class_labels)\n\n# Adição dos valores numéricos na matriz\nthresh = cm.max() / 2.0\nfor i, j in np.ndindex(cm.shape):\n    plt.text(j, i, format(cm[i, j], 'd'), ha='center', va='center',\n             color='white' if cm[i, j] > thresh else 'black')\n\nplt.xlabel('Previsão')\nplt.ylabel('Valor Real')\nplt.tight_layout()\nplt.show()\n"

# %% [markdown]
# ### 2.4 - Salvando CSV do resultado da Modelagem de Redes Neurais Recorrentes (RNN)

# %% [markdown]
# **USANDO DUAS CATEGORIAS E OS DADOS BALANCEADOS - GERANDO CSV**

# %%
"""
# Gerar as previsões do modelo
y_pred = model.predict(X_test)

# Arredondar as previsões para obter classes binárias (0 ou 1)
y_pred = y_pred.round().astype(int)

# Crie um DataFrame com as previsões
df_resultRNN = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred.flatten()})

# Salve o DataFrame em um arquivo CSV
df_resultRNN.to_csv('/content/drive/MyDrive/PROJETO BTG/resultadoRNN.csv', index=False)
print("Salvo com sucesso")
"""
# Out:
# '\n# Gerar as previsões do modelo\ny_pred = model.predict(X_test)\n\n# Arredondar as previsões para obter classes binárias (0 ou 1)\ny_pred = y_pred.round().astype(int)\n\n# Crie um DataFrame com as previsões\ndf_resultRNN = pd.DataFrame({\'y_test\': y_test, \'y_pred\': y_pred.flatten()})\n\n# Salve o DataFrame em um arquivo CSV\ndf_resultRNN.to_csv(\'/content/drive/MyDrive/PROJETO BTG/resultadoRNN.csv\', index=False)\nprint("Salvo com sucesso")\n'

# %% [markdown]
# ## RNN - Três categorias e sem balanceamento

# %% [markdown]
# ### 2.2 - Teste da Função

# %% [markdown]
# **USANDO TRÊS CATEGORIAS SEM BALANCEAMENTO DE DADOS**

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from keras.preprocessing.text import Tokenizer
from sklearn.metrics import recall_score

# %%
# Balanceamento dos dados
df_negative = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_positive, df_negative, df_neutral])

# Separando os dados de teste em X_test e y_test (balanceados)
X_test = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
y_test = np.array(dfrnn_balanced['sentimento2'])

model, y_test, y_pred = classification_rnn(X_test, y_test)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 8s 6ms/step - loss: 0.9981 - accuracy: 0.5142
# Epoch 2/10
# 108/108 [==============================] - 1s 6ms/step - loss: 0.9322 - accuracy: 0.5726
# Epoch 3/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.9147 - accuracy: 0.5834
# Epoch 4/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.9019 - accuracy: 0.5898
# Epoch 5/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.8972 - accuracy: 0.5895
# Epoch 6/10
# 108/108 [==============================] - 1s 8ms/step - loss: 0.8903 - accuracy: 0.5974
# Epoch 7/10
# 108/108 [==============================] - 1s 10ms/step - loss: 0.8812 - accuracy: 0.6032
# Epoch 8/10
# 108/108 [==============================] - 1s 7ms/step - loss: 0.8761 - accuracy: 0.6044
# Epoch 9/10
# 108/108 [==============================] - 1s 8ms/step - loss: 0.8782 - accuracy: 0.5980
# Epoch 10/10
# 108/108 [==============================] - 1s 6ms/step - loss: 0.8694 - accuracy: 0.6085
# 108/108 [==============================] - 1s 4ms/step - loss: 0.8713 - accuracy: 0.6018
# Acurácia: 60.18%
# 108/108 [==============================] - 1s 4ms/step
# Recall: 56.77%

# %% [markdown]
# ### 2.3 - Visualização da Matriz de Confusão de Redes Neurais Recorrentes (RNN)

# %% [markdown]
# **USANDO TRÊS CATEGORIAS SEM BALANCEAMENTO DE DADOS - MATRIZ DE CONFUSÃO**

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Previsões no conjunto de teste
y_test = y_test.astype(int)
y_pred = y_pred.astype(int)

# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Definição dos rótulos das classes
class_labels = ['POSITIVO', 'NEGATIVO', 'NEUTRO']

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusão da Modelagem de Redes Neurais Recorrentes (RNN)')
plt.colorbar()
tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels)
plt.yticks(tick_marks, class_labels)

# Adição dos valores numéricos na matriz
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'), ha='center', va='center',
             color='white' if cm[i, j] > thresh else 'black')

plt.xlabel('Previsão')
plt.ylabel('Valor Real')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4 - Hiperparâmetros com Random Search do RNN

# %%
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from scipy.stats import randint as sp_randint
from sklearn.metrics import recall_score
import tensorflow as tf

# Dados de entrada e rótulos
X_data = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
Y_labels = np.array(dfrnn_balanced['sentimento2'])

# Divisão em conjunto de treinamento e teste
X_train, X_val, y_train, y_val = train_test_split(X_data, Y_labels, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Normalização dos dados
X_train_mean = X_train.mean(axis=0)
X_train_std = X_train.std(axis=0)
X_train = (X_train - X_train_mean) / X_train_std
X_val = (X_val - X_train_mean) / X_train_std
X_data = (X_data - X_train_mean) / X_train_std

# Função para criar o modelo RNN
def create_model(num_epochs, batch_size, learning_rate, num_hidden_units):
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(units=num_hidden_units, activation='relu'),
        tf.keras.layers.Dense(units=1, activation='sigmoid')
    ])

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=learning_rate),
                  loss=tf.losses.BinaryCrossentropy(),
                  metrics=[tf.metrics.BinaryAccuracy()])

    model.fit(X_train, y_train, epochs=num_epochs, batch_size=batch_size,
              validation_data=(X_val, y_val))

    y_pred = model.predict(X_data)
    y_pred = np.round(y_pred).flatten()

    recall = recall_score(Y_labels, y_pred, average='macro')
    print('Recall:', recall)

    return model

# Definir a distribuição de valores para cada hiperparâmetro
param_dist = {
    'num_epochs': sp_randint(10, 31),  # Intervalo entre 10 e 30
    'batch_size': sp_randint(32, 129),  # Intervalo entre 32 e 128
    'learning_rate': [0.001, 0.01, 0.1],  # Valores fixos
    'num_hidden_units': sp_randint(64, 257)  # Intervalo entre 64 e 256
}

# Criação do KerasClassifier com a função create_model
keras_classifier = KerasClassifier(build_fn=create_model)

# Realizar a busca aleatória
random_search = RandomizedSearchCV(estimator=keras_classifier, param_distributions=param_dist,
                                   n_iter=10, cv=3, scoring='recall_macro', refit=False, error_score='raise')

random_result = random_search.fit(X_data, Y_labels)

# Obter os resultados da busca aleatória
results = random_result.cv_results_
best_params_idx = results['rank_test_score'].argmin()
best_params = results['params'][best_params_idx]
best_recall = results['mean_test_score'][best_params_idx]

print('Melhores hiperparâmetros:', best_params)
print('Melhor Recall:', best_recall)
# Out:
# <ipython-input-19-3a65faf2cc9d>:55: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_classifier = KerasClassifier(build_fn=create_model)
# Epoch 1/19
# 63/63 [==============================] - 3s 9ms/step - loss: -10998.0029 - binary_accuracy: 0.4022 - val_loss: -37767.2539 - val_binary_accuracy: 0.4168
# Epoch 2/19
# 63/63 [==============================] - 0s 7ms/step - loss: -110570.0625 - binary_accuracy: 0.4063 - val_loss: -197538.6250 - val_binary_accuracy: 0.4218
# Epoch 3/19
# 63/63 [==============================] - 0s 8ms/step - loss: -352032.0312 - binary_accuracy: 0.4035 - val_loss: -494281.3438 - val_binary_accuracy: 0.4249
# Epoch 4/19
# 63/63 [==============================] - 0s 7ms/step - loss: -732226.1875 - binary_accuracy: 0.4119 - val_loss: -909378.7500 - val_binary_accuracy: 0.4149
# Epoch 5/19
# 63/63 [==============================] - 0s 7ms/step - loss: -1232843.1250 - binary_accuracy: 0.4138 - val_loss: -1458786.6250 - val_binary_accuracy: 0.4093
# Epoch 6/19
# 63/63 [==============================] - 1s 12ms/step - loss: -1891466.8750 - binary_accuracy: 0.4124 - val_loss: -2128403.2500 - val_binary_accuracy: 0.4180
# Epoch 7/19
# 63/63 [==============================] - 1s 12ms/step - loss: -2668400.2500 - binary_accuracy: 0.4124 - val_loss: -2936872.2500 - val_binary_accuracy: 0.4143
# Epoch 8/19
# 63/63 [==============================] - 1s 12ms/step - loss: -3566073.2500 - binary_accuracy: 0.4122 - val_loss: -3852960.0000 - val_binary_accuracy: 0.4186
# Epoch 9/19
# 63/63 [==============================] - 1s 12ms/step - loss: -4613201.5000 - binary_accuracy: 0.4149 - val_loss: -4901826.0000 - val_binary_accuracy: 0.4118
# Epoch 10/19
# 63/63 [==============================] - 1s 9ms/step - loss: -5780866.0000 - binary_accuracy: 0.4105 - val_loss: -6057132.5000 - val_binary_accuracy: 0.4186
# Epoch 11/19
# 63/63 [==============================] - 1s 9ms/step - loss: -7055375.5000 - binary_accuracy: 0.4130 - val_loss: -7340924.5000 - val_binary_accuracy: 0.4143
# Epoch 12/19
# 63/63 [==============================] - 1s 10ms/step - loss: -8482273.0000 - binary_accuracy: 0.4119 - val_loss: -8713234.0000 - val_binary_accuracy: 0.4180
# Epoch 13/19
# 63/63 [==============================] - 0s 7ms/step - loss: -9989390.0000 - binary_accuracy: 0.4144 - val_loss: -10171257.0000 - val_binary_accuracy: 0.4174
# Epoch 14/19
# 63/63 [==============================] - 0s 7ms/step - loss: -11615637.0000 - binary_accuracy: 0.4169 - val_loss: -11762648.0000 - val_binary_accuracy: 0.4124
# Epoch 15/19
# 63/63 [==============================] - 1s 8ms/step - loss: -13327655.0000 - binary_accuracy: 0.4143 - val_loss: -13414090.0000 - val_binary_accuracy: 0.4130
# Epoch 16/19
# 63/63 [==============================] - 1s 9ms/step - loss: -15149794.0000 - binary_accuracy: 0.4132 - val_loss: -15200293.0000 - val_binary_accuracy: 0.4180
# Epoch 17/19
# 63/63 [==============================] - 0s 7ms/step - loss: -17115458.0000 - binary_accuracy: 0.4146 - val_loss: -17089572.0000 - val_binary_accuracy: 0.4130
# Epoch 18/19
# 63/63 [==============================] - 1s 9ms/step - loss: -19200508.0000 - binary_accuracy: 0.4141 - val_loss: -19085168.0000 - val_binary_accuracy: 0.4161
# Epoch 19/19
# 63/63 [==============================] - 1s 9ms/step - loss: -21354150.0000 - binary_accuracy: 0.4163 - val_loss: -21183822.0000 - val_binary_accuracy: 0.4149
# 357/357 [==============================] - 1s 4ms/step
# Recall: 0.3770115701864272
# 74/74 [==============================] - 0s 3ms/step - loss: -35841644.0000 - binary_accuracy: 0.1573
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/19
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 63/63 [==============================] - 1s 6ms/step - loss: -10710.0801 - binary_accuracy: 0.3989 - val_loss: -38630.9375 - val_binary_accuracy: 0.4168
# Epoch 2/19
# 63/63 [==============================] - 0s 4ms/step - loss: -109068.7344 - binary_accuracy: 0.4127 - val_loss: -201508.3281 - val_binary_accuracy: 0.4068
# Epoch 3/19
# 63/63 [==============================] - 0s 4ms/step - loss: -358009.5000 - binary_accuracy: 0.4041 - val_loss: -514398.1250 - val_binary_accuracy: 0.4043
# Epoch 4/19
# 63/63 [==============================] - 0s 4ms/step - loss: -763309.5000 - binary_accuracy: 0.4063 - val_loss: -969755.8750 - val_binary_accuracy: 0.4105
# Epoch 5/19
# 63/63 [==============================] - 0s 4ms/step - loss: -1302535.8750 - binary_accuracy: 0.4079 - val_loss: -1562777.5000 - val_binary_accuracy: 0.4111
# Epoch 6/19
# 63/63 [==============================] - 0s 4ms/step - loss: -1982907.6250 - binary_accuracy: 0.4108 - val_loss: -2265240.2500 - val_binary_accuracy: 0.4143
# Epoch 7/19
# 63/63 [==============================] - 0s 4ms/step - loss: -2797820.5000 - binary_accuracy: 0.4127 - val_loss: -3107475.7500 - val_binary_accuracy: 0.4161
# Epoch 8/19
# 63/63 [==============================] - 0s 4ms/step - loss: -3715034.5000 - binary_accuracy: 0.4097 - val_loss: -4042050.7500 - val_binary_accuracy: 0.4168
# Epoch 9/19
# 63/63 [==============================] - 0s 4ms/step - loss: -4743084.5000 - binary_accuracy: 0.4122 - val_loss: -5096130.0000 - val_binary_accuracy: 0.4105
# Epoch 10/19
# 63/63 [==============================] - 0s 4ms/step - loss: -5917204.5000 - binary_accuracy: 0.4105 - val_loss: -6263351.0000 - val_binary_accuracy: 0.4118
# Epoch 11/19
# 63/63 [==============================] - 0s 4ms/step - loss: -7190773.0000 - binary_accuracy: 0.4124 - val_loss: -7553971.0000 - val_binary_accuracy: 0.4130
# Epoch 12/19
# 63/63 [==============================] - 0s 4ms/step - loss: -8622865.0000 - binary_accuracy: 0.4105 - val_loss: -8958334.0000 - val_binary_accuracy: 0.4130
# Epoch 13/19
# 63/63 [==============================] - 0s 4ms/step - loss: -10152725.0000 - binary_accuracy: 0.4132 - val_loss: -10470449.0000 - val_binary_accuracy: 0.4212
# Epoch 14/19
# 63/63 [==============================] - 0s 4ms/step - loss: -11756316.0000 - binary_accuracy: 0.4108 - val_loss: -12048446.0000 - val_binary_accuracy: 0.4130
# Epoch 15/19
# 63/63 [==============================] - 0s 4ms/step - loss: -13491948.0000 - binary_accuracy: 0.4129 - val_loss: -13788090.0000 - val_binary_accuracy: 0.4130
# Epoch 16/19
# 63/63 [==============================] - 0s 4ms/step - loss: -15356236.0000 - binary_accuracy: 0.4135 - val_loss: -15648009.0000 - val_binary_accuracy: 0.4180
# Epoch 17/19
# 63/63 [==============================] - 0s 5ms/step - loss: -17325636.0000 - binary_accuracy: 0.4124 - val_loss: -17565488.0000 - val_binary_accuracy: 0.4212
# Epoch 18/19
# 63/63 [==============================] - 0s 4ms/step - loss: -19397124.0000 - binary_accuracy: 0.4135 - val_loss: -19616014.0000 - val_binary_accuracy: 0.4111
# Epoch 19/19
# 63/63 [==============================] - 0s 4ms/step - loss: -21554144.0000 - binary_accuracy: 0.4127 - val_loss: -21714180.0000 - val_binary_accuracy: 0.4155
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.38753441769534097
# 74/74 [==============================] - 0s 3ms/step - loss: 17092216.0000 - binary_accuracy: 0.5411
# 119/119 [==============================] - 0s 2ms/step
# Epoch 1/19
# 63/63 [==============================] - 2s 7ms/step - loss: -11413.0010 - binary_accuracy: 0.4035 - val_loss: -38954.5000 - val_binary_accuracy: 0.4105
# Epoch 2/19
# 63/63 [==============================] - 0s 6ms/step - loss: -109229.7734 - binary_accuracy: 0.4093 - val_loss: -198546.1250 - val_binary_accuracy: 0.4149
# Epoch 3/19
# 63/63 [==============================] - 0s 6ms/step - loss: -348395.4688 - binary_accuracy: 0.4022 - val_loss: -497155.8750 - val_binary_accuracy: 0.4161
# Epoch 4/19
# 63/63 [==============================] - 0s 5ms/step - loss: -733065.3125 - binary_accuracy: 0.4085 - val_loss: -935015.0625 - val_binary_accuracy: 0.4130
# Epoch 5/19
# 63/63 [==============================] - 0s 6ms/step - loss: -1264005.8750 - binary_accuracy: 0.4089 - val_loss: -1498155.6250 - val_binary_accuracy: 0.4005
# Epoch 6/19
# 63/63 [==============================] - 0s 5ms/step - loss: -1919263.7500 - binary_accuracy: 0.4080 - val_loss: -2189302.2500 - val_binary_accuracy: 0.4130
# Epoch 7/19
# 63/63 [==============================] - 0s 6ms/step - loss: -2713179.2500 - binary_accuracy: 0.4088 - val_loss: -2993207.0000 - val_binary_accuracy: 0.4111
# Epoch 8/19
# 63/63 [==============================] - 0s 6ms/step - loss: -3613465.2500 - binary_accuracy: 0.4111 - val_loss: -3919319.2500 - val_binary_accuracy: 0.4130
# Epoch 9/19
# 63/63 [==============================] - 0s 5ms/step - loss: -4627671.5000 - binary_accuracy: 0.4093 - val_loss: -4927138.0000 - val_binary_accuracy: 0.4180
# Epoch 10/19
# 63/63 [==============================] - 0s 6ms/step - loss: -5788407.5000 - binary_accuracy: 0.4079 - val_loss: -6100755.5000 - val_binary_accuracy: 0.4143
# Epoch 11/19
# 63/63 [==============================] - 0s 6ms/step - loss: -7056635.0000 - binary_accuracy: 0.4115 - val_loss: -7366650.0000 - val_binary_accuracy: 0.4136
# Epoch 12/19
# 63/63 [==============================] - 0s 4ms/step - loss: -8464099.0000 - binary_accuracy: 0.4127 - val_loss: -8774109.0000 - val_binary_accuracy: 0.4105
# Epoch 13/19
# 63/63 [==============================] - 0s 4ms/step - loss: -9986181.0000 - binary_accuracy: 0.4116 - val_loss: -10250787.0000 - val_binary_accuracy: 0.4149
# Epoch 14/19
# 63/63 [==============================] - 0s 4ms/step - loss: -11628670.0000 - binary_accuracy: 0.4132 - val_loss: -11876252.0000 - val_binary_accuracy: 0.4111
# Epoch 15/19
# 63/63 [==============================] - 0s 4ms/step - loss: -13361437.0000 - binary_accuracy: 0.4127 - val_loss: -13565078.0000 - val_binary_accuracy: 0.4124
# Epoch 16/19
# 63/63 [==============================] - 0s 5ms/step - loss: -15232300.0000 - binary_accuracy: 0.4119 - val_loss: -15403087.0000 - val_binary_accuracy: 0.4124
# Epoch 17/19
# 63/63 [==============================] - 0s 4ms/step - loss: -17166902.0000 - binary_accuracy: 0.4143 - val_loss: -17284832.0000 - val_binary_accuracy: 0.4105
# Epoch 18/19
# 63/63 [==============================] - 0s 4ms/step - loss: -19265030.0000 - binary_accuracy: 0.4122 - val_loss: -19301446.0000 - val_binary_accuracy: 0.4161
# Epoch 19/19
# 63/63 [==============================] - 0s 4ms/step - loss: -21461788.0000 - binary_accuracy: 0.4119 - val_loss: -21450848.0000 - val_binary_accuracy: 0.4193
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3916449933219485
# 74/74 [==============================] - 0s 3ms/step - loss: 2935349.2500 - binary_accuracy: 0.6381
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 75/75 [==============================] - 1s 5ms/step - loss: -2.6093 - binary_accuracy: 0.3950 - val_loss: -6.6995 - val_binary_accuracy: 0.4130
# Epoch 2/30
# 75/75 [==============================] - 0s 4ms/step - loss: -15.1249 - binary_accuracy: 0.4066 - val_loss: -25.7153 - val_binary_accuracy: 0.4193
# Epoch 3/30
# 75/75 [==============================] - 0s 4ms/step - loss: -43.6993 - binary_accuracy: 0.4085 - val_loss: -61.5666 - val_binary_accuracy: 0.4186
# Epoch 4/30
# 75/75 [==============================] - 0s 4ms/step - loss: -90.5601 - binary_accuracy: 0.4127 - val_loss: -115.9359 - val_binary_accuracy: 0.4218
# Epoch 5/30
# 75/75 [==============================] - 0s 5ms/step - loss: -155.4233 - binary_accuracy: 0.4146 - val_loss: -185.0265 - val_binary_accuracy: 0.4212
# Epoch 6/30
# 75/75 [==============================] - 0s 6ms/step - loss: -236.8887 - binary_accuracy: 0.4143 - val_loss: -271.2792 - val_binary_accuracy: 0.4212
# Epoch 7/30
# 75/75 [==============================] - 1s 7ms/step - loss: -335.5921 - binary_accuracy: 0.4129 - val_loss: -372.9841 - val_binary_accuracy: 0.4224
# Epoch 8/30
# 75/75 [==============================] - 1s 7ms/step - loss: -451.7878 - binary_accuracy: 0.4163 - val_loss: -493.1428 - val_binary_accuracy: 0.4230
# Epoch 9/30
# 75/75 [==============================] - 0s 6ms/step - loss: -584.7636 - binary_accuracy: 0.4143 - val_loss: -626.9973 - val_binary_accuracy: 0.4212
# Epoch 10/30
# 75/75 [==============================] - 1s 7ms/step - loss: -733.8414 - binary_accuracy: 0.4147 - val_loss: -778.0400 - val_binary_accuracy: 0.4205
# Epoch 11/30
# 75/75 [==============================] - 0s 6ms/step - loss: -899.5978 - binary_accuracy: 0.4154 - val_loss: -941.3349 - val_binary_accuracy: 0.4212
# Epoch 12/30
# 75/75 [==============================] - 1s 7ms/step - loss: -1081.2631 - binary_accuracy: 0.4127 - val_loss: -1122.2434 - val_binary_accuracy: 0.4212
# Epoch 13/30
# 75/75 [==============================] - 1s 7ms/step - loss: -1278.7498 - binary_accuracy: 0.4130 - val_loss: -1316.4515 - val_binary_accuracy: 0.4224
# Epoch 14/30
# 75/75 [==============================] - 0s 7ms/step - loss: -1489.4585 - binary_accuracy: 0.4132 - val_loss: -1526.5278 - val_binary_accuracy: 0.4212
# Epoch 15/30
# 75/75 [==============================] - 0s 7ms/step - loss: -1714.5151 - binary_accuracy: 0.4136 - val_loss: -1740.0280 - val_binary_accuracy: 0.4186
# Epoch 16/30
# 75/75 [==============================] - 1s 8ms/step - loss: -1952.6185 - binary_accuracy: 0.4102 - val_loss: -1973.5851 - val_binary_accuracy: 0.4155
# Epoch 17/30
# 75/75 [==============================] - 0s 6ms/step - loss: -2205.3772 - binary_accuracy: 0.4136 - val_loss: -2220.1052 - val_binary_accuracy: 0.4155
# Epoch 18/30
# 75/75 [==============================] - 0s 5ms/step - loss: -2469.6799 - binary_accuracy: 0.4107 - val_loss: -2480.5752 - val_binary_accuracy: 0.4143
# Epoch 19/30
# 75/75 [==============================] - 0s 4ms/step - loss: -2749.2334 - binary_accuracy: 0.4121 - val_loss: -2747.6321 - val_binary_accuracy: 0.4130
# Epoch 20/30
# 75/75 [==============================] - 0s 4ms/step - loss: -3040.2720 - binary_accuracy: 0.4105 - val_loss: -3032.2026 - val_binary_accuracy: 0.4143
# Epoch 21/30
# 75/75 [==============================] - 0s 4ms/step - loss: -3341.6255 - binary_accuracy: 0.4102 - val_loss: -3327.8843 - val_binary_accuracy: 0.4149
# Epoch 22/30
# 75/75 [==============================] - 0s 4ms/step - loss: -3656.4165 - binary_accuracy: 0.4125 - val_loss: -3630.2498 - val_binary_accuracy: 0.4149
# Epoch 23/30
# 75/75 [==============================] - 0s 4ms/step - loss: -3982.2209 - binary_accuracy: 0.4102 - val_loss: -3947.2668 - val_binary_accuracy: 0.4143
# Epoch 24/30
# 75/75 [==============================] - 0s 4ms/step - loss: -4319.1484 - binary_accuracy: 0.4108 - val_loss: -4271.0591 - val_binary_accuracy: 0.4143
# Epoch 25/30
# 75/75 [==============================] - 0s 4ms/step - loss: -4665.7661 - binary_accuracy: 0.4119 - val_loss: -4603.0825 - val_binary_accuracy: 0.4143
# Epoch 26/30
# 75/75 [==============================] - 0s 4ms/step - loss: -5023.1338 - binary_accuracy: 0.4113 - val_loss: -4951.9595 - val_binary_accuracy: 0.4124
# Epoch 27/30
# 75/75 [==============================] - 0s 4ms/step - loss: -5393.5063 - binary_accuracy: 0.4110 - val_loss: -5307.0405 - val_binary_accuracy: 0.4143
# Epoch 28/30
# 75/75 [==============================] - 0s 4ms/step - loss: -5771.7271 - binary_accuracy: 0.4110 - val_loss: -5670.4839 - val_binary_accuracy: 0.4136
# Epoch 29/30
# 75/75 [==============================] - 0s 4ms/step - loss: -6160.8130 - binary_accuracy: 0.4110 - val_loss: -6053.7065 - val_binary_accuracy: 0.4118
# Epoch 30/30
# 75/75 [==============================] - 0s 4ms/step - loss: -6565.4248 - binary_accuracy: 0.4111 - val_loss: -6436.4614 - val_binary_accuracy: 0.4143
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3758395256334257
# 89/89 [==============================] - 0s 3ms/step - loss: -10475.0654 - binary_accuracy: 0.1516
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 75/75 [==============================] - 1s 6ms/step - loss: -2.6424 - binary_accuracy: 0.3994 - val_loss: -6.2614 - val_binary_accuracy: 0.4130
# Epoch 2/30
# 75/75 [==============================] - 0s 4ms/step - loss: -14.4430 - binary_accuracy: 0.4049 - val_loss: -23.3539 - val_binary_accuracy: 0.4161
# Epoch 3/30
# 75/75 [==============================] - 0s 4ms/step - loss: -40.1679 - binary_accuracy: 0.4113 - val_loss: -54.7871 - val_binary_accuracy: 0.4212
# Epoch 4/30
# 75/75 [==============================] - 0s 4ms/step - loss: -82.3323 - binary_accuracy: 0.4132 - val_loss: -100.8638 - val_binary_accuracy: 0.4199
# Epoch 5/30
# 75/75 [==============================] - 0s 4ms/step - loss: -140.8924 - binary_accuracy: 0.4158 - val_loss: -163.5616 - val_binary_accuracy: 0.4218
# Epoch 6/30
# 75/75 [==============================] - 0s 4ms/step - loss: -216.8493 - binary_accuracy: 0.4140 - val_loss: -241.3579 - val_binary_accuracy: 0.4218
# Epoch 7/30
# 75/75 [==============================] - 0s 4ms/step - loss: -310.0303 - binary_accuracy: 0.4130 - val_loss: -333.7200 - val_binary_accuracy: 0.4237
# Epoch 8/30
# 75/75 [==============================] - 0s 4ms/step - loss: -419.4868 - binary_accuracy: 0.4133 - val_loss: -442.5825 - val_binary_accuracy: 0.4237
# Epoch 9/30
# 75/75 [==============================] - 0s 4ms/step - loss: -545.5300 - binary_accuracy: 0.4157 - val_loss: -566.5088 - val_binary_accuracy: 0.4268
# Epoch 10/30
# 75/75 [==============================] - 0s 4ms/step - loss: -686.6431 - binary_accuracy: 0.4152 - val_loss: -701.0587 - val_binary_accuracy: 0.4243
# Epoch 11/30
# 75/75 [==============================] - 0s 4ms/step - loss: -840.4720 - binary_accuracy: 0.4132 - val_loss: -850.6436 - val_binary_accuracy: 0.4230
# Epoch 12/30
# 75/75 [==============================] - 0s 4ms/step - loss: -1008.0953 - binary_accuracy: 0.4147 - val_loss: -1009.6817 - val_binary_accuracy: 0.4186
# Epoch 13/30
# 75/75 [==============================] - 0s 4ms/step - loss: -1188.9285 - binary_accuracy: 0.4138 - val_loss: -1181.5631 - val_binary_accuracy: 0.4205
# Epoch 14/30
# 75/75 [==============================] - 0s 4ms/step - loss: -1382.9226 - binary_accuracy: 0.4124 - val_loss: -1364.7466 - val_binary_accuracy: 0.4212
# Epoch 15/30
# 75/75 [==============================] - 0s 5ms/step - loss: -1590.1516 - binary_accuracy: 0.4140 - val_loss: -1561.6854 - val_binary_accuracy: 0.4174
# Epoch 16/30
# 75/75 [==============================] - 0s 5ms/step - loss: -1810.4735 - binary_accuracy: 0.4107 - val_loss: -1771.7216 - val_binary_accuracy: 0.4174
# Epoch 17/30
# 75/75 [==============================] - 0s 5ms/step - loss: -2041.8699 - binary_accuracy: 0.4102 - val_loss: -1986.9467 - val_binary_accuracy: 0.4186
# Epoch 18/30
# 75/75 [==============================] - 0s 5ms/step - loss: -2286.4761 - binary_accuracy: 0.4063 - val_loss: -2215.8779 - val_binary_accuracy: 0.4243
# Epoch 19/30
# 75/75 [==============================] - 0s 5ms/step - loss: -2544.8325 - binary_accuracy: 0.4132 - val_loss: -2459.3447 - val_binary_accuracy: 0.4174
# Epoch 20/30
# 75/75 [==============================] - 0s 5ms/step - loss: -2813.1626 - binary_accuracy: 0.4105 - val_loss: -2714.7256 - val_binary_accuracy: 0.4174
# Epoch 21/30
# 75/75 [==============================] - 0s 5ms/step - loss: -3095.3142 - binary_accuracy: 0.4116 - val_loss: -2975.8760 - val_binary_accuracy: 0.4168
# Epoch 22/30
# 75/75 [==============================] - 0s 6ms/step - loss: -3387.3069 - binary_accuracy: 0.4100 - val_loss: -3249.1899 - val_binary_accuracy: 0.4161
# Epoch 23/30
# 75/75 [==============================] - 0s 5ms/step - loss: -3692.6492 - binary_accuracy: 0.4147 - val_loss: -3537.7554 - val_binary_accuracy: 0.4168
# Epoch 24/30
# 75/75 [==============================] - 0s 4ms/step - loss: -4009.2092 - binary_accuracy: 0.4104 - val_loss: -3832.2026 - val_binary_accuracy: 0.4161
# Epoch 25/30
# 75/75 [==============================] - 0s 4ms/step - loss: -4334.6323 - binary_accuracy: 0.4100 - val_loss: -4140.6948 - val_binary_accuracy: 0.4143
# Epoch 26/30
# 75/75 [==============================] - 0s 4ms/step - loss: -4671.6270 - binary_accuracy: 0.4113 - val_loss: -4449.9575 - val_binary_accuracy: 0.4193
# Epoch 27/30
# 75/75 [==============================] - 0s 4ms/step - loss: -5017.5986 - binary_accuracy: 0.4119 - val_loss: -4771.6763 - val_binary_accuracy: 0.4161
# Epoch 28/30
# 75/75 [==============================] - 0s 4ms/step - loss: -5375.5659 - binary_accuracy: 0.4140 - val_loss: -5104.7002 - val_binary_accuracy: 0.4155
# Epoch 29/30
# 75/75 [==============================] - 0s 4ms/step - loss: -5741.1084 - binary_accuracy: 0.4116 - val_loss: -5448.1108 - val_binary_accuracy: 0.4155
# Epoch 30/30
# 75/75 [==============================] - 0s 4ms/step - loss: -6115.7007 - binary_accuracy: 0.4125 - val_loss: -5788.1162 - val_binary_accuracy: 0.4143
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3790749832960394
# 89/89 [==============================] - 0s 3ms/step - loss: 5160.5781 - binary_accuracy: 0.5263
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/30
# 75/75 [==============================] - 1s 6ms/step - loss: -2.5741 - binary_accuracy: 0.3996 - val_loss: -6.2378 - val_binary_accuracy: 0.4105
# Epoch 2/30
# 75/75 [==============================] - 0s 4ms/step - loss: -14.1499 - binary_accuracy: 0.4049 - val_loss: -23.3095 - val_binary_accuracy: 0.4168
# Epoch 3/30
# 75/75 [==============================] - 0s 4ms/step - loss: -40.0452 - binary_accuracy: 0.4107 - val_loss: -55.4134 - val_binary_accuracy: 0.4205
# Epoch 4/30
# 75/75 [==============================] - 0s 4ms/step - loss: -82.8265 - binary_accuracy: 0.4125 - val_loss: -103.3556 - val_binary_accuracy: 0.4212
# Epoch 5/30
# 75/75 [==============================] - 0s 5ms/step - loss: -142.8117 - binary_accuracy: 0.4144 - val_loss: -166.9406 - val_binary_accuracy: 0.4218
# Epoch 6/30
# 75/75 [==============================] - 0s 4ms/step - loss: -220.1824 - binary_accuracy: 0.4144 - val_loss: -247.9188 - val_binary_accuracy: 0.4224
# Epoch 7/30
# 75/75 [==============================] - 0s 4ms/step - loss: -313.4953 - binary_accuracy: 0.4179 - val_loss: -342.3339 - val_binary_accuracy: 0.4161
# Epoch 8/30
# 75/75 [==============================] - 0s 4ms/step - loss: -422.2886 - binary_accuracy: 0.4147 - val_loss: -449.8863 - val_binary_accuracy: 0.4199
# Epoch 9/30
# 75/75 [==============================] - 0s 4ms/step - loss: -545.4489 - binary_accuracy: 0.4127 - val_loss: -572.5462 - val_binary_accuracy: 0.4205
# Epoch 10/30
# 75/75 [==============================] - 0s 4ms/step - loss: -685.0289 - binary_accuracy: 0.4127 - val_loss: -709.1254 - val_binary_accuracy: 0.4224
# Epoch 11/30
# 75/75 [==============================] - 0s 4ms/step - loss: -839.6384 - binary_accuracy: 0.4138 - val_loss: -857.9295 - val_binary_accuracy: 0.4193
# Epoch 12/30
# 75/75 [==============================] - 0s 4ms/step - loss: -1009.3775 - binary_accuracy: 0.4115 - val_loss: -1024.3475 - val_binary_accuracy: 0.4155
# Epoch 13/30
# 75/75 [==============================] - 0s 4ms/step - loss: -1193.7917 - binary_accuracy: 0.4093 - val_loss: -1203.6760 - val_binary_accuracy: 0.4174
# Epoch 14/30
# 75/75 [==============================] - 0s 4ms/step - loss: -1392.9971 - binary_accuracy: 0.4127 - val_loss: -1393.5974 - val_binary_accuracy: 0.4149
# Epoch 15/30
# 75/75 [==============================] - 0s 4ms/step - loss: -1602.3027 - binary_accuracy: 0.4104 - val_loss: -1594.7532 - val_binary_accuracy: 0.4136
# Epoch 16/30
# 75/75 [==============================] - 0s 4ms/step - loss: -1823.9866 - binary_accuracy: 0.4089 - val_loss: -1807.5411 - val_binary_accuracy: 0.4149
# Epoch 17/30
# 75/75 [==============================] - 0s 4ms/step - loss: -2058.5579 - binary_accuracy: 0.4102 - val_loss: -2032.4618 - val_binary_accuracy: 0.4143
# Epoch 18/30
# 75/75 [==============================] - 0s 5ms/step - loss: -2307.4709 - binary_accuracy: 0.4115 - val_loss: -2272.1482 - val_binary_accuracy: 0.4143
# Epoch 19/30
# 75/75 [==============================] - 0s 4ms/step - loss: -2565.1936 - binary_accuracy: 0.4099 - val_loss: -2517.3179 - val_binary_accuracy: 0.4143
# Epoch 20/30
# 75/75 [==============================] - 0s 4ms/step - loss: -2833.3115 - binary_accuracy: 0.4111 - val_loss: -2775.0056 - val_binary_accuracy: 0.4143
# Epoch 21/30
# 75/75 [==============================] - 0s 4ms/step - loss: -3113.8689 - binary_accuracy: 0.4118 - val_loss: -3041.2930 - val_binary_accuracy: 0.4149
# Epoch 22/30
# 75/75 [==============================] - 0s 4ms/step - loss: -3406.1318 - binary_accuracy: 0.4115 - val_loss: -3317.7043 - val_binary_accuracy: 0.4149
# Epoch 23/30
# 75/75 [==============================] - 0s 4ms/step - loss: -3708.7637 - binary_accuracy: 0.4105 - val_loss: -3604.8201 - val_binary_accuracy: 0.4143
# Epoch 24/30
# 75/75 [==============================] - 0s 4ms/step - loss: -4021.6880 - binary_accuracy: 0.4105 - val_loss: -3901.4697 - val_binary_accuracy: 0.4155
# Epoch 25/30
# 75/75 [==============================] - 0s 4ms/step - loss: -4344.6763 - binary_accuracy: 0.4125 - val_loss: -4209.2705 - val_binary_accuracy: 0.4136
# Epoch 26/30
# 75/75 [==============================] - 0s 6ms/step - loss: -4680.1641 - binary_accuracy: 0.4107 - val_loss: -4526.0161 - val_binary_accuracy: 0.4136
# Epoch 27/30
# 75/75 [==============================] - 0s 5ms/step - loss: -5024.2012 - binary_accuracy: 0.4121 - val_loss: -4853.6182 - val_binary_accuracy: 0.4143
# Epoch 28/30
# 75/75 [==============================] - 0s 5ms/step - loss: -5379.9873 - binary_accuracy: 0.4121 - val_loss: -5189.7793 - val_binary_accuracy: 0.4143
# Epoch 29/30
# 75/75 [==============================] - 0s 6ms/step - loss: -5744.8408 - binary_accuracy: 0.4110 - val_loss: -5530.3525 - val_binary_accuracy: 0.4155
# Epoch 30/30
# 75/75 [==============================] - 0s 5ms/step - loss: -6117.0259 - binary_accuracy: 0.4111 - val_loss: -5881.9707 - val_binary_accuracy: 0.4155
# 357/357 [==============================] - 1s 2ms/step
# Recall: 0.37327281518436534
# 89/89 [==============================] - 0s 3ms/step - loss: 589.8954 - binary_accuracy: 0.6376
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 51/51 [==============================] - 1s 7ms/step - loss: -30.1472 - binary_accuracy: 0.3989 - val_loss: -96.4607 - val_binary_accuracy: 0.4161
# Epoch 2/10
# 51/51 [==============================] - 0s 4ms/step - loss: -290.4126 - binary_accuracy: 0.4121 - val_loss: -521.8524 - val_binary_accuracy: 0.4199
# Epoch 3/10
# 51/51 [==============================] - 0s 4ms/step - loss: -987.3118 - binary_accuracy: 0.4113 - val_loss: -1419.3796 - val_binary_accuracy: 0.4237
# Epoch 4/10
# 51/51 [==============================] - 0s 4ms/step - loss: -2224.9729 - binary_accuracy: 0.4121 - val_loss: -2802.9724 - val_binary_accuracy: 0.4218
# Epoch 5/10
# 51/51 [==============================] - 0s 4ms/step - loss: -3995.5210 - binary_accuracy: 0.4099 - val_loss: -4683.2222 - val_binary_accuracy: 0.4293
# Epoch 6/10
# 51/51 [==============================] - 0s 4ms/step - loss: -6277.1230 - binary_accuracy: 0.4138 - val_loss: -7009.3604 - val_binary_accuracy: 0.4193
# Epoch 7/10
# 51/51 [==============================] - 0s 5ms/step - loss: -9069.3350 - binary_accuracy: 0.4111 - val_loss: -9765.5029 - val_binary_accuracy: 0.4136
# Epoch 8/10
# 51/51 [==============================] - 0s 4ms/step - loss: -12329.4756 - binary_accuracy: 0.4115 - val_loss: -12983.7412 - val_binary_accuracy: 0.4186
# Epoch 9/10
# 51/51 [==============================] - 0s 5ms/step - loss: -16029.1367 - binary_accuracy: 0.4110 - val_loss: -16638.5625 - val_binary_accuracy: 0.4105
# Epoch 10/10
# 51/51 [==============================] - 0s 4ms/step - loss: -20224.1445 - binary_accuracy: 0.4107 - val_loss: -20582.5195 - val_binary_accuracy: 0.4111
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.366587403812389
# 61/61 [==============================] - 0s 3ms/step - loss: -38523.3125 - binary_accuracy: 0.1489
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 51/51 [==============================] - 1s 7ms/step - loss: -34.0592 - binary_accuracy: 0.4021 - val_loss: -109.5831 - val_binary_accuracy: 0.4186
# Epoch 2/10
# 51/51 [==============================] - 0s 5ms/step - loss: -310.3800 - binary_accuracy: 0.4102 - val_loss: -569.2783 - val_binary_accuracy: 0.4218
# Epoch 3/10
# 51/51 [==============================] - 0s 5ms/step - loss: -1030.3099 - binary_accuracy: 0.4121 - val_loss: -1488.7765 - val_binary_accuracy: 0.4174
# Epoch 4/10
# 51/51 [==============================] - 0s 4ms/step - loss: -2267.7546 - binary_accuracy: 0.4136 - val_loss: -2889.3445 - val_binary_accuracy: 0.4168
# Epoch 5/10
# 51/51 [==============================] - 0s 4ms/step - loss: -4026.7969 - binary_accuracy: 0.4107 - val_loss: -4758.6118 - val_binary_accuracy: 0.4105
# Epoch 6/10
# 51/51 [==============================] - 0s 4ms/step - loss: -6254.6133 - binary_accuracy: 0.4072 - val_loss: -7138.6597 - val_binary_accuracy: 0.4180
# Epoch 7/10
# 51/51 [==============================] - 0s 4ms/step - loss: -9003.6768 - binary_accuracy: 0.4088 - val_loss: -9892.9434 - val_binary_accuracy: 0.4180
# Epoch 8/10
# 51/51 [==============================] - 0s 5ms/step - loss: -12183.1875 - binary_accuracy: 0.4096 - val_loss: -13102.2881 - val_binary_accuracy: 0.4136
# Epoch 9/10
# 51/51 [==============================] - 0s 4ms/step - loss: -15818.3320 - binary_accuracy: 0.4110 - val_loss: -16760.6289 - val_binary_accuracy: 0.4193
# Epoch 10/10
# 51/51 [==============================] - 0s 4ms/step - loss: -19883.9453 - binary_accuracy: 0.4083 - val_loss: -20798.0234 - val_binary_accuracy: 0.4168
# 357/357 [==============================] - 1s 4ms/step
# Recall: 0.3838371723592022
# 61/61 [==============================] - 0s 3ms/step - loss: 16479.8750 - binary_accuracy: 0.5423
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/10
# 51/51 [==============================] - 1s 6ms/step - loss: -33.4862 - binary_accuracy: 0.3988 - val_loss: -102.5936 - val_binary_accuracy: 0.4186
# Epoch 2/10
# 51/51 [==============================] - 0s 4ms/step - loss: -294.1471 - binary_accuracy: 0.4110 - val_loss: -526.7781 - val_binary_accuracy: 0.4105
# Epoch 3/10
# 51/51 [==============================] - 0s 5ms/step - loss: -972.4116 - binary_accuracy: 0.4141 - val_loss: -1410.0765 - val_binary_accuracy: 0.4243
# Epoch 4/10
# 51/51 [==============================] - 0s 4ms/step - loss: -2155.8889 - binary_accuracy: 0.4113 - val_loss: -2776.4009 - val_binary_accuracy: 0.4293
# Epoch 5/10
# 51/51 [==============================] - 0s 4ms/step - loss: -3855.5312 - binary_accuracy: 0.4158 - val_loss: -4595.4106 - val_binary_accuracy: 0.4205
# Epoch 6/10
# 51/51 [==============================] - 0s 4ms/step - loss: -6041.7075 - binary_accuracy: 0.4144 - val_loss: -6867.7383 - val_binary_accuracy: 0.4136
# Epoch 7/10
# 51/51 [==============================] - 0s 4ms/step - loss: -8721.1924 - binary_accuracy: 0.4107 - val_loss: -9569.6123 - val_binary_accuracy: 0.4143
# Epoch 8/10
# 51/51 [==============================] - 0s 4ms/step - loss: -11849.5127 - binary_accuracy: 0.4113 - val_loss: -12720.8662 - val_binary_accuracy: 0.4155
# Epoch 9/10
# 51/51 [==============================] - 0s 4ms/step - loss: -15430.4961 - binary_accuracy: 0.4110 - val_loss: -16220.3291 - val_binary_accuracy: 0.4180
# Epoch 10/10
# 51/51 [==============================] - 0s 4ms/step - loss: -19427.2832 - binary_accuracy: 0.4144 - val_loss: -20238.1934 - val_binary_accuracy: 0.4124
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.37476645661009345
# 61/61 [==============================] - 0s 3ms/step - loss: 2016.0106 - binary_accuracy: 0.6346
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/17
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 52/52 [==============================] - 1s 7ms/step - loss: -6894.3774 - binary_accuracy: 0.3997 - val_loss: -23456.6504 - val_binary_accuracy: 0.4155
# Epoch 2/17
# 52/52 [==============================] - 0s 6ms/step - loss: -67589.6953 - binary_accuracy: 0.4107 - val_loss: -125575.8516 - val_binary_accuracy: 0.4174
# Epoch 3/17
# 52/52 [==============================] - 0s 5ms/step - loss: -223244.0156 - binary_accuracy: 0.4115 - val_loss: -323616.6562 - val_binary_accuracy: 0.4118
# Epoch 4/17
# 52/52 [==============================] - 0s 6ms/step - loss: -481442.1875 - binary_accuracy: 0.4122 - val_loss: -620784.0000 - val_binary_accuracy: 0.4105
# Epoch 5/17
# 52/52 [==============================] - 0s 5ms/step - loss: -840892.1250 - binary_accuracy: 0.4068 - val_loss: -1015079.6250 - val_binary_accuracy: 0.4111
# Epoch 6/17
# 52/52 [==============================] - 0s 6ms/step - loss: -1297556.2500 - binary_accuracy: 0.4107 - val_loss: -1496111.8750 - val_binary_accuracy: 0.4118
# Epoch 7/17
# 52/52 [==============================] - 0s 6ms/step - loss: -1846216.2500 - binary_accuracy: 0.4088 - val_loss: -2065346.1250 - val_binary_accuracy: 0.4143
# Epoch 8/17
# 52/52 [==============================] - 0s 6ms/step - loss: -2479732.0000 - binary_accuracy: 0.4111 - val_loss: -2725174.5000 - val_binary_accuracy: 0.4136
# Epoch 9/17
# 52/52 [==============================] - 0s 6ms/step - loss: -3205008.7500 - binary_accuracy: 0.4108 - val_loss: -3456532.2500 - val_binary_accuracy: 0.4111
# Epoch 10/17
# 52/52 [==============================] - 0s 6ms/step - loss: -4009769.2500 - binary_accuracy: 0.4075 - val_loss: -4269145.0000 - val_binary_accuracy: 0.4143
# Epoch 11/17
# 52/52 [==============================] - 0s 6ms/step - loss: -4907918.5000 - binary_accuracy: 0.4110 - val_loss: -5154847.5000 - val_binary_accuracy: 0.4118
# Epoch 12/17
# 52/52 [==============================] - 0s 6ms/step - loss: -5880123.5000 - binary_accuracy: 0.4124 - val_loss: -6143282.5000 - val_binary_accuracy: 0.4130
# Epoch 13/17
# 52/52 [==============================] - 0s 6ms/step - loss: -6945293.5000 - binary_accuracy: 0.4105 - val_loss: -7194150.0000 - val_binary_accuracy: 0.4143
# Epoch 14/17
# 52/52 [==============================] - 0s 5ms/step - loss: -8082211.5000 - binary_accuracy: 0.4132 - val_loss: -8324299.0000 - val_binary_accuracy: 0.4143
# Epoch 15/17
# 52/52 [==============================] - 0s 5ms/step - loss: -9294112.0000 - binary_accuracy: 0.4122 - val_loss: -9541269.0000 - val_binary_accuracy: 0.4111
# Epoch 16/17
# 52/52 [==============================] - 0s 4ms/step - loss: -10592542.0000 - binary_accuracy: 0.4118 - val_loss: -10785099.0000 - val_binary_accuracy: 0.4168
# Epoch 17/17
# 52/52 [==============================] - 0s 4ms/step - loss: -11948236.0000 - binary_accuracy: 0.4146 - val_loss: -12154324.0000 - val_binary_accuracy: 0.4155
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3808983468908023
# 62/62 [==============================] - 0s 3ms/step - loss: -20354088.0000 - binary_accuracy: 0.1568
# 119/119 [==============================] - 0s 2ms/step
# Epoch 1/17
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 52/52 [==============================] - 1s 6ms/step - loss: -7234.6489 - binary_accuracy: 0.3988 - val_loss: -24260.2676 - val_binary_accuracy: 0.4161
# Epoch 2/17
# 52/52 [==============================] - 0s 4ms/step - loss: -70899.5234 - binary_accuracy: 0.4124 - val_loss: -129178.4844 - val_binary_accuracy: 0.4143
# Epoch 3/17
# 52/52 [==============================] - 0s 4ms/step - loss: -228874.8125 - binary_accuracy: 0.4083 - val_loss: -330565.6562 - val_binary_accuracy: 0.4130
# Epoch 4/17
# 52/52 [==============================] - 0s 4ms/step - loss: -490044.5625 - binary_accuracy: 0.4061 - val_loss: -628375.6875 - val_binary_accuracy: 0.4130
# Epoch 5/17
# 52/52 [==============================] - 0s 4ms/step - loss: -854178.0625 - binary_accuracy: 0.4088 - val_loss: -1021482.3125 - val_binary_accuracy: 0.4099
# Epoch 6/17
# 52/52 [==============================] - 0s 5ms/step - loss: -1314723.5000 - binary_accuracy: 0.4107 - val_loss: -1509485.1250 - val_binary_accuracy: 0.4099
# Epoch 7/17
# 52/52 [==============================] - 0s 4ms/step - loss: -1868083.8750 - binary_accuracy: 0.4100 - val_loss: -2077897.3750 - val_binary_accuracy: 0.4130
# Epoch 8/17
# 52/52 [==============================] - 0s 4ms/step - loss: -2510485.2500 - binary_accuracy: 0.4127 - val_loss: -2735747.7500 - val_binary_accuracy: 0.4124
# Epoch 9/17
# 52/52 [==============================] - 0s 5ms/step - loss: -3242348.0000 - binary_accuracy: 0.4122 - val_loss: -3478594.2500 - val_binary_accuracy: 0.4186
# Epoch 10/17
# 52/52 [==============================] - 0s 5ms/step - loss: -4062973.0000 - binary_accuracy: 0.4108 - val_loss: -4308987.5000 - val_binary_accuracy: 0.4118
# Epoch 11/17
# 52/52 [==============================] - 0s 4ms/step - loss: -4975686.0000 - binary_accuracy: 0.4086 - val_loss: -5205223.0000 - val_binary_accuracy: 0.4149
# Epoch 12/17
# 52/52 [==============================] - 0s 4ms/step - loss: -5964919.0000 - binary_accuracy: 0.4140 - val_loss: -6192986.5000 - val_binary_accuracy: 0.4130
# Epoch 13/17
# 52/52 [==============================] - 0s 4ms/step - loss: -7044589.0000 - binary_accuracy: 0.4107 - val_loss: -7246787.0000 - val_binary_accuracy: 0.4143
# Epoch 14/17
# 52/52 [==============================] - 0s 4ms/step - loss: -8199897.0000 - binary_accuracy: 0.4124 - val_loss: -8407699.0000 - val_binary_accuracy: 0.4199
# Epoch 15/17
# 52/52 [==============================] - 0s 4ms/step - loss: -9443532.0000 - binary_accuracy: 0.4154 - val_loss: -9627015.0000 - val_binary_accuracy: 0.4130
# Epoch 16/17
# 52/52 [==============================] - 0s 5ms/step - loss: -10766553.0000 - binary_accuracy: 0.4135 - val_loss: -10919562.0000 - val_binary_accuracy: 0.4180
# Epoch 17/17
# 52/52 [==============================] - 0s 4ms/step - loss: -12176893.0000 - binary_accuracy: 0.4155 - val_loss: -12295617.0000 - val_binary_accuracy: 0.4143
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3775395378095944
# 62/62 [==============================] - 0s 3ms/step - loss: 9963263.0000 - binary_accuracy: 0.5455
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/17
# 52/52 [==============================] - 1s 10ms/step - loss: -7006.7173 - binary_accuracy: 0.3996 - val_loss: -24159.4238 - val_binary_accuracy: 0.4118
# Epoch 2/17
# 52/52 [==============================] - 0s 6ms/step - loss: -70799.8672 - binary_accuracy: 0.4083 - val_loss: -129479.6172 - val_binary_accuracy: 0.4149
# Epoch 3/17
# 52/52 [==============================] - 0s 6ms/step - loss: -231259.3125 - binary_accuracy: 0.4097 - val_loss: -327553.2812 - val_binary_accuracy: 0.4136
# Epoch 4/17
# 52/52 [==============================] - 0s 6ms/step - loss: -492109.2812 - binary_accuracy: 0.4115 - val_loss: -623503.1875 - val_binary_accuracy: 0.3999
# Epoch 5/17
# 52/52 [==============================] - 0s 6ms/step - loss: -850658.1875 - binary_accuracy: 0.4077 - val_loss: -1011552.2500 - val_binary_accuracy: 0.4074
# Epoch 6/17
# 52/52 [==============================] - 0s 6ms/step - loss: -1309866.1250 - binary_accuracy: 0.4086 - val_loss: -1481013.6250 - val_binary_accuracy: 0.4111
# Epoch 7/17
# 52/52 [==============================] - 0s 6ms/step - loss: -1861607.3750 - binary_accuracy: 0.4119 - val_loss: -2052462.5000 - val_binary_accuracy: 0.4118
# Epoch 8/17
# 52/52 [==============================] - 0s 6ms/step - loss: -2513353.0000 - binary_accuracy: 0.4118 - val_loss: -2699764.2500 - val_binary_accuracy: 0.4161
# Epoch 9/17
# 52/52 [==============================] - 0s 6ms/step - loss: -3249890.0000 - binary_accuracy: 0.4110 - val_loss: -3435009.5000 - val_binary_accuracy: 0.4143
# Epoch 10/17
# 52/52 [==============================] - 0s 6ms/step - loss: -4073604.7500 - binary_accuracy: 0.4115 - val_loss: -4260160.5000 - val_binary_accuracy: 0.4186
# Epoch 11/17
# 52/52 [==============================] - 0s 5ms/step - loss: -4992608.0000 - binary_accuracy: 0.4125 - val_loss: -5164750.5000 - val_binary_accuracy: 0.4118
# Epoch 12/17
# 52/52 [==============================] - 0s 4ms/step - loss: -5995290.5000 - binary_accuracy: 0.4125 - val_loss: -6154272.0000 - val_binary_accuracy: 0.4161
# Epoch 13/17
# 52/52 [==============================] - 0s 5ms/step - loss: -7088368.5000 - binary_accuracy: 0.4127 - val_loss: -7224700.5000 - val_binary_accuracy: 0.4118
# Epoch 14/17
# 52/52 [==============================] - 0s 5ms/step - loss: -8262120.5000 - binary_accuracy: 0.4146 - val_loss: -8362280.5000 - val_binary_accuracy: 0.4130
# Epoch 15/17
# 52/52 [==============================] - 0s 5ms/step - loss: -9520291.0000 - binary_accuracy: 0.4130 - val_loss: -9566054.0000 - val_binary_accuracy: 0.4124
# Epoch 16/17
# 52/52 [==============================] - 0s 4ms/step - loss: -10844002.0000 - binary_accuracy: 0.4143 - val_loss: -10880647.0000 - val_binary_accuracy: 0.4168
# Epoch 17/17
# 52/52 [==============================] - 0s 5ms/step - loss: -12260310.0000 - binary_accuracy: 0.4138 - val_loss: -12236850.0000 - val_binary_accuracy: 0.4168
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3847778814832505
# 62/62 [==============================] - 0s 3ms/step - loss: 1467274.1250 - binary_accuracy: 0.6398
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/24
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 94/94 [==============================] - 1s 5ms/step - loss: -29150.3848 - binary_accuracy: 0.4063 - val_loss: -97223.0859 - val_binary_accuracy: 0.4124
# Epoch 2/24
# 94/94 [==============================] - 0s 3ms/step - loss: -270248.0000 - binary_accuracy: 0.4088 - val_loss: -478271.8125 - val_binary_accuracy: 0.4136
# Epoch 3/24
# 94/94 [==============================] - 0s 3ms/step - loss: -824336.7500 - binary_accuracy: 0.4080 - val_loss: -1163830.1250 - val_binary_accuracy: 0.4118
# Epoch 4/24
# 94/94 [==============================] - 0s 4ms/step - loss: -1700208.7500 - binary_accuracy: 0.4074 - val_loss: -2154993.0000 - val_binary_accuracy: 0.4099
# Epoch 5/24
# 94/94 [==============================] - 0s 5ms/step - loss: -2884608.2500 - binary_accuracy: 0.4121 - val_loss: -3422021.2500 - val_binary_accuracy: 0.4124
# Epoch 6/24
# 94/94 [==============================] - 1s 5ms/step - loss: -4348410.0000 - binary_accuracy: 0.4083 - val_loss: -4993379.5000 - val_binary_accuracy: 0.4149
# Epoch 7/24
# 94/94 [==============================] - 0s 5ms/step - loss: -6078377.0000 - binary_accuracy: 0.4129 - val_loss: -6751555.5000 - val_binary_accuracy: 0.4130
# Epoch 8/24
# 94/94 [==============================] - 0s 5ms/step - loss: -8059731.0000 - binary_accuracy: 0.4097 - val_loss: -8782501.0000 - val_binary_accuracy: 0.4130
# Epoch 9/24
# 94/94 [==============================] - 0s 4ms/step - loss: -10309542.0000 - binary_accuracy: 0.4105 - val_loss: -11054682.0000 - val_binary_accuracy: 0.4155
# Epoch 10/24
# 94/94 [==============================] - 0s 4ms/step - loss: -12809402.0000 - binary_accuracy: 0.4129 - val_loss: -13544404.0000 - val_binary_accuracy: 0.4155
# Epoch 11/24
# 94/94 [==============================] - 0s 5ms/step - loss: -15550870.0000 - binary_accuracy: 0.4132 - val_loss: -16247198.0000 - val_binary_accuracy: 0.4193
# Epoch 12/24
# 94/94 [==============================] - 0s 5ms/step - loss: -18500480.0000 - binary_accuracy: 0.4130 - val_loss: -19244268.0000 - val_binary_accuracy: 0.4143
# Epoch 13/24
# 94/94 [==============================] - 0s 4ms/step - loss: -21670854.0000 - binary_accuracy: 0.4149 - val_loss: -22399496.0000 - val_binary_accuracy: 0.4111
# Epoch 14/24
# 94/94 [==============================] - 0s 4ms/step - loss: -25057864.0000 - binary_accuracy: 0.4089 - val_loss: -25730742.0000 - val_binary_accuracy: 0.4143
# Epoch 15/24
# 94/94 [==============================] - 0s 3ms/step - loss: -28656288.0000 - binary_accuracy: 0.4160 - val_loss: -29257704.0000 - val_binary_accuracy: 0.4161
# Epoch 16/24
# 94/94 [==============================] - 0s 3ms/step - loss: -32452808.0000 - binary_accuracy: 0.4135 - val_loss: -32989994.0000 - val_binary_accuracy: 0.4136
# Epoch 17/24
# 94/94 [==============================] - 0s 3ms/step - loss: -36447292.0000 - binary_accuracy: 0.4140 - val_loss: -36924132.0000 - val_binary_accuracy: 0.4111
# Epoch 18/24
# 94/94 [==============================] - 0s 3ms/step - loss: -40655136.0000 - binary_accuracy: 0.4122 - val_loss: -41026236.0000 - val_binary_accuracy: 0.4186
# Epoch 19/24
# 94/94 [==============================] - 0s 4ms/step - loss: -45032208.0000 - binary_accuracy: 0.4146 - val_loss: -45335020.0000 - val_binary_accuracy: 0.4143
# Epoch 20/24
# 94/94 [==============================] - 0s 3ms/step - loss: -49612724.0000 - binary_accuracy: 0.4125 - val_loss: -49804248.0000 - val_binary_accuracy: 0.4155
# Epoch 21/24
# 94/94 [==============================] - 0s 3ms/step - loss: -54363628.0000 - binary_accuracy: 0.4140 - val_loss: -54483424.0000 - val_binary_accuracy: 0.4155
# Epoch 22/24
# 94/94 [==============================] - 0s 3ms/step - loss: -59307380.0000 - binary_accuracy: 0.4143 - val_loss: -59260252.0000 - val_binary_accuracy: 0.4161
# Epoch 23/24
# 94/94 [==============================] - 0s 3ms/step - loss: -64401208.0000 - binary_accuracy: 0.4154 - val_loss: -64260444.0000 - val_binary_accuracy: 0.4193
# Epoch 24/24
# 94/94 [==============================] - 0s 3ms/step - loss: -69687296.0000 - binary_accuracy: 0.4152 - val_loss: -69364808.0000 - val_binary_accuracy: 0.4155
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3826323322261734
# 112/112 [==============================] - 1s 3ms/step - loss: -113235104.0000 - binary_accuracy: 0.1594
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/24
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 94/94 [==============================] - 1s 5ms/step - loss: -31316.5000 - binary_accuracy: 0.3999 - val_loss: -101747.1875 - val_binary_accuracy: 0.3961
# Epoch 2/24
# 94/94 [==============================] - 0s 3ms/step - loss: -287518.4062 - binary_accuracy: 0.4055 - val_loss: -493448.4375 - val_binary_accuracy: 0.4124
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# 89/89 [==============================] - 1s 5ms/step - loss: -96.7241 - binary_accuracy: 0.4014 - val_loss: -315.7679 - val_binary_accuracy: 0.4230
# Epoch 2/29
# 89/89 [==============================] - 0s 5ms/step - loss: -960.0638 - binary_accuracy: 0.4088 - val_loss: -1725.0250 - val_binary_accuracy: 0.4199
# Epoch 3/29
# 89/89 [==============================] - 0s 5ms/step - loss: -3106.8691 - binary_accuracy: 0.4107 - val_loss: -4374.7598 - val_binary_accuracy: 0.4255
# Epoch 4/29
# 89/89 [==============================] - 1s 6ms/step - loss: -6520.9229 - binary_accuracy: 0.4130 - val_loss: -8202.6592 - val_binary_accuracy: 0.4149
# Epoch 5/29
# 89/89 [==============================] - 0s 5ms/step - loss: -11122.1660 - binary_accuracy: 0.4107 - val_loss: -13016.1279 - val_binary_accuracy: 0.4111
# Epoch 6/29
# 89/89 [==============================] - 0s 5ms/step - loss: -16897.3047 - binary_accuracy: 0.4089 - val_loss: -18929.3320 - val_binary_accuracy: 0.4118
# Epoch 7/29
# 89/89 [==============================] - 0s 5ms/step - loss: -23842.1328 - binary_accuracy: 0.4111 - val_loss: -25906.0430 - val_binary_accuracy: 0.4143
# Epoch 8/29
# 89/89 [==============================] - 1s 6ms/step - loss: -31834.8770 - binary_accuracy: 0.4122 - val_loss: -33871.5117 - val_binary_accuracy: 0.4149
# Epoch 9/29
# 89/89 [==============================] - 1s 6ms/step - loss: -40838.6250 - binary_accuracy: 0.4118 - val_loss: -42732.0000 - val_binary_accuracy: 0.4136
# Epoch 10/29
# 89/89 [==============================] - 0s 4ms/step - loss: -50763.5352 - binary_accuracy: 0.4122 - val_loss: -52389.8516 - val_binary_accuracy: 0.4149
# Epoch 11/29
# 89/89 [==============================] - 0s 4ms/step - loss: -61577.5820 - binary_accuracy: 0.4129 - val_loss: -62964.0703 - val_binary_accuracy: 0.4105
# Epoch 12/29
# 89/89 [==============================] - 0s 5ms/step - loss: -73332.3984 - binary_accuracy: 0.4107 - val_loss: -74144.5000 - val_binary_accuracy: 0.4124
# Epoch 13/29
# 89/89 [==============================] - 0s 4ms/step - loss: -85912.9219 - binary_accuracy: 0.4127 - val_loss: -86513.1328 - val_binary_accuracy: 0.4118
# Epoch 14/29
# 89/89 [==============================] - 0s 4ms/step - loss: -99450.7266 - binary_accuracy: 0.4124 - val_loss: -99622.8750 - val_binary_accuracy: 0.4136
# Epoch 15/29
# 89/89 [==============================] - 0s 4ms/step - loss: -113792.8594 - binary_accuracy: 0.4111 - val_loss: -113451.4922 - val_binary_accuracy: 0.4105
# Epoch 16/29
# 89/89 [==============================] - 0s 4ms/step - loss: -129014.3672 - binary_accuracy: 0.4111 - val_loss: -127920.6094 - val_binary_accuracy: 0.4130
# Epoch 17/29
# 89/89 [==============================] - 0s 4ms/step - loss: -145018.0625 - binary_accuracy: 0.4132 - val_loss: -143343.4062 - val_binary_accuracy: 0.4118
# Epoch 18/29
# 89/89 [==============================] - 0s 4ms/step - loss: -161882.0781 - binary_accuracy: 0.4116 - val_loss: -159279.3125 - val_binary_accuracy: 0.4130
# Epoch 19/29
# 89/89 [==============================] - 0s 4ms/step - loss: -179500.6406 - binary_accuracy: 0.4118 - val_loss: -176135.0312 - val_binary_accuracy: 0.4161
# Epoch 20/29
# 89/89 [==============================] - 0s 4ms/step - loss: -197962.0000 - binary_accuracy: 0.4136 - val_loss: -193742.1562 - val_binary_accuracy: 0.4130
# Epoch 21/29
# 89/89 [==============================] - 0s 4ms/step - loss: -217200.4844 - binary_accuracy: 0.4136 - val_loss: -212228.6875 - val_binary_accuracy: 0.4124
# Epoch 22/29
# 89/89 [==============================] - 0s 4ms/step - loss: -237067.3750 - binary_accuracy: 0.4151 - val_loss: -231223.9688 - val_binary_accuracy: 0.4118
# Epoch 23/29
# 89/89 [==============================] - 0s 4ms/step - loss: -257686.0312 - binary_accuracy: 0.4129 - val_loss: -250884.0312 - val_binary_accuracy: 0.4161
# Epoch 24/29
# 89/89 [==============================] - 0s 4ms/step - loss: -279006.6875 - binary_accuracy: 0.4127 - val_loss: -271159.7500 - val_binary_accuracy: 0.4174
# Epoch 25/29
# 89/89 [==============================] - 0s 4ms/step - loss: -301060.4062 - binary_accuracy: 0.4144 - val_loss: -291654.1562 - val_binary_accuracy: 0.4111
# Epoch 26/29
# 89/89 [==============================] - 0s 4ms/step - loss: -323606.0000 - binary_accuracy: 0.4130 - val_loss: -313210.4375 - val_binary_accuracy: 0.4149
# Epoch 27/29
# 89/89 [==============================] - 0s 4ms/step - loss: -346836.0312 - binary_accuracy: 0.4140 - val_loss: -335361.1875 - val_binary_accuracy: 0.4143
# Epoch 28/29
# 89/89 [==============================] - 0s 4ms/step - loss: -370799.8125 - binary_accuracy: 0.4165 - val_loss: -357850.0625 - val_binary_accuracy: 0.4143
# Epoch 29/29
# 89/89 [==============================] - 0s 4ms/step - loss: -395304.0000 - binary_accuracy: 0.4146 - val_loss: -381143.1875 - val_binary_accuracy: 0.4161
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3820050946785432
# 106/106 [==============================] - 0s 3ms/step - loss: -631951.1250 - binary_accuracy: 0.1564
# 119/119 [==============================] - 0s 2ms/step
# Epoch 1/29
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 89/89 [==============================] - 1s 5ms/step - loss: -117.5894 - binary_accuracy: 0.4039 - val_loss: -367.1731 - val_binary_accuracy: 0.4186
# Epoch 2/29
# 89/89 [==============================] - 0s 4ms/step - loss: -1050.7383 - binary_accuracy: 0.4160 - val_loss: -1859.8152 - val_binary_accuracy: 0.4180
# Epoch 3/29
# 89/89 [==============================] - 0s 4ms/step - loss: -3290.0588 - binary_accuracy: 0.4111 - val_loss: -4628.0747 - val_binary_accuracy: 0.4212
# Epoch 4/29
# 89/89 [==============================] - 0s 4ms/step - loss: -6786.1445 - binary_accuracy: 0.4115 - val_loss: -8545.9678 - val_binary_accuracy: 0.4149
# Epoch 5/29
# 89/89 [==============================] - 0s 4ms/step - loss: -11546.5459 - binary_accuracy: 0.4121 - val_loss: -13621.1963 - val_binary_accuracy: 0.4105
# Epoch 6/29
# 89/89 [==============================] - 0s 4ms/step - loss: -17528.9395 - binary_accuracy: 0.4082 - val_loss: -19845.5059 - val_binary_accuracy: 0.4105
# Epoch 7/29
# 89/89 [==============================] - 0s 4ms/step - loss: -24637.0332 - binary_accuracy: 0.4124 - val_loss: -27110.7656 - val_binary_accuracy: 0.4124
# Epoch 8/29
# 89/89 [==============================] - 0s 4ms/step - loss: -32837.3203 - binary_accuracy: 0.4105 - val_loss: -35407.6562 - val_binary_accuracy: 0.4136
# Epoch 9/29
# 89/89 [==============================] - 0s 4ms/step - loss: -42120.3867 - binary_accuracy: 0.4116 - val_loss: -44717.9766 - val_binary_accuracy: 0.4124
# Epoch 10/29
# 89/89 [==============================] - 0s 4ms/step - loss: -52529.0547 - binary_accuracy: 0.4121 - val_loss: -54934.9023 - val_binary_accuracy: 0.4105
# Epoch 11/29
# 89/89 [==============================] - 0s 5ms/step - loss: -63964.5508 - binary_accuracy: 0.4108 - val_loss: -66364.6328 - val_binary_accuracy: 0.4124
# Epoch 12/29
# 89/89 [==============================] - 0s 5ms/step - loss: -76458.2188 - binary_accuracy: 0.4107 - val_loss: -78591.3203 - val_binary_accuracy: 0.4124
# Epoch 13/29
# 89/89 [==============================] - 0s 5ms/step - loss: -89867.2734 - binary_accuracy: 0.4129 - val_loss: -91833.5703 - val_binary_accuracy: 0.4118
# Epoch 14/29
# 89/89 [==============================] - 0s 5ms/step - loss: -104176.9141 - binary_accuracy: 0.4111 - val_loss: -105723.6016 - val_binary_accuracy: 0.4136
# Epoch 15/29
# 89/89 [==============================] - 0s 5ms/step - loss: -119374.5859 - binary_accuracy: 0.4116 - val_loss: -120401.5000 - val_binary_accuracy: 0.4130
# Epoch 16/29
# 89/89 [==============================] - 0s 5ms/step - loss: -135515.6406 - binary_accuracy: 0.4130 - val_loss: -136174.3438 - val_binary_accuracy: 0.4118
# Epoch 17/29
# 89/89 [==============================] - 0s 6ms/step - loss: -152542.2812 - binary_accuracy: 0.4121 - val_loss: -152566.8750 - val_binary_accuracy: 0.4136
# Epoch 18/29
# 89/89 [==============================] - 0s 5ms/step - loss: -170350.8750 - binary_accuracy: 0.4124 - val_loss: -169957.4531 - val_binary_accuracy: 0.4124
# Epoch 19/29
# 89/89 [==============================] - 0s 5ms/step - loss: -189027.1875 - binary_accuracy: 0.4147 - val_loss: -188022.4844 - val_binary_accuracy: 0.4124
# Epoch 20/29
# 89/89 [==============================] - 0s 4ms/step - loss: -208374.8281 - binary_accuracy: 0.4119 - val_loss: -207020.0938 - val_binary_accuracy: 0.4130
# Epoch 21/29
# 89/89 [==============================] - 0s 4ms/step - loss: -228562.4062 - binary_accuracy: 0.4127 - val_loss: -226126.7344 - val_binary_accuracy: 0.4111
# Epoch 22/29
# 89/89 [==============================] - 0s 4ms/step - loss: -249476.5469 - binary_accuracy: 0.4158 - val_loss: -246185.1719 - val_binary_accuracy: 0.4130
# Epoch 23/29
# 89/89 [==============================] - 0s 4ms/step - loss: -271122.2500 - binary_accuracy: 0.4160 - val_loss: -267366.8125 - val_binary_accuracy: 0.4118
# Epoch 24/29
# 89/89 [==============================] - 0s 4ms/step - loss: -293592.2500 - binary_accuracy: 0.4157 - val_loss: -288580.5312 - val_binary_accuracy: 0.4118
# Epoch 25/29
# 89/89 [==============================] - 0s 4ms/step - loss: -316605.1250 - binary_accuracy: 0.4135 - val_loss: -311126.5000 - val_binary_accuracy: 0.4161
# Epoch 26/29
# 89/89 [==============================] - 0s 4ms/step - loss: -340575.3438 - binary_accuracy: 0.4154 - val_loss: -333566.5000 - val_binary_accuracy: 0.4124
# Epoch 27/29
# 89/89 [==============================] - 0s 4ms/step - loss: -365096.7188 - binary_accuracy: 0.4152 - val_loss: -357676.9062 - val_binary_accuracy: 0.4155
# Epoch 28/29
# 89/89 [==============================] - 0s 4ms/step - loss: -390575.9375 - binary_accuracy: 0.4151 - val_loss: -381681.9062 - val_binary_accuracy: 0.4155
# Epoch 29/29
# 89/89 [==============================] - 0s 4ms/step - loss: -416625.4062 - binary_accuracy: 0.4166 - val_loss: -406884.0938 - val_binary_accuracy: 0.4186
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.39020098685845195
# 106/106 [==============================] - 0s 3ms/step - loss: 332749.1250 - binary_accuracy: 0.5380
# 119/119 [==============================] - 0s 2ms/step
# Epoch 1/29
# 89/89 [==============================] - 1s 5ms/step - loss: -112.8620 - binary_accuracy: 0.4039 - val_loss: -367.7840 - val_binary_accuracy: 0.4180
# Epoch 2/29
# 89/89 [==============================] - 0s 4ms/step - loss: -1066.9482 - binary_accuracy: 0.4107 - val_loss: -1871.6487 - val_binary_accuracy: 0.4218
# Epoch 3/29
# 89/89 [==============================] - 0s 4ms/step - loss: -3366.8169 - binary_accuracy: 0.4135 - val_loss: -4708.8301 - val_binary_accuracy: 0.4268
# Epoch 4/29
# 89/89 [==============================] - 0s 4ms/step - loss: -7007.2964 - binary_accuracy: 0.4118 - val_loss: -8757.3604 - val_binary_accuracy: 0.4080
# Epoch 5/29
# 89/89 [==============================] - 0s 4ms/step - loss: -11954.9854 - binary_accuracy: 0.4104 - val_loss: -13950.0547 - val_binary_accuracy: 0.4193
# Epoch 6/29
# 89/89 [==============================] - 0s 4ms/step - loss: -18095.9570 - binary_accuracy: 0.4121 - val_loss: -20351.2324 - val_binary_accuracy: 0.4124
# Epoch 7/29
# 89/89 [==============================] - 0s 4ms/step - loss: -25385.0566 - binary_accuracy: 0.4116 - val_loss: -27661.2520 - val_binary_accuracy: 0.4124
# Epoch 8/29
# 89/89 [==============================] - 0s 5ms/step - loss: -33805.9062 - binary_accuracy: 0.4105 - val_loss: -36176.6094 - val_binary_accuracy: 0.4105
# Epoch 9/29
# 89/89 [==============================] - 0s 5ms/step - loss: -43379.6641 - binary_accuracy: 0.4097 - val_loss: -45702.0469 - val_binary_accuracy: 0.4111
# Epoch 10/29
# 89/89 [==============================] - 0s 5ms/step - loss: -53981.7305 - binary_accuracy: 0.4105 - val_loss: -56141.2812 - val_binary_accuracy: 0.4111
# Epoch 11/29
# 89/89 [==============================] - 1s 6ms/step - loss: -65629.3750 - binary_accuracy: 0.4104 - val_loss: -67612.9688 - val_binary_accuracy: 0.4111
# Epoch 12/29
# 89/89 [==============================] - 0s 5ms/step - loss: -78272.8672 - binary_accuracy: 0.4121 - val_loss: -79932.4297 - val_binary_accuracy: 0.4124
# Epoch 13/29
# 89/89 [==============================] - 1s 7ms/step - loss: -91869.2734 - binary_accuracy: 0.4119 - val_loss: -93209.5547 - val_binary_accuracy: 0.4136
# Epoch 14/29
# 89/89 [==============================] - 1s 7ms/step - loss: -106343.7500 - binary_accuracy: 0.4132 - val_loss: -107252.9375 - val_binary_accuracy: 0.4118
# Epoch 15/29
# 89/89 [==============================] - 0s 5ms/step - loss: -121762.5547 - binary_accuracy: 0.4122 - val_loss: -121851.6328 - val_binary_accuracy: 0.4124
# Epoch 16/29
# 89/89 [==============================] - 0s 4ms/step - loss: -137981.9844 - binary_accuracy: 0.4132 - val_loss: -137747.4062 - val_binary_accuracy: 0.4118
# Epoch 17/29
# 89/89 [==============================] - 0s 4ms/step - loss: -155154.4375 - binary_accuracy: 0.4138 - val_loss: -154364.5625 - val_binary_accuracy: 0.4118
# Epoch 18/29
# 89/89 [==============================] - 0s 4ms/step - loss: -173163.5469 - binary_accuracy: 0.4115 - val_loss: -171331.3594 - val_binary_accuracy: 0.4130
# Epoch 19/29
# 89/89 [==============================] - 0s 4ms/step - loss: -191872.4844 - binary_accuracy: 0.4121 - val_loss: -189527.6250 - val_binary_accuracy: 0.4149
# Epoch 20/29
# 89/89 [==============================] - 0s 4ms/step - loss: -211443.6406 - binary_accuracy: 0.4141 - val_loss: -208271.9375 - val_binary_accuracy: 0.4130
# Epoch 21/29
# 89/89 [==============================] - 0s 4ms/step - loss: -231824.9062 - binary_accuracy: 0.4151 - val_loss: -227621.3594 - val_binary_accuracy: 0.4105
# Epoch 22/29
# 89/89 [==============================] - 0s 4ms/step - loss: -252942.2188 - binary_accuracy: 0.4135 - val_loss: -248089.0938 - val_binary_accuracy: 0.4124
# Epoch 23/29
# 89/89 [==============================] - 0s 4ms/step - loss: -274911.1250 - binary_accuracy: 0.4110 - val_loss: -268851.4375 - val_binary_accuracy: 0.4168
# Epoch 24/29
# 89/89 [==============================] - 0s 4ms/step - loss: -297558.7812 - binary_accuracy: 0.4141 - val_loss: -290743.1250 - val_binary_accuracy: 0.4130
# Epoch 25/29
# 89/89 [==============================] - 0s 4ms/step - loss: -320974.3125 - binary_accuracy: 0.4113 - val_loss: -313251.4688 - val_binary_accuracy: 0.4161
# Epoch 26/29
# 89/89 [==============================] - 0s 4ms/step - loss: -345074.3125 - binary_accuracy: 0.4141 - val_loss: -336096.1562 - val_binary_accuracy: 0.4149
# Epoch 27/29
# 89/89 [==============================] - 0s 4ms/step - loss: -369828.9375 - binary_accuracy: 0.4163 - val_loss: -359633.9688 - val_binary_accuracy: 0.4136
# Epoch 28/29
# 89/89 [==============================] - 0s 4ms/step - loss: -395266.8125 - binary_accuracy: 0.4121 - val_loss: -383479.7500 - val_binary_accuracy: 0.4161
# Epoch 29/29
# 89/89 [==============================] - 0s 4ms/step - loss: -421208.8438 - binary_accuracy: 0.4144 - val_loss: -408691.4688 - val_binary_accuracy: 0.4174
# 357/357 [==============================] - 1s 2ms/step
# Recall: 0.3901925671673498
# 106/106 [==============================] - 0s 3ms/step - loss: 47421.6758 - binary_accuracy: 0.6477
# 119/119 [==============================] - 0s 1ms/step
# Melhores hiperparâmetros: {'batch_size': 126, 'learning_rate': 0.01, 'num_epochs': 10, 'num_hidden_units': 111}
# Melhor Recall: 0.28871780160624544
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 2.4.1 - RNN com os Melhores Hiperparâmetros

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
import tensorflow as tf

# Dados de entrada e rótulos
X_test = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
y_test = np.array(dfrnn_balanced['sentimento2'])

# Divisão em conjunto de treinamento e teste
X_train, X_val, y_train, y_val = train_test_split(X_test, y_test, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Normalização dos dados
X_train_mean = X_train.mean(axis=0)
X_train_std = X_train.std(axis=0)
X_train = (X_train - X_train_mean) / X_train_std
X_val = (X_val - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# Função para criar o modelo RNN com hiperparâmetros otimizados
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(units=125, activation='relu'),
        tf.keras.layers.Dense(units=1, activation='sigmoid')
    ])

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001),
                  loss=tf.losses.BinaryCrossentropy(),
                  metrics=[tf.metrics.BinaryAccuracy()])

    model.fit(X_train, y_train, epochs=14, batch_size=47,
              validation_data=(X_val, y_val))

    return model

# Criação do modelo com hiperparâmetros otimizados
best_model = create_model()

# Previsões do modelo com hiperparâmetros otimizados
y_pred_best_model = best_model.predict(X_test)
y_pred_best_model = np.round(y_pred_best_model).flatten()

# Cálculo do recall geral
recall_best_model = recall_score(y_test, y_pred_best_model, average='weighted')

RNNRecall = recall_best_model

print('Recall:', recall_best_model)
# Out:
# Epoch 1/14
# 136/136 [==============================] - 1s 4ms/step - loss: -3.7510 - binary_accuracy: 0.3986 - val_loss: -9.3404 - val_binary_accuracy: 0.4155
# Epoch 2/14
# 136/136 [==============================] - 0s 3ms/step - loss: -22.7753 - binary_accuracy: 0.4099 - val_loss: -36.9204 - val_binary_accuracy: 0.4193
# Epoch 3/14
# 136/136 [==============================] - 0s 3ms/step - loss: -64.0433 - binary_accuracy: 0.4124 - val_loss: -86.4815 - val_binary_accuracy: 0.4212
# Epoch 4/14
# 136/136 [==============================] - 0s 3ms/step - loss: -129.8826 - binary_accuracy: 0.4161 - val_loss: -160.5403 - val_binary_accuracy: 0.4237
# Epoch 5/14
# 136/136 [==============================] - 0s 4ms/step - loss: -220.7150 - binary_accuracy: 0.4168 - val_loss: -255.5498 - val_binary_accuracy: 0.4224
# Epoch 6/14
# 136/136 [==============================] - 0s 3ms/step - loss: -334.9346 - binary_accuracy: 0.4138 - val_loss: -373.3757 - val_binary_accuracy: 0.4230
# Epoch 7/14
# 136/136 [==============================] - 0s 3ms/step - loss: -471.4198 - binary_accuracy: 0.4151 - val_loss: -511.3800 - val_binary_accuracy: 0.4155
# Epoch 8/14
# 136/136 [==============================] - 0s 3ms/step - loss: -628.4023 - binary_accuracy: 0.4116 - val_loss: -667.4541 - val_binary_accuracy: 0.4180
# Epoch 9/14
# 136/136 [==============================] - 0s 3ms/step - loss: -805.9258 - binary_accuracy: 0.4122 - val_loss: -841.3461 - val_binary_accuracy: 0.4149
# Epoch 10/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1002.6459 - binary_accuracy: 0.4122 - val_loss: -1037.6146 - val_binary_accuracy: 0.4136
# Epoch 11/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1219.1365 - binary_accuracy: 0.4107 - val_loss: -1243.9346 - val_binary_accuracy: 0.4155
# Epoch 12/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1451.5212 - binary_accuracy: 0.4124 - val_loss: -1470.7756 - val_binary_accuracy: 0.4155
# Epoch 13/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1700.4803 - binary_accuracy: 0.4127 - val_loss: -1708.6996 - val_binary_accuracy: 0.4143
# Epoch 14/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1964.5833 - binary_accuracy: 0.4094 - val_loss: -1965.5400 - val_binary_accuracy: 0.4149
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.41681997371879104

# %% [markdown]
# ### 2.5 - Salvando CSV do resultado da Modelagem de Redes Neurais Recorrentes (RNN)

# %%
# Criar DataFrame com as previsões
df_predictions = pd.DataFrame({'Sentimento Real': y_test, 'Sentimento Previsto': y_pred_best_model})

# Salvar o DataFrame em um arquivo CSV
df_predictions.to_csv('predictionsRNN3SB.csv', index=False)
print("Salvo com sucesso")
# Out:
# Salvo com sucesso

# %% [markdown]
# ### 2.6 - Exportar o Modelo de Redes Neurais Recorrentes (RNN) com pickle

# %%
#biblioteca para exportação dos modelos
import pickle

# Salvar o modelo RNN em um arquivo PKL
with open('/content/drive/MyDrive/PROJETO BTG/modelo_rnn.pkl', 'wb') as arquivo:
    pickle.dump(best_model, arquivo)

# %% [markdown]
# ## RNN - Três categorias e com balanceamento

# %% [markdown]
# ### 2.2 - Teste da Função

# %% [markdown]
# **USANDO TRÊS CATEGORIAS COM BALANCEAMENTO DE DADOS**

# %%
# Balanceamento dos dados
df_negative = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

df_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)
df_neutral_resampled = resample(df_neutral, replace=True, n_samples=len(df_negative), random_state=42)

dfrnn_balanced = pd.concat([df_positive_resampled, df_negative, df_neutral_resampled])

# Separando os dados de teste em X_test e y_test (balanceados)
X_test = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
y_test = np.array(dfrnn_balanced['sentimento2'])

model, y_test, y_pred = classification_rnn(X_test, y_test)
# Out:
# Epoch 1/10
# 71/71 [==============================] - 2s 3ms/step - loss: 1.0505 - accuracy: 0.4573
# Epoch 2/10
# 71/71 [==============================] - 0s 3ms/step - loss: 0.9794 - accuracy: 0.5603
# Epoch 3/10
# 71/71 [==============================] - 0s 3ms/step - loss: 0.9581 - accuracy: 0.5744
# Epoch 4/10
# 71/71 [==============================] - 0s 4ms/step - loss: 0.9390 - accuracy: 0.5889
# Epoch 5/10
# 71/71 [==============================] - 0s 3ms/step - loss: 0.9266 - accuracy: 0.5885
# Epoch 6/10
# 71/71 [==============================] - 0s 4ms/step - loss: 0.9184 - accuracy: 0.5968
# Epoch 7/10
# 71/71 [==============================] - 0s 3ms/step - loss: 0.9093 - accuracy: 0.5986
# Epoch 8/10
# 71/71 [==============================] - 0s 3ms/step - loss: 0.9061 - accuracy: 0.6026
# Epoch 9/10
# 71/71 [==============================] - 0s 4ms/step - loss: 0.8996 - accuracy: 0.6096
# Epoch 10/10
# 71/71 [==============================] - 0s 5ms/step - loss: 0.8917 - accuracy: 0.6171
# 71/71 [==============================] - 1s 4ms/step - loss: 0.8861 - accuracy: 0.6052
# Acurácia: 60.52%
# 71/71 [==============================] - 1s 3ms/step
# Recall: 60.72%

# %% [markdown]
# ### 2.3 - Visualização da Matriz de Confusão de Redes Neurais Recorrentes (RNN)

# %% [markdown]
# **USANDO TRÊS CATEGORIAS COM BALANCEAMENTO DE DADOS - MATRIZ DE CONFUSÃO**

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Previsões no conjunto de teste
y_test = y_test.astype(int)
y_pred = y_pred.astype(int)

# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Definição dos rótulos das classes
class_labels = ['POSITIVO', 'NEGATIVO', 'NEUTRO']

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusão da Modelagem de Redes Neurais Recorrentes (RNN)')
plt.colorbar()
tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels)
plt.yticks(tick_marks, class_labels)

# Adição dos valores numéricos na matriz
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'), ha='center', va='center',
             color='white' if cm[i, j] > thresh else 'black')

plt.xlabel('Previsão')
plt.ylabel('Valor Real')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4 - Salvando CSV do resultado da Modelagem de Redes Neurais Recorrentes (RNN)

# %%
"""
# Criar DataFrame com as previsões
df_predictions = pd.DataFrame({'Sentimento Real': y_test, 'Sentimento Previsto': y_pred})

# Salvar o DataFrame em um arquivo CSV
df_predictions.to_csv('predictionsRNN3CB.csv', index=False)
print("Salvo com sucesso")
"""
# Out:
# '\n# Criar DataFrame com as previsões\ndf_predictions = pd.DataFrame({\'Sentimento Real\': y_test, \'Sentimento Previsto\': y_pred})\n\n# Salvar o DataFrame em um arquivo CSV\ndf_predictions.to_csv(\'predictionsRNN3CB.csv\', index=False)\nprint("Salvo com sucesso")\n'

# %% [markdown]
# # Atividade 3 - Implementação do Embedding Layer com Word2Vec

# %% [markdown]
# O modelo de aprendizado profundo utilizado, que inclui as camadas de incorporação (Embedding), convolução unidimensional (Conv1D), pooling máximo global (GlobalMaxPooling1D) e camadas densas (Dense), traz benefícios significativos para o Processamento de Linguagem Natural (PLN).
#
# Essas camadas são projetadas para lidar especificamente com dados textuais e têm vantagens específicas:
#
# A camada de incorporação (Embedding) permite a representação eficiente de palavras em vetores densos de tamanho fixo, capturando relações semânticas e contextuais entre as palavras. Isso é fundamental para o PLN, pois possibilita que o modelo compreenda melhor as similaridades e diferenças entre as palavras em um texto, melhorando a capacidade de generalização e entendimento do contexto.
#
# A camada convolucional unidimensional (Conv1D) é capaz de identificar padrões locais em sequências de palavras, como combinações específicas de palavras ou frases. Isso permite que o modelo extraia características relevantes dos dados textuais, capturando informações importantes em diferentes níveis de granularidade. A convolução unidimensional é especialmente útil para identificar características importantes em trechos curtos de texto.
#
# A camada de pooling máximo global (GlobalMaxPooling1D) reduz a dimensionalidade dos recursos extraídos pela camada convolucional, mantendo as características mais importantes. Essa operação de pooling preserva as informações mais salientes, tornando o modelo mais robusto a variações na posição das características dentro das sequências. Além disso, o pooling máximo global permite que o modelo trabalhe com sequências de comprimentos variáveis, já que retorna um vetor de características fixo independentemente do tamanho da sequência original.
#
# As camadas densas (Dense) são responsáveis por aprender padrões mais complexos nos recursos extraídos pelas camadas anteriores. Elas permitem que o modelo capture relações não lineares entre as características, aumentando a capacidade de representação e aprendizado. As camadas densas são cruciais para a tomada de decisões finais do modelo, mapeando os recursos em probabilidades de pertencer a cada classe e permitindo a classificação adequada dos dados textuais.
#
# Portanto, o uso dessas camadas no modelo de aprendizado profundo para PLN traz ganhos significativos, permitindo que o modelo compreenda melhor o contexto, identifique padrões relevantes nas sequências de palavras e capture informações importantes para a classificação precisa dos dados textuais. Essa arquitetura é especialmente útil para tarefas como classificação de sentimentos, análise de sentimento, categorização de texto e muitas outras aplicações de PLN.
#
# **Referências**
#
# (1) What Are Embedding Layers in Neural Networks? - Baeldung.
#
# https://www.baeldung.com/cs/neural-nets-embedding-layers.
#
# (2) Understanding Embedding Layer in Keras | by sawan saxena - Medium.
#
# https://medium.com/analytics-vidhya/understanding-embedding-layer-in-keras-bbe3ff1327ce.
#
# (3) Embedding layer - Keras.
#
# https://keras.io/api/layers/core_layers/embedding/.

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from keras.preprocessing.text import Tokenizer

# %% [markdown]
# ## 3.1 - Definição da Função

# %%
def classification_embedding_layer(X, y):
  # Separar em conjuntos de treinamento e teste
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

  # Tokenizar os dados
  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(X_train)
  X_train = tokenizer.texts_to_sequences(X_train)
  X_test = tokenizer.texts_to_sequences(X_test)

  # Obter o tamanho do vocabulário
  vocab_size = len(tokenizer.word_index) + 1

  # Padding para ter sequências com o mesmo comprimento
  max_length = 50
  X_train = pad_sequences(X_train, maxlen=max_length)
  X_test = pad_sequences(X_test, maxlen=max_length)

  # Criar o modelo
  model = Sequential()
  model.add(Embedding(input_dim=vocab_size, output_dim=50, input_length=max_length))
  model.add(LSTM(128))
  model.add(Dense(3, activation='softmax'))

  # Compilar o modelo
  model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

  # Treinar o modelo
  model.fit(X_train, y_train, epochs=10, batch_size=32)

  # Fazer previsões no conjunto de teste
  y_pred = model.predict(X_test)
  y_pred = np.argmax(y_pred, axis=1)

  # Printar o relatório de classificação (incluindo recall)
  labels = ['Negative', 'Positive', 'Neutral']

  # Avaliar a precisão do modelo
  _, accuracy = model.evaluate(X_test, y_test)
  print('Acurácia: %.2f%%' % (accuracy * 100))

  report = classification_report(y_test, y_pred, target_names=labels)
  print(report)

  return model, y_test, y_pred

# %% [markdown]
# ## Embedding Layer - Duas categorias e com balanceamento

# %% [markdown]
# ### 3.2 - Teste de Função

# %%
"""
# Balanceamento dos dados
df_positive = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 0]
df_negative = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 1]

df_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)

dfrnn_balanced = pd.concat([df_positive_resampled, df_negative])

# Inverter a codificação das classes
dfrnn_balanced['sentimento'] = dfrnn_balanced['sentimento'].map({1: 0, 0: 1})

# Separando os dados em X e y (balanceados)
X = np.array(dfrnn_balanced['Frase'])
Y = np.array(dfrnn_balanced['sentimento'])

# Definição dos hiperparâmetros
num_epochs = 20
batch_size = 64
learning_rate = 0.001
num_hidden_units = 128
embedding_dim = 50

loss, accuracy, y_pred, y_test, X_test = classification_embedding_layer(X, Y, num_epochs, batch_size, learning_rate, num_hidden_units, embedding_dim)
"""
# Out:
# "\n# Balanceamento dos dados\ndf_positive = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 0]\ndf_negative = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 1]\n\ndf_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)\n\ndfrnn_balanced = pd.concat([df_positive_resampled, df_negative])\n\n# Inverter a codificação das classes\ndfrnn_balanced['sentimento'] = dfrnn_balanced['sentimento'].map({1: 0, 0: 1})\n\n# Separando os dados em X e y (balanceados)\nX = np.array(dfrnn_balanced['Frase'])\nY = np.array(dfrnn_balanced['sentimento'])\n\n# Definição dos hiperparâmetros\nnum_epochs = 20\nbatch_size = 64\nlearning_rate = 0.001\nnum_hidden_units = 128\nembedding_dim = 50\n\nloss, accuracy, y_pred, y_test, X_test = classification_embedding_layer(X, Y, num_epochs, batch_size, learning_rate, num_hidden_units, embedding_dim)\n"

# %% [markdown]
# ### 14.3 - Visualização da Matriz de Confusão do Embedding Layer

# %%
"""
# Calcular a matriz de confusão
confusion = confusion_matrix(y_pred,y_test)

print("Matriz de Confusão:")
print(confusion)
"""
# Out:
# '\n# Calcular a matriz de confusão\nconfusion = confusion_matrix(y_pred,y_test)\n\nprint("Matriz de Confusão:")\nprint(confusion)\n'

# %% [markdown]
# A matriz de confusão que você obteve mostra os seguintes resultados:
#
# - Verdadeiros Positivos (TP): 127
# - Falsos Positivos (FP): 38
# - Falsos Negativos (FN): 25
# - Verdadeiros Negativos (TN): 141

# %%
"""
# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Definição dos rótulos das classes
class_labels = ['POSITIVO', 'NEGATIVO']

# Criação da matriz de confusão personalizada
cm_custom = np.array([[cm[1, 1], cm[1, 0]], [cm[0, 1], cm[0, 0]]])

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(cm_custom, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusão do Embedding Layer com Word2Vec')
plt.colorbar()
tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels)
plt.yticks(tick_marks, class_labels)

# Adição dos valores numéricos na matriz
thresh = cm_custom.max() / 2.0
for i, j in np.ndindex(cm_custom.shape):
    plt.text(j, i, format(cm_custom[i, j], 'd'), ha='center', va='center',
             color='white' if cm_custom[i, j] > thresh else 'black')

plt.xlabel('Previsão')
plt.ylabel('Valor Real')
plt.tight_layout()
plt.show()
"""
# Out:
# "\n# Cálculo da matriz de confusão\ncm = confusion_matrix(y_test, y_pred)\n\n# Definição dos rótulos das classes\nclass_labels = ['POSITIVO', 'NEGATIVO']\n\n# Criação da matriz de confusão personalizada\ncm_custom = np.array([[cm[1, 1], cm[1, 0]], [cm[0, 1], cm[0, 0]]])\n\n# Plot da matriz de confusão\nplt.figure(figsize=(8, 6))\nplt.imshow(cm_custom, interpolation='nearest', cmap=plt.cm.Blues)\nplt.title('Matriz de Confusão do Embedding Layer com Word2Vec')\nplt.colorbar()\ntick_marks = np.arange(len(class_labels))\nplt.xticks(tick_marks, class_labels)\nplt.yticks(tick_marks, class_labels)\n\n# Adição dos valores numéricos na matriz\nthresh = cm_custom.max() / 2.0\nfor i, j in np.ndindex(cm_custom.shape):\n    plt.text(j, i, format(cm_custom[i, j], 'd'), ha='center', va='center',\n             color='white' if cm_custom[i, j] > thresh else 'black')\n\nplt.xlabel('Previsão')\nplt.ylabel('Valor Real')\nplt.tight_layout()\nplt.show()\n"

# %% [markdown]
# ### 3.4 - Salvando CSV do resultado Embedding Layer com Word2Vec

# %%
"""
import pandas as pd

# Converter X_test em lista e y_pred em array unidimensional
X_test_list = X_test.tolist()
y_pred_flat = y_pred.flatten()

# Criar um DataFrame com as previsões
df_resultEL = pd.DataFrame({'Texto': X_test_list, 'Sentimento_Predito': y_pred_flat})

# Salvar o DataFrame em um arquivo CSV
df_resultEL.to_csv('/content/drive/MyDrive/PROJETO BTG/resultados.csv', index=False)
print("Salvo com sucesso")
"""
# Out:
# '\nimport pandas as pd\n\n# Converter X_test em lista e y_pred em array unidimensional\nX_test_list = X_test.tolist()\ny_pred_flat = y_pred.flatten()\n\n# Criar um DataFrame com as previsões\ndf_resultEL = pd.DataFrame({\'Texto\': X_test_list, \'Sentimento_Predito\': y_pred_flat})\n\n# Salvar o DataFrame em um arquivo CSV\ndf_resultEL.to_csv(\'/content/drive/MyDrive/PROJETO BTG/resultados.csv\', index=False)\nprint("Salvo com sucesso")\n'

# %%
# df_resultEL

# %% [markdown]
# ## Embedding Layer - Três categorias e sem balanceamento

# %% [markdown]
# ### 3.2 - Teste de Função

# %%
# Carregar os dados
df_negative = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_positive, df_negative, df_neutral])

# Separar os dados em X e y (balanceados)
X = dfrnn_balanced['Frase'].values
y = dfrnn_balanced['sentimento2'].values

model, y_test, y_pred = classification_embedding_layer(X, y)
# Out:
# Epoch 1/10
# 250/250 [==============================] - 38s 144ms/step - loss: 0.8799 - accuracy: 0.5892
# Epoch 2/10
# 250/250 [==============================] - 20s 80ms/step - loss: 0.4914 - accuracy: 0.8065
# Epoch 3/10
# 250/250 [==============================] - 12s 46ms/step - loss: 0.2617 - accuracy: 0.9060
# Epoch 4/10
# 250/250 [==============================] - 6s 25ms/step - loss: 0.1607 - accuracy: 0.9401
# Epoch 5/10
# 250/250 [==============================] - 4s 17ms/step - loss: 0.1141 - accuracy: 0.9597
# Epoch 6/10
# 250/250 [==============================] - 6s 26ms/step - loss: 0.0907 - accuracy: 0.9691
# Epoch 7/10
# 250/250 [==============================] - 3s 11ms/step - loss: 0.0769 - accuracy: 0.9743
# Epoch 8/10
# 250/250 [==============================] - 3s 12ms/step - loss: 0.0665 - accuracy: 0.9783
# Epoch 9/10
# 250/250 [==============================] - 3s 14ms/step - loss: 0.0611 - accuracy: 0.9795
# Epoch 10/10
# 250/250 [==============================] - 3s 11ms/step - loss: 0.0576 - accuracy: 0.9804
# 108/108 [==============================] - 1s 3ms/step
# 108/108 [==============================] - 1s 5ms/step - loss: 1.4159 - accuracy: 0.6870
# Acurácia: 68.70%
#               precision    recall  f1-score   support
#
#     Negative       0.65      0.64      0.64       743
#     Positive       0.73      0.68      0.70      1380
#      Neutral       0.66      0.73      0.69      1302
#
#     accuracy                           0.69      3425
#    macro avg       0.68      0.68      0.68      3425
# weighted avg       0.69      0.69      0.69      3425

# %% [markdown]
# ### 3.3 - Visualização da Matriz de Confusão do Embedding Layer

# %%
# Criar matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Printar a matriz de confusão
labels = ['NEGATIVO', 'POSITIVO', 'NEUTRO']
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ### 3.4 - Hiperparâmetros com Random Search do Embedding Layer

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import recall_score

def create_model(embedding_dim, vocab_size, max_length):
    # Criação do modelo
    model = Sequential([
        Embedding(vocab_size, embedding_dim, input_length=max_length),
        Conv1D(32, 3, activation='relu'),
        GlobalMaxPooling1D(),
        Dense(units=128, activation='relu'),
        Dense(units=3, activation='softmax')  # Altere o número de unidades para o número de classes
    ])

    # Compilação do modelo
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Dados de entrada
X = dfrnn_balanced['Frase'].values
Y = dfrnn_balanced['sentimento2'].values

# Tokenização
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
X_seq = tokenizer.texts_to_sequences(X)
max_length = max(len(seq) for seq in X_seq)
X_padded = pad_sequences(X_seq, maxlen=max_length)
vocab_size = len(tokenizer.word_index) + 1

# Melhores hiperparâmetros encontrados
best_embedding_dim = 100
best_batch_size = 32

# Criação do modelo com os melhores hiperparâmetros
model = create_model(best_embedding_dim, vocab_size, max_length)

# Treinamento do modelo
model.fit(X_padded, Y, batch_size=best_batch_size, epochs=10, validation_split=0.2)

# Avaliação do modelo
y_pred = model.predict(X_padded)
y_pred = np.argmax(y_pred, axis=1)  # Converter as previsões para as classes numéricas
recall = recall_score(Y, y_pred, average='weighted')

print('Recall:', recall)
# Out:
# Epoch 1/10
# 286/286 [==============================] - 60s 188ms/step - loss: 0.7974 - accuracy: 0.6460 - val_loss: 1.6051 - val_accuracy: 0.3031
# Epoch 2/10
# 286/286 [==============================] - 24s 84ms/step - loss: 0.3562 - accuracy: 0.8721 - val_loss: 1.4739 - val_accuracy: 0.4402
# Epoch 3/10
# 286/286 [==============================] - 19s 68ms/step - loss: 0.1153 - accuracy: 0.9650 - val_loss: 1.7743 - val_accuracy: 0.4661
# Epoch 4/10
# 286/286 [==============================] - 13s 46ms/step - loss: 0.0658 - accuracy: 0.9817 - val_loss: 2.0314 - val_accuracy: 0.4577
# Epoch 5/10
# 286/286 [==============================] - 5s 19ms/step - loss: 0.0514 - accuracy: 0.9863 - val_loss: 2.3228 - val_accuracy: 0.4152
# Epoch 6/10
# 286/286 [==============================] - 8s 27ms/step - loss: 0.0378 - accuracy: 0.9898 - val_loss: 2.3031 - val_accuracy: 0.4008
# Epoch 7/10
# 286/286 [==============================] - 6s 20ms/step - loss: 0.0335 - accuracy: 0.9915 - val_loss: 2.2644 - val_accuracy: 0.4363
# Epoch 8/10
# 286/286 [==============================] - 8s 29ms/step - loss: 0.0320 - accuracy: 0.9918 - val_loss: 2.7567 - val_accuracy: 0.3285
# Epoch 9/10
# 286/286 [==============================] - 4s 13ms/step - loss: 0.0273 - accuracy: 0.9918 - val_loss: 3.0855 - val_accuracy: 0.3487
# Epoch 10/10
# 286/286 [==============================] - 3s 11ms/step - loss: 0.0252 - accuracy: 0.9938 - val_loss: 2.9571 - val_accuracy: 0.3653
# 357/357 [==============================] - 1s 3ms/step
# Recall: 0.8687691633815156

# %% [markdown]
# ### 3.4.1 - Embedding Layer com os Melhores Hiperparâmetros

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import recall_score

def create_model(vocab_size, max_length):
    # Criação do modelo
    model = Sequential([
        Embedding(vocab_size, 100, input_length=max_length),  # Aplicação do melhor hiperparâmetro
        Conv1D(32, 3, activation='relu'),
        GlobalMaxPooling1D(),
        Dense(units=128, activation='relu'),
        Dense(units=1, activation='sigmoid')
    ])

    # Compilação do modelo
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Recall()])

    return model

# Dados de entrada
X = dfrnn_balanced['Frase'].values
Y = dfrnn_balanced['sentimento2'].values

# Tokenização
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
X_seq = tokenizer.texts_to_sequences(X)
max_length = max(len(seq) for seq in X_seq)
X_padded = pad_sequences(X_seq, maxlen=max_length)
vocab_size = len(tokenizer.word_index) + 1

# Criação do modelo com o melhor hiperparâmetro
model = create_model(vocab_size, max_length)

# Treinamento do modelo
model.fit(X_padded, Y, batch_size=32, epochs=10, validation_split=0.2)

# Avaliação do modelo
loss, accuracy, recall = model.evaluate(X_padded, Y)

ELRecall = recall;

print('Recall:', ELRecall)
# Out:
# Epoch 1/10
# 286/286 [==============================] - 39s 132ms/step - loss: -3.0537 - accuracy: 0.5041 - recall: 0.9924 - val_loss: -221.9660 - val_accuracy: 0.0000e+00 - val_recall: 0.9834
# Epoch 2/10
# 286/286 [==============================] - 21s 72ms/step - loss: -852.8340 - accuracy: 0.5440 - recall: 0.9834 - val_loss: -19547.0723 - val_accuracy: 0.0000e+00 - val_recall: 0.9847
# Epoch 3/10
# 286/286 [==============================] - 13s 43ms/step - loss: -11105.5791 - accuracy: 0.5530 - recall: 0.9843 - val_loss: -141712.0312 - val_accuracy: 0.0000e+00 - val_recall: 0.9838
# Epoch 4/10
# 286/286 [==============================] - 10s 34ms/step - loss: -52417.9102 - accuracy: 0.5564 - recall: 0.9853 - val_loss: -512954.0312 - val_accuracy: 0.0000e+00 - val_recall: 0.9842
# Epoch 5/10
# 286/286 [==============================] - 7s 25ms/step - loss: -158991.8438 - accuracy: 0.5558 - recall: 0.9862 - val_loss: -1278172.6250 - val_accuracy: 0.0000e+00 - val_recall: 0.9855
# Epoch 6/10
# 286/286 [==============================] - 7s 26ms/step - loss: -365444.0938 - accuracy: 0.5558 - recall: 0.9873 - val_loss: -2617061.0000 - val_accuracy: 0.0000e+00 - val_recall: 0.9851
# Epoch 7/10
# 286/286 [==============================] - 5s 18ms/step - loss: -714933.6875 - accuracy: 0.5585 - recall: 0.9873 - val_loss: -4786258.5000 - val_accuracy: 0.0000e+00 - val_recall: 0.9864
# Epoch 8/10
# 286/286 [==============================] - 4s 15ms/step - loss: -1246878.1250 - accuracy: 0.5575 - recall: 0.9858 - val_loss: -7864791.0000 - val_accuracy: 0.0000e+00 - val_recall: 0.9869
# Epoch 9/10
# 286/286 [==============================] - 5s 19ms/step - loss: -2001867.2500 - accuracy: 0.5550 - recall: 0.9882 - val_loss: -12102635.0000 - val_accuracy: 0.0000e+00 - val_recall: 0.9860
# Epoch 10/10
# 286/286 [==============================] - 4s 15ms/step - loss: -3033858.7500 - accuracy: 0.5594 - recall: 0.9873 - val_loss: -17809064.0000 - val_accuracy: 0.0000e+00 - val_recall: 0.9869
# 357/357 [==============================] - 1s 3ms/step - loss: -6531024.0000 - accuracy: 0.4565 - recall: 0.9875
# Recall: 0.9875154495239258

# %% [markdown]
# ### 3.5 - Salvando CSV do resultado Embedding Layer com Word2Vec

# %%
"""
# Criar DataFrame com as previsões
df_predictions = pd.DataFrame({'Sentimento Real': y_test, 'Sentimento Previsto': y_pred})

# Salvar o DataFrame em um arquivo CSV
df_predictions.to_csv('predictionsEmbeddingLayer.csv', index=False)
print("Salvo com sucesso")
"""
# Out:
# '\n# Criar DataFrame com as previsões\ndf_predictions = pd.DataFrame({\'Sentimento Real\': y_test, \'Sentimento Previsto\': y_pred})\n\n# Salvar o DataFrame em um arquivo CSV\ndf_predictions.to_csv(\'predictionsEmbeddingLayer.csv\', index=False)\nprint("Salvo com sucesso")\n'

# %% [markdown]
# ### 3.6 - Exportar o Modelo Embedding Layer com pickle

# %%
# Salvar o modelo RNN em um arquivo PKL
with open('/content/drive/MyDrive/PROJETO BTG/modelo_embedding_layer.pkl', 'wb') as arquivo:
    pickle.dump(model, arquivo)

# %% [markdown]
# ## Embedding Layer - Três categorias e com balanceamento

# %% [markdown]
# ### 3.2 - Teste de Função

# %%
# Balanceamento dos dados
df_negative = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

df_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)
df_neutral_resampled = resample(df_neutral, replace=True, n_samples=len(df_negative), random_state=42)

dfrnn_balanced = pd.concat([df_positive_resampled, df_negative, df_neutral_resampled])

# Separar os dados em X e y (balanceados)
X = dfrnn_balanced['Frase'].values
y = dfrnn_balanced['sentimento2'].values

model, y_test, y_pred = classification_embedding_layer(X, y)
# Out:
# Epoch 1/10
# 166/166 [==============================] - 30s 163ms/step - loss: 0.9044 - accuracy: 0.5798
# Epoch 2/10
# 166/166 [==============================] - 17s 104ms/step - loss: 0.4805 - accuracy: 0.8160
# Epoch 3/10
# 166/166 [==============================] - 9s 55ms/step - loss: 0.2385 - accuracy: 0.9149
# Epoch 4/10
# 166/166 [==============================] - 9s 56ms/step - loss: 0.1377 - accuracy: 0.9530
# Epoch 5/10
# 166/166 [==============================] - 7s 40ms/step - loss: 0.0984 - accuracy: 0.9660
# Epoch 6/10
# 166/166 [==============================] - 5s 31ms/step - loss: 0.0877 - accuracy: 0.9706
# Epoch 7/10
# 166/166 [==============================] - 3s 20ms/step - loss: 0.0685 - accuracy: 0.9768
# Epoch 8/10
# 166/166 [==============================] - 3s 18ms/step - loss: 0.0624 - accuracy: 0.9775
# Epoch 9/10
# 166/166 [==============================] - 3s 17ms/step - loss: 0.0537 - accuracy: 0.9798
# Epoch 10/10
# 166/166 [==============================] - 4s 24ms/step - loss: 0.0501 - accuracy: 0.9800
# 71/71 [==============================] - 1s 3ms/step
# 71/71 [==============================] - 1s 3ms/step - loss: 1.2645 - accuracy: 0.7390
# Acurácia: 73.90%
#               precision    recall  f1-score   support
#
#     Negative       0.75      0.75      0.75       742
#     Positive       0.73      0.75      0.74       786
#      Neutral       0.73      0.71      0.72       744
#
#     accuracy                           0.74      2272
#    macro avg       0.74      0.74      0.74      2272
# weighted avg       0.74      0.74      0.74      2272

# %% [markdown]
# ### 3.3 - Visualização da Matriz de Confusão do Embedding Layer

# %%
import seaborn as sns

# Calcular a matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Definição dos rótulos das classes
class_labels = ['POSITIVO', 'NEGATIVO', 'NEUTRO']

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predito')
plt.ylabel('Verdadeiro')
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# ### 3.4 - Salvando CSV do resultado Embedding Layer com Word2Vec

# %%
# df_resultEL

# %% [markdown]
# #Atividade 4 - Modelagem de Naive Bayes

# %% [markdown]
# O algoritmo “Naive Bayes” foi baseado no “Teorema de Bayes”, modelo criado pelo matemático inglê Thomas Bayes (1701 – 1761). Tal modelo realiza uma classificação probabilística de observações, desconsiderando correlações entre features, caracterizando-as em classes pré-definidas. Dessa maneira, realiza a predição de um evento A acontecer dado a ocorrência que um evento B já aconteceu. Ao contrario dos outros modelos que consideram a proximidade grafica entre dois elementos para os atribuir uma classe, o Naive Bayes se baseia inteiramente na formula do "Teorema de Bayes" para fazer as contas que irão atribuir a classe do elemento.
#
# **Referências**
#
# (1) O que é Naive Bayes e como funciona esse algoritmo de classificação.
#
# https://rockcontent.com/br/blog/naive-bayes/.
#
# (2) 1.9. Naive Bayes — scikit-learn 1.2.2 documentation.
#
# https://scikit-learn.org/stable/modules/naive_bayes.html.

# %% [markdown]
# ![Dados Iniciais (1).png](data:image/png;base64,...)

# %% [markdown]
# Fonte da imagem: Autoria Própria

# %% [markdown]
# ## 4.1 - Definição da Função

# %%
# Função de treinamento Naive Bayes
def classification_naive_bayes(X,Y):
    # Divisão do DataFrame em conjuntos de treinamento e teste
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

    # Criação de uma instância do classificador Naive Bayes Gaussiano
    gnb = GaussianNB()

    # Treinamento do classificador utilizando os dados de treinamento
    gnb.fit(X_train, y_train)

    # Previsões nos dados de teste
    y_pred = gnb.predict(X_test)

    # Calculo da precisão do classificador
    accuracy = accuracy_score(y_test, y_pred)

    # Retorno da acurácia, y_test, y_pred
    return accuracy, y_test, y_pred

# %% [markdown]
# ## Naive Bayes - Duas categorias com balanceamento

# %% [markdown]
# ### 4.2 - Teste da Função

# %%
'''
# Balanceamento dos dados
df_positive = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 0]
df_negative = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 1]

df_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)

dfrnn_balanced = pd.concat([df_positive_resampled, df_negative])

# Inverter a codificação das classes
dfrnn_balanced['sentimento'] = dfrnn_balanced['sentimento'].map({1: 0, 0: 1})

# Separando os dados em X e y (balanceados)
X = np.array(dfrnn_balanced.drop(['Frase', 'sentimento'], axis=1))
Y = np.array(dfrnn_balanced['sentimento'])

# Chamada da função com os dados balanceados
accuracy, y_test, y_pred = classification_naive_bayes(X, Y)

# Imprime a acurácia
print(accuracy)
'''
# Out:
# "\n# Balanceamento dos dados\ndf_positive = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 0]\ndf_negative = dfW2Vmodelo[dfW2Vmodelo['sentimento'] == 1]\n\ndf_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)\n\ndfrnn_balanced = pd.concat([df_positive_resampled, df_negative])\n\n# Inverter a codificação das classes\ndfrnn_balanced['sentimento'] = dfrnn_balanced['sentimento'].map({1: 0, 0: 1})\n\n# Separando os dados em X e y (balanceados)\nX = np.array(dfrnn_balanced.drop(['Frase', 'sentimento'], axis=1))\nY = np.array(dfrnn_balanced['sentimento'])\n\n# Chamada da função com os dados balanceados\naccuracy, y_test, y_pred = classification_naive_bayes(X, Y)\n\n# Imprime a acurácia\nprint(accuracy)\n"

# %% [markdown]
# A acurácia foi utilizada para avaliar o desempenho do modelo Naive Bayes. O resultado representa a proporção de instâncias classificadas corretamente em relação ao total de instâncias.

# %% [markdown]
# ### 4.3 - Visualização da Matriz de Confusão da Modelagem de Naive Bayes

# %%
'''
# Cálculo da matriz de confusão
VP = confusion_matrix(y_test, y_pred)[0, 0]
FN = confusion_matrix(y_test, y_pred)[0, 1]
FP = confusion_matrix(y_test, y_pred)[1, 0]
VN = confusion_matrix(y_test, y_pred)[1, 1]

# Criação da matriz de confusão personalizada
custom_cm = np.array([[VP, FN], [FP, VN]])

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(custom_cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusão da Modelagem de Naive Bayes')
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['POSITIVO', 'NEGATIVO'])
plt.yticks(tick_marks, ['POSITIVO', 'NEGATIVO'])

# Adição dos valores numéricos na matriz
thresh = custom_cm.max() / 2.
for i, j in np.ndindex(custom_cm.shape):
    plt.text(j, i, format(custom_cm[i, j], 'd'), ha='center', va='center',
             color='white' if custom_cm[i, j] > thresh else 'black')

plt.xlabel('Previsão')
plt.ylabel('Valor Real')
plt.tight_layout()
plt.show()
'''
# Out:
# "\n# Cálculo da matriz de confusão\nVP = confusion_matrix(y_test, y_pred)[0, 0]\nFN = confusion_matrix(y_test, y_pred)[0, 1]\nFP = confusion_matrix(y_test, y_pred)[1, 0]\nVN = confusion_matrix(y_test, y_pred)[1, 1]\n\n# Criação da matriz de confusão personalizada\ncustom_cm = np.array([[VP, FN], [FP, VN]])\n\n# Plot da matriz de confusão\nplt.figure(figsize=(8, 6))\nplt.imshow(custom_cm, interpolation='nearest', cmap=plt.cm.Blues)\nplt.title('Matriz de Confusão da Modelagem de Naive Bayes')\nplt.colorbar()\ntick_marks = np.arange(2)\nplt.xticks(tick_marks, ['POSITIVO', 'NEGATIVO'])\nplt.yticks(tick_marks, ['POSITIVO', 'NEGATIVO'])\n\n# Adição dos valores numéricos na matriz\nthresh = custom_cm.max() / 2.\nfor i, j in np.ndindex(custom_cm.shape):\n    plt.text(j, i, format(custom_cm[i, j], 'd'), ha='center', va='center',\n             color='white' if custom_cm[i, j] > thresh else 'black')\n\nplt.xlabel('Previsão')\nplt.ylabel('Valor Real')\nplt.tight_layout()\nplt.show()\n"

# %% [markdown]
# ### 4.4 - Salvando CSV do resultado da Modelagem de Naive Bayes

# %%
'''
# Crie um DataFrame com as previsões
df_resultNB = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})
# Salve o DataFrame em um arquivo CSV
df_resultNB.to_csv('/content/drive/MyDrive/PROJETO BTG/resultadoNaiveBayes.csv', index=False)
print('Salvo com sucesso')
'''
# Out:
# "\n# Crie um DataFrame com as previsões\ndf_resultNB = pd.DataFrame({'y_test': y_test, 'y_pred': y_pred})\n# Salve o DataFrame em um arquivo CSV\ndf_resultNB.to_csv('/content/drive/MyDrive/PROJETO BTG/resultadoNaiveBayes.csv', index=False)\nprint('Salvo com sucesso')\n"

# %% [markdown]
# O Naive Bayes é um algoritmo de aprendizado supervisionado que faz uso do Teorema de Bayes para estimar a probabilidade de um exemplo pertencer a cada uma das classes disponíveis. No caso binário, onde temos duas classes (0 e 1), o modelo calcula a probabilidade de um exemplo pertencer à classe 0 e à classe 1.

# %% [markdown]
# ## Naive Bayes - Três categorias sem balanceamento

# %% [markdown]
# ### 4.2 - Teste da Função

# %%
# Balanceamento dos dados
df_negativo = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_negative, df_positive, df_neutral])

# Separando os dados em X e y (balanceados)
X = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
Y = np.array(dfrnn_balanced['sentimento2'])

# Chamada da função com os dados balanceados
accuracy, y_test, y_pred = classification_naive_bayes(X, Y)

# Imprime a acurácia
print(accuracy)
# Out:
# 0.5004379562043796

# %% [markdown]
# A acurácia foi utilizada para avaliar o desempenho do modelo Naive Bayes. O resultado representa a proporção de instâncias classificadas corretamente em relação ao total de instâncias.

# %% [markdown]
# ### 4.3 - Visualização da Matriz de Confusão da Modelagem de Naive Bayes

# %%
# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Plot da matriz de confusão
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

# Configurações do gráfico
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=['Negativo', 'Positivo', 'Neutro'],
       yticklabels=['Negativo', 'Positivo', 'Neutro'],
       title='Matriz de Confusão',
       ylabel='Valor Verdadeiro',
       xlabel='Valor Previsto')

# Adiciona os valores nas células da matriz
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

# Mostra o gráfico
plt.show()

# %% [markdown]
# ### 4.4 - Hiperparâmetros com Random Search do Naive Bayes

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.naive_bayes import GaussianNB
from scipy.stats import uniform
from sklearn.metrics import recall_score

# Função de treinamento Naive Bayes
def classification_naive_bayes(X, Y):
    # Divisão do DataFrame em conjuntos de treinamento e teste
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

    # Definindo os hiperparâmetros a serem otimizados
    param_dist = {'var_smoothing': uniform(1e-20, 1e-2)}  # Intervalo para o hiperparâmetro var_smoothing

    # Criação do classificador Naive Bayes
    clf = GaussianNB()

    # Realização da busca aleatória com validação cruzada
    random_search = RandomizedSearchCV(clf, param_distributions=param_dist, cv=5, n_iter=10, random_state=42)
    random_search.fit(X_train, y_train)

    # Melhores hiperparâmetros encontrados
    best_params = random_search.best_params_
    print("Melhores hiperparâmetros:", best_params)

    # Treinamento do classificador utilizando os melhores hiperparâmetros
    clf = GaussianNB(**best_params)
    clf.fit(X_train, y_train)

    # Previsões nos dados de teste
    y_pred = clf.predict(X_test)

    # Cálculo do recall
    recall = recall_score(y_test, y_pred, average='weighted')

    # Retorno do recall, y_test, y_pred
    return recall, y_test, y_pred

# Balanceamento dos dados
df_negative = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_negative, df_positive, df_neutral])

# Separando os dados em X e y (balanceados)
X = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
Y = np.array(dfrnn_balanced['sentimento2'])

# Chamada da função com os dados balanceados
recall, y_test, y_pred = classification_naive_bayes(X, Y)

# Imprime o recall
print("Recall:", recall)
# Out:
# Melhores hiperparâmetros: {'var_smoothing': 0.0005808361216819946}
# Recall: 0.4992700729927007

# %% [markdown]
# ###4.4.1 - Aplicando o hiperparâmetro

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import recall_score
from imblearn.over_sampling import RandomOverSampler

# Balanceamento dos dados
df_negative = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

# Realizar oversampling
ros = RandomOverSampler(random_state=42)
X_resampled, Y_resampled = ros.fit_resample(X, Y)

# Divisão dos dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X_resampled, Y_resampled, test_size=0.3, random_state=42)

# Criação do classificador Naive Bayes com o melhor hiperparâmetro
clf = GaussianNB(var_smoothing=0.0005808361216819946)

# Treinamento do classificador
clf.fit(X_train, y_train)

# Previsões nos dados de teste
y_pred = clf.predict(X_test)

# Cálculo do recall
recall = recall_score(y_test, y_pred, average='macro')

NBRecall = recall

# Imprimir o resultado do recall
print("Recall:", NBRecall)
# Out:
# Recall: 0.5358134240535136

# %% [markdown]
# ### 4.5 - Salvando CSV do resultado do Modelo Naive Bayes

# %%
# Criar DataFrame com as previsões
df_predictions = pd.DataFrame({'Sentimento Real': y_test, 'Sentimento Previsto': y_pred})

# Salvar o DataFrame em um arquivo CSV
df_predictions.to_csv('predictionsNaiveBayes.csv', index=False)
print("Salvo com sucesso")
# Out:
# Salvo com sucesso

# %% [markdown]
# ### 4.6 - Exportar o Modelo Naive Bayes com pickle

# %%
# Salvar o modelo Naive Bayes em um arquivo PKL
with open('/content/drive/MyDrive/PROJETO BTG/modelo_naive_bayes.pkl', 'wb') as arquivo:
    pickle.dump(clf, arquivo)

# %% [markdown]
# ## Naive Bayes - Três categorias com balanceamento

# %% [markdown]
# ### 4.2 - Teste da Função

# %%
# Balanceamento dos dados
df_negativo = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

df_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)
df_neutral_resampled = resample(df_neutral, replace=True, n_samples=len(df_negative), random_state=42)

dfrnn_balanced = pd.concat([df_negative, df_positive_resampled, df_neutral_resampled])

# Separando os dados em X e y (balanceados)
X = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
Y = np.array(dfrnn_balanced['sentimento2'])

# Chamada da função com os dados balanceados
accuracy, y_test, y_pred = classification_naive_bayes(X, Y)

# Imprime a acurácia
print(accuracy)
# Out:
# Melhores hiperparâmetros: {'var_smoothing': 0.0005808361216819946}
# 0.5299295774647887

# %% [markdown]
# A acurácia foi utilizada para avaliar o desempenho do modelo Naive Bayes. O resultado representa a proporção de instâncias classificadas corretamente em relação ao total de instâncias.

# %% [markdown]
# ### 4.3 - Visualização da Matriz de Confusão da Modelagem de Naive Bayes

# %%
# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Plot da matriz de confusão
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

# Configurações do gráfico
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=['Negativo', 'Positivo', 'Neutro'],
       yticklabels=['Negativo', 'Positivo', 'Neutro'],
       title='Matriz de Confusão',
       ylabel='Valor Verdadeiro',
       xlabel='Valor Previsto')

# Adiciona os valores nas células da matriz
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

# Mostra o gráfico
plt.show()

# %% [markdown]
# # Atividade 5 - Modelo SVM (Support Vector Machine)

# %% [markdown]
# A definição do Support Vector Machine(SVM), pode ser dada por, um modelo que visa encontrar o hiperplano de separação ideal para os dados propostos, sendo o seu maior objetivo a maximização das distâncias das variáveis deixando-as o mais definida possível. Este tende a ser mais complexo que o KNN e apresentar resultados mais estruturados. Nesse algorítmo, é escolhida a reta - denominada de "hiperplano" em maiores dimensões - que mais se distancia entre dois grupos de dados. Ao formular essa reta, o programa consegue predizer a qual classe pertence os dados depois de checar de qual lado da reta esse valor está.
#
# **Referências**
#
# (1) Introduction to Support Vector Machines (SVM) - GeeksforGeeks.
#
# https://www.geeksforgeeks.org/introduction-to-support-vector-machines-svm/.
#
#
# (2) 1.4. Support Vector Machines — scikit-learn 1.2.2 documentation.
#
# https://scikit-learn.org/stable/modules/svm.html.

# %% [markdown]
# ![CLASSE A CLASSE B (3).png](data:image/png;base64,...)

# %% [markdown]
# Fonte da imagem: Autoria Própria

# %%
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

# %% [markdown]
# ## 5.1 - Definição da Função

# %%
def classification_svm(x, y):
  # Dividir o conjunto de dados em treinamento e teste
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

  # Criar e treinar o modelo SVM
  modelo_svm = SVC()
  modelo_svm.fit(x_train, y_train)

  # Fazer previsões no conjunto de teste
  y_pred = modelo_svm.predict(x_test)

  # Calcular a acurácia
  acuracia = accuracy_score(y_test, y_pred)
  print("Acurácia:", acuracia)

  # Calcular o F-score
  fscore = f1_score(y_test, y_pred, average='macro')
  print("F-score:", fscore)

  # Calcular o recall
  recall = recall_score(y_test, y_pred, average='macro')
  print("Recall:", recall)

  # Realizar validação cruzada
  scores = cross_val_score(modelo_svm, x, y, cv=5)  # cv define o número de dobras (folds)
  print("Acurácia da Validação Cruzada:", np.mean(scores))

  return modelo_svm, y_test, y_pred

# %% [markdown]
# ## SVM - Duas categorias com balanceamento

# %% [markdown]
# ### 5.2 - Definição da Função

# %%
'''
from sklearn.svm import SVC

# Definir os arrays x e y
x = np.array(dfrnn_balanced.drop(['Frase', 'sentimento'], axis=1))
y = np.array(dfrnn_balanced['sentimento'])

# Dividir o conjunto de dados em treinamento e teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Criar e treinar o modelo SVM
modelo_svm = SVC()
modelo_svm.fit(x_train, y_train)

# Fazer previsões no conjunto de teste
y_pred = modelo_svm.predict(x_test)
'''
# Out:
# "\nfrom sklearn.svm import SVC\n\n# Definir os arrays x e y\nx = np.array(dfrnn_balanced.drop(['Frase', 'sentimento'], axis=1))\ny = np.array(dfrnn_balanced['sentimento'])\n\n# Dividir o conjunto de dados em treinamento e teste\nx_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)\n\n# Criar e treinar o modelo SVM\nmodelo_svm = SVC()\nmodelo_svm.fit(x_train, y_train)\n\n# Fazer previsões no conjunto de teste\ny_pred = modelo_svm.predict(x_test)\n"

# %% [markdown]
# ### 5.3 - Teste da Função

# %%
'''
# Calcular a acurácia
acuracia = accuracy_score(y_test, y_pred)
print("Acurácia:", acuracia)

# Calcular o F-score
fscore = f1_score(y_test, y_pred)
print("F-score:", fscore)

# Calcular o recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Realizar validação cruzada
scores = cross_val_score(modelo_svm, x, y, cv=5)  # cv define o número de dobras (folds)
print("Acurácia da Validação Cruzada:", np.mean(scores))
'''
# Out:
# '\n# Calcular a acurácia\nacuracia = accuracy_score(y_test, y_pred)\nprint("Acurácia:", acuracia)\n\n# Calcular o F-score\nfscore = f1_score(y_test, y_pred)\nprint("F-score:", fscore)\n\n# Calcular o recall\nrecall = recall_score(y_test, y_pred)\nprint("Recall:", recall)\n\n# Realizar validação cruzada\nscores = cross_val_score(modelo_svm, x, y, cv=5)  # cv define o número de dobras (folds)\nprint("Acurácia da Validação Cruzada:", np.mean(scores))\n'

# %% [markdown]
# ### 5.4 - Matriz de confusão

# %%
'''
# Cálculo da matriz de confusão
VP = confusion_matrix(y_test, y_pred)[0, 0]
FN = confusion_matrix(y_test, y_pred)[0, 1]
FP = confusion_matrix(y_test, y_pred)[1, 0]
VN = confusion_matrix(y_test, y_pred)[1, 1]

# Criação da matriz de confusão personalizada
custom_cm = np.array([[VP, FN], [FP, VN]])

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(custom_cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusão da Modelagem de SVM')
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['POSITIVO', 'NEGATIVO'])
plt.yticks(tick_marks, ['POSITIVO', 'NEGATIVO'])

# Adição dos valores numéricos na matriz
thresh = custom_cm.max() / 2.
for i, j in np.ndindex(custom_cm.shape):
    plt.text(j, i, format(custom_cm[i, j], 'd'), ha='center', va='center',
             color='white' if custom_cm[i, j] > thresh else 'black')

plt.xlabel('Previsão')
plt.ylabel('Valor Real')
plt.tight_layout()
plt.show()

# Calcular a matriz de confusão
matriz_confusao = confusion_matrix(y_test, y_pred)
print("Matriz de Confusão:")
print(matriz_confusao)
'''
# Out:
# '\n# Cálculo da matriz de confusão\nVP = confusion_matrix(y_test, y_pred)[0, 0]\nFN = confusion_matrix(y_test, y_pred)[0, 1]\nFP = confusion_matrix(y_test, y_pred)[1, 0]\nVN = confusion_matrix(y_test, y_pred)[1, 1]\n\n# Criação da matriz de confusão personalizada\ncustom_cm = np.array([[VP, FN], [FP, VN]])\n\n# Plot da matriz de confusão\nplt.figure(figsize=(8, 6))\nplt.imshow(custom_cm, interpolation=\'nearest\', cmap=plt.cm.Blues)\nplt.title(\'Matriz de Confusão da Modelagem de SVM\')\nplt.colorbar()\ntick_marks = np.arange(2)\nplt.xticks(tick_marks, [\'POSITIVO\', \'NEGATIVO\'])\nplt.yticks(tick_marks, [\'POSITIVO\', \'NEGATIVO\'])\n\n# Adição dos valores numéricos na matriz\nthresh = custom_cm.max() / 2.\nfor i, j in np.ndindex(custom_cm.shape):\n    plt.text(j, i, format(custom_cm[i, j], \'d\'), ha=\'center\', va=\'center\',\n             color=\'white\' if custom_cm[i, j] > thresh else \'black\')\n\nplt.xlabel(\'Previsão\')\nplt.ylabel(\'Valor Real\')\nplt.tight_layout()\nplt.show()\n\n# Calcular a matriz de confusão\nmatriz_confusao = confusion_matrix(y_test, y_pred)\nprint("Matriz de Confusão:")\nprint(matriz_confusao)\n'

# %% [markdown]
# ## SVM - Três categorias sem balanceamento

# %% [markdown]
# ### 5.2 - Teste da Função

# %%
# Balanceamento dos dados
df_negativo = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_negative, df_positive, df_neutral])

# Definir os arrays x e y
x = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
y = np.array(dfrnn_balanced['sentimento2'])

model, y_test, y_pred = classification_svm(x, y)
# Out:
# Acurácia: 0.6037956204379562
# F-score: 0.585549218791849
# Recall: 0.5797738449355753
# Acurácia da Validação Cruzada: 0.6140166447656592

# %% [markdown]
# ### 5.3 - Matriz de confusão

# %%
# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Plot da matriz de confusão
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

# Configurações do gráfico
classes = ['Negativo', 'Positivo', 'Neutro']
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes,
       yticklabels=classes,
       title='Matriz de Confusão',
       ylabel='Valor Verdadeiro',
       xlabel='Valor Previsto')

# Adiciona os valores nas células da matriz
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

# Mostra o gráfico
plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import make_scorer, recall_score, accuracy_score
from imblearn.over_sampling import RandomOverSampler

def classification_svm(x, y):
    # Balanceamento dos dados
    df_negative = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
    df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
    df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

    # Realizar oversampling
    ros = RandomOverSampler(random_state=42)
    x_resampled, y_resampled = ros.fit_resample(x, y)

    # Dividir o conjunto de dados em treinamento e teste
    x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

    # Definir os hiperparâmetros a serem testados
    param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}

    # Criar o modelo SVM
    svm = SVC()

    # Criar o scorer utilizando o recall como métrica
    scorer = make_scorer(recall_score, average='macro')

    # Realizar a busca de grade com validação cruzada
    grid_search = GridSearchCV(svm, param_grid=param_grid, scoring=scorer, cv=5)
    grid_search.fit(x_train, y_train)

    # Melhores hiperparâmetros encontrados
    best_params = grid_search.best_params_
    print("Melhores hiperparâmetros:", best_params)

    # Acessar o valor específico do melhor hiperparâmetro
    best_C = best_params['C']
    print("Melhor valor de C:", best_C)

    # Treinar o modelo SVM utilizando os melhores hiperparâmetros
    modelo_svm = SVC(**best_params)
    modelo_svm.fit(x_train, y_train)

    # Fazer previsões no conjunto de teste
    y_pred = modelo_svm.predict(x_test)

    # Calcular o recall
    recall = recall_score(y_test, y_pred, average='macro')

    # Calcular a acurácia
    accuracy = accuracy_score(y_test, y_pred)

    # Imprimir os resultados
    print("Recall:", recall)
    print("Acurácia:", accuracy)

    return modelo_svm, y_test, y_pred

# %%
print("Melhores hiperparâmetros:", best_params)
# Out:
# Melhores hiperparâmetros: {'batch_size': 126, 'learning_rate': 0.01, 'num_epochs': 10, 'num_hidden_units': 111}

# %% [markdown]
# ###5.4 - Aplicando os Melhores Hiperparâmetros

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import make_scorer, recall_score
from imblearn.over_sampling import RandomOverSampler

def classification_svm(x, y):
    # Balanceamento dos dados
    df_negative = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
    df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
    df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

    # Realizar oversampling
    ros = RandomOverSampler(random_state=42)
    x_resampled, y_resampled = ros.fit_resample(x, y)

    # Dividir o conjunto de dados em treinamento e teste
    x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

    # Definir os hiperparâmetros a serem testados
    param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}

    # Criar o modelo SVM
    svm = SVC()

    # Criar o scorer utilizando o recall como métrica
    scorer = make_scorer(recall_score, average='macro')

    # Realizar a busca de grade com validação cruzada
    grid_search = GridSearchCV(svm, param_grid=param_grid, scoring=scorer, cv=5)
    grid_search.fit(x_train, y_train)

    # Melhores hiperparâmetros encontrados
    best_params = grid_search.best_params_
    print("Melhores hiperparâmetros:", best_params)

    # Acessar o valor específico do melhor hiperparâmetro
    best_C = best_params['C']
    print("Melhor valor de C:", best_C)

    # Treinar o modelo SVM utilizando os melhores hiperparâmetros
    modelo_svm = SVC(**best_params)
    modelo_svm.fit(x_train, y_train)

    # Fazer previsões no conjunto de teste
    y_pred = modelo_svm.predict(x_test)

    # Calcular o recall
    recall = recall_score(y_test, y_pred, average='macro')

    SVMRecall = recall

    # Imprimir o resultado do recall
    print("Recall: ", SVMRecall)

    return modelo_svm, y_test, y_pred, SVMRecall

# Chamar a função com os dados balanceados
modelo_svm, y_test, y_pred, SVMRecall  = classification_svm(X, Y)
# Out:
# Melhores hiperparâmetros: {'C': 100}
# Melhor valor de C: 100
# Recall:  0.653251424683431

# %% [markdown]
# ### Salvando CSV do resultado do Modelo SVM

# %%
# Criar DataFrame com as previsões
df_predictions = pd.DataFrame({'Sentimento Real': y_test, 'Sentimento Previsto': y_pred})

# Salvar o DataFrame em um arquivo CSV
df_predictions.to_csv('predictionsSVM.csv', index=False)
print("Salvo com sucesso")
# Out:
# Salvo com sucesso

# %% [markdown]
# ### Exportar o Modelo SVM com pickle

# %%
# Salvar o modelo SVM em um arquivo PKL
with open('/content/drive/MyDrive/PROJETO BTG/modelo_svm.pkl', 'wb') as arquivo:
    pickle.dump(modelo_svm, arquivo)

# %% [markdown]
# ## SVM - Três categorias com balanceamento

# %% [markdown]
# ### 5.2 - Teste da Função

# %%
# # Balanceamento dos dados
# df_negativo = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
# df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
# df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

# df_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)
# df_neutral_resampled = resample(df_neutral, replace=True, n_samples=len(df_negative), random_state=42)

# dfrnn_balanced = pd.concat([df_negative, df_positive_resampled, df_neutral_resampled])

# # Definir os arrays x e y
# x = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
# y = np.array(dfrnn_balanced['sentimento2'])

# model, y_test, y_pred = classification_svm(x, y)

# %% [markdown]
# ### 5.3 - Matriz de confusão

# %%
# # Cálculo da matriz de confusão
# cm = confusion_matrix(y_test, y_pred)

# # Plot da matriz de confusão
# fig, ax = plt.subplots()
# im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
# ax.figure.colorbar(im, ax=ax)

# # Configurações do gráfico
# classes = ['Negativo', 'Positivo', 'Neutro']
# ax.set(xticks=np.arange(cm.shape[1]),
#        yticks=np.arange(cm.shape[0]),
#        xticklabels=classes,
#        yticklabels=classes,
#        title='Matriz de Confusão',
#        ylabel='Valor Verdadeiro',
#        xlabel='Valor Previsto')

# # Adiciona os valores nas células da matriz
# thresh = cm.max() / 2.
# for i in range(cm.shape[0]):
#     for j in range(cm.shape[1]):
#         ax.text(j, i, format(cm[i, j], 'd'),
#                 ha="center", va="center",
#                 color="white" if cm[i, j] > thresh else "black")

# # Mostra o gráfico
# plt.show()

# %% [markdown]
# # Atividade 6 - Modelo Random Forest

# %% [markdown]
# Random Forest é um algoritmo de aprendizado de máquina que combina várias árvores de decisão para realizar tarefas de classificação ou regressão. Ele usa aleatoriedade para criar árvores independentes e evitar overfitting, melhorando a precisão e a generalização do modelo. As previsões de cada árvore são combinadas por votação majoritária (classificação) ou média (regressão). O Random Forest é robusto, lida bem com conjuntos de dados grandes e complexos e fornece uma medida de importância das características.
#
# **Referências**
#
# (1) Entenda como funciona o Random Forest (Machine Learning).
#
# https://didatica.tech/o-que-e-e-como-funciona-o-algoritmo-randomforest/.
#
#
# (2) What is Random Forest? | IBM.
#
#  https://www.ibm.com/topics/random-forest.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte Imagem: Google Images - Analytics Vidhya

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, recall_score
from sklearn.model_selection import cross_val_score, train_test_split
import pandas as pd
import numpy as np

# %% [markdown]
# ## 6.1 - Definição da função

# %%
def classification_random_forest(x, y):
  # Dividir o conjunto de dados em treinamento e teste
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

  # Criar e treinar o modelo Random Forest
  modelo_rf = RandomForestClassifier()
  modelo_rf.fit(x_train, y_train)

  # Fazer previsões no conjunto de teste
  y_pred = modelo_rf.predict(x_test)

  # Calcular a acurácia
  acuracia = accuracy_score(y_test, y_pred)
  print("Acurácia:", acuracia)

  # Calcular o F-score
  fscore = f1_score(y_test, y_pred, average='macro')
  print("F-score:", fscore)

  # Calcular o recall
  recall = recall_score(y_test, y_pred, average='macro')
  print("Recall:", recall)

  # Realizar validação cruzada
  scores = cross_val_score(modelo_rf, x, y, cv=5)  # cv define o número de dobras (folds)
  print("Acurácia da Validação Cruzada:", np.mean(scores))

  return modelo_rf, y_test, y_pred

# %% [markdown]
# ## Random Florest - Duas categorias com balanceamento

# %% [markdown]
# ### 6.2 - Definição da função

# %%
'''
# Definir os arrays x e y
x = np.array(dfrnn_balanced.drop(['Frase', 'sentimento'], axis=1))
y = np.array(dfrnn_balanced['sentimento'])

# Dividir o conjunto de dados em treinamento e teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Criar e treinar o modelo Random Forest
modelo_rf = RandomForestClassifier()
modelo_rf.fit(x_train, y_train)

# Fazer previsões no conjunto de teste
y_pred = modelo_rf.predict(x_test)
'''
# Out:
# "\n# Definir os arrays x e y\nx = np.array(dfrnn_balanced.drop(['Frase', 'sentimento'], axis=1))\ny = np.array(dfrnn_balanced['sentimento'])\n\n# Dividir o conjunto de dados em treinamento e teste\nx_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)\n\n# Criar e treinar o modelo Random Forest\nmodelo_rf = RandomForestClassifier()\nmodelo_rf.fit(x_train, y_train)\n\n# Fazer previsões no conjunto de teste\ny_pred = modelo_rf.predict(x_test)\n"

# %% [markdown]
# ### 6.3 - Teste da função

# %%
'''
# Calcular a acurácia
acuracia = accuracy_score(y_test, y_pred)
print("Acurácia:", acuracia)

# Calcular o F-score
fscore = f1_score(y_test, y_pred)
print("F-score:", fscore)

# Calcular o recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Realizar validação cruzada
scores = cross_val_score(modelo_rf, x, y, cv=5)  # cv define o número de dobras (folds)
print("Acurácia da Validação Cruzada:", np.mean(scores))
'''
# Out:
# '\n# Calcular a acurácia\nacuracia = accuracy_score(y_test, y_pred)\nprint("Acurácia:", acuracia)\n\n# Calcular o F-score\nfscore = f1_score(y_test, y_pred)\nprint("F-score:", fscore)\n\n# Calcular o recall\nrecall = recall_score(y_test, y_pred)\nprint("Recall:", recall)\n\n# Realizar validação cruzada\nscores = cross_val_score(modelo_rf, x, y, cv=5)  # cv define o número de dobras (folds)\nprint("Acurácia da Validação Cruzada:", np.mean(scores))\n'

# %% [markdown]
# ###6.4 - Matriz de confusão

# %%
'''
# Cálculo da matriz de confusão
VP = confusion_matrix(y_test, y_pred)[0, 0]
FN = confusion_matrix(y_test, y_pred)[0, 1]
FP = confusion_matrix(y_test, y_pred)[1, 0]
VN = confusion_matrix(y_test, y_pred)[1, 1]

# Criação da matriz de confusão personalizada
custom_cm = np.array([[VP, FN], [FP, VN]])

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(custom_cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusão da Modelagem de Random Florest')
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['POSITIVO', 'NEGATIVO'])
plt.yticks(tick_marks, ['POSITIVO', 'NEGATIVO'])

# Adição dos valores numéricos na matriz
thresh = custom_cm.max() / 2.
for i, j in np.ndindex(custom_cm.shape):
    plt.text(j, i, format(custom_cm[i, j], 'd'), ha='center', va='center',
             color='white' if custom_cm[i, j] > thresh else 'black')

plt.xlabel('Previsão')
plt.ylabel('Valor Real')
plt.tight_layout()
plt.show()

# Calcular a matriz de confusão
matriz_confusao = confusion_matrix(y_test, y_pred)
print("Matriz de Confusão:")
print(matriz_confusao)
'''
# Out:
# '\n# Cálculo da matriz de confusão\nVP = confusion_matrix(y_test, y_pred)[0, 0]\nFN = confusion_matrix(y_test, y_pred)[0, 1]\nFP = confusion_matrix(y_test, y_pred)[1, 0]\nVN = confusion_matrix(y_test, y_pred)[1, 1]\n\n# Criação da matriz de confusão personalizada\ncustom_cm = np.array([[VP, FN], [FP, VN]])\n\n# Plot da matriz de confusão\nplt.figure(figsize=(8, 6))\nplt.imshow(custom_cm, interpolation=\'nearest\', cmap=plt.cm.Blues)\nplt.title(\'Matriz de Confusão da Modelagem de Random Florest\')\nplt.colorbar()\ntick_marks = np.arange(2)\nplt.xticks(tick_marks, [\'POSITIVO\', \'NEGATIVO\'])\nplt.yticks(tick_marks, [\'POSITIVO\', \'NEGATIVO\'])\n\n# Adição dos valores numéricos na matriz\nthresh = custom_cm.max() / 2.\nfor i, j in np.ndindex(custom_cm.shape):\n    plt.text(j, i, format(custom_cm[i, j], \'d\'), ha=\'center\', va=\'center\',\n             color=\'white\' if custom_cm[i, j] > thresh else \'black\')\n\nplt.xlabel(\'Previsão\')\nplt.ylabel(\'Valor Real\')\nplt.tight_layout()\nplt.show()\n\n# Calcular a matriz de confusão\nmatriz_confusao = confusion_matrix(y_test, y_pred)\nprint("Matriz de Confusão:")\nprint(matriz_confusao)\n'

# %% [markdown]
# ## Random Florest - Três categorias sem balanceamento

# %% [markdown]
# ### 6.1 - Teste da função

# %%
# Balanceamento dos dados
df_negativo = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_negative, df_positive, df_neutral])

# Definir os arrays x e y
x = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
y = np.array(dfrnn_balanced['sentimento2'])

model, y_test, y_pred = classification_random_forest(x, y)

RFRecall = recall_score(y_test, y_pred, average='weighted')
# Out:
# Acurácia: 0.6583941605839416
# F-score: 0.6447222125917238
# Recall: 0.6410756270429548
# Acurácia da Validação Cruzada: 0.6399474375821287

# %% [markdown]
# ### 6.2 - Matriz de confusão

# %%
# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Plot da matriz de confusão
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

# Configurações do gráfico
classes = ['Negativo', 'Positivo', 'Neutro']
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes,
       yticklabels=classes,
       title='Matriz de Confusão',
       ylabel='Valor Verdadeiro',
       xlabel='Valor Previsto')

# Adiciona os valores nas células da matriz
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

# Mostra o gráfico
plt.show()

# %% [markdown]
# ### Salvando CSV do resultado do Modelo Random Forest

# %%
# Criar DataFrame com as previsões
df_predictions = pd.DataFrame({'Sentimento Real': y_test, 'Sentimento Previsto': y_pred})

# Salvar o DataFrame em um arquivo CSV
df_predictions.to_csv('predictionsRandomForest.csv', index=False)
print("Salvo com sucesso")
# Out:
# Salvo com sucesso

# %% [markdown]
# ### Exportar Modelo Random Forest com pickle

# %%
# Salvar o modelo Random Forest em um arquivo PKL
with open('/content/drive/MyDrive/PROJETO BTG/modelo_random_forest.pkl', 'wb') as arquivo:
    pickle.dump(model, arquivo)

# %% [markdown]
# ## Random Florest - Três categorias com balanceamento

# %% [markdown]
# ### 6.1 - Teste da função

# %%
# # Balanceamento dos dados
# df_negativo = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
# df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
# df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

# df_positive_resampled = resample(df_positive, replace=True, n_samples=len(df_negative), random_state=42)
# df_neutral_resampled = resample(df_neutral, replace=True, n_samples=len(df_negative), random_state=42)

# dfrnn_balanced = pd.concat([df_negative, df_positive_resampled, df_neutral_resampled])

# # Separando os dados em X e y (balanceados)
# x = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2'], axis=1))
# y = np.array(dfrnn_balanced['sentimento2'])

# model, y_test, y_pred = classification_random_forest(x, y)

# %% [markdown]
# ### 6.2 - Matriz de confusão

# %%
# # Cálculo da matriz de confusão
# cm = confusion_matrix(y_test, y_pred)

# # Plot da matriz de confusão
# fig, ax = plt.subplots()
# im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
# ax.figure.colorbar(im, ax=ax)

# # Configurações do gráfico
# classes = ['Negativo', 'Positivo', 'Neutro']
# ax.set(xticks=np.arange(cm.shape[1]),
#        yticks=np.arange(cm.shape[0]),
#        xticklabels=classes,
#        yticklabels=classes,
#        title='Matriz de Confusão',
#        ylabel='Valor Verdadeiro',
#        xlabel='Valor Previsto')

# # Adiciona os valores nas células da matriz
# thresh = cm.max() / 2.
# for i in range(cm.shape[0]):
#     for j in range(cm.shape[1]):
#         ax.text(j, i, format(cm[i, j], 'd'),
#                 ha="center", va="center",
#                 color="white" if cm[i, j] > thresh else "black")

# # Mostra o gráfico
# plt.show()

# %% [markdown]
# # Atividade 7 - Vetorização TF-IDF (Regressão Logística)

# %% [markdown]
# **Vetorização TFID**
#
# A vetorização TF-IDF é uma técnica de processamento de linguagem natural que representa textos como vetores numéricos. Ela calcula a importância de cada palavra em um documento com base em sua frequência no documento e em sua raridade no conjunto de documentos. Essa abordagem permite quantificar a relevância das palavras e é útil em tarefas como classificação de textos e recuperação de informações. A vetorização TF-IDF facilita o trabalho de algoritmos de aprendizado de máquina ao transformar os textos em representações numéricas.
#
# **Referências**
#
# Text Vectorization Using Python: TF-IDF - Okan Bulut.
#
# https://okan.cloud/posts/2022-01-16-text-vectorization-using-python-tf-idf/.
#
#
# Scikit Learn TfidfVectorizer.
#
# https://stackoverflow.com/questions/34232190/scikit-learn-tfidfvectorizer-how-to-get-top-n-terms-with-highest-tf-idf-score.

# %% [markdown]
# **Regressão Logística**
#
# A regressão logística é um algoritmo de aprendizado de máquina usado para classificação binária. Ele estima a probabilidade de um objeto pertencer a uma classe usando uma função sigmoide. Durante o treinamento, os pesos das variáveis são ajustados para minimizar a diferença entre as probabilidades estimadas e as classes reais. O modelo treinado pode ser usado para fazer previsões em novos objetos, definindo um limiar para determinar a classe final. A regressão logística é uma técnica simples, eficiente e interpretável usada em várias áreas.
#
#
# **Referências**
#
# (1) Regressão Logística: Conceitos Essenciais e Modelo.
#
# https://estatsite.com.br/2018/08/29/regressao-logistica-conceitos-e-formula/.
#
# (2) O que é regressão logística? | IBM.
#
# https://www.ibm.com/br-pt/topics/logistic-regression.

# %% [markdown]
# ## Regressão Logística - Três categorias sem balanceamento

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 7.1 - Definição da função

# %%
def classification_logistic_regression(X_combined, y):
  X_combined_train, X_combined_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.3, random_state=42)

  # Criar o vetor TF-IDF
  vectorizer = TfidfVectorizer()
  X_combined_train_tfidf = vectorizer.fit_transform(X_combined_train)
  X_combined_test_tfidf = vectorizer.transform(X_combined_test)

  # Treinar um modelo (Regressão Logística com os hiperparâmetros definidos)
  model = LogisticRegression(solver='liblinear', penalty='l2', C=10)
  model.fit(X_combined_train_tfidf, y_train)

  # Fazer previsões e avaliar o modelo
  y_pred = model.predict(X_combined_test_tfidf)
  accuracy = accuracy_score(y_test, y_pred)
  print("Acurácia do modelo:", accuracy)
  recall = recall_score(y_test, y_pred, average='weighted')
  print("Revocação do modelo:", recall)

  # Calcular o F1-score
  f1 = f1_score(y_test, y_pred, average='weighted')
  print("F1-score do modelo:", f1)

  return model, y_test, y_pred

# %% [markdown]
# ###7.2 - Teste da Função

# %%
# df_negativo = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 0]
# df_positive = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 1]
# df_neutral = dfW2Vmodelo2[dfW2Vmodelo2['sentimento2'] == 2]

# dfrnn_balanced = pd.concat([df_negativo, df_positive, df_neutral])

# textFinal = base_tratada['texto_processado'].iloc[:12343]
# textFinal2 = textFinal.astype(str).values

# tipoInteracaoFinal = base_tratada['tipoInteracao'].iloc[:12343]
# tipoInteracaoFinal2 = tipoInteracaoFinal.astype(str).values

# # Dividir os dados em conjunto de treinamento e teste
# X_text = textFinal2
# X_type = tipoInteracaoFinal2
# X_combined = [text + ' ' + type for text, type in zip(X_text, X_type)]

# selected_data = dfrnn_balanced['sentimento2'].iloc[:12343]
# # y = base_tratada['sentimento2'].astype(str).values
# y = np.array(selected_data)

# model, y_test, y_pred = classification_logistic_regression(X_combined, y)

# RLRecall = recall_score(y_test, y_pred, average='weighted')

# print("Recall: ",RLRecall)

# %% [markdown]
# ### 7.3 - Matriz de Confusão

# %%
# # Calcular a matriz de confusão
# confusion = confusion_matrix(y_test, y_pred)

# # Criar um DataFrame para exibir a matriz de confusão
# confusion_df = pd.DataFrame(confusion, index=['NEGATIVO', 'POSITIVO', 'NEUTRO'], columns=['NEGATIVO', 'POSITIVO', 'NEUTRO'])

# # Plotar a matriz de confusão
# plt.figure(figsize=(8, 6))
# sns.heatmap(confusion_df, annot=True, fmt="d", cmap="Blues")
# plt.title("Matriz de Confusão")
# plt.xlabel("Valores Previstos")
# plt.ylabel("Valores Reais")
# plt.show()

# %% [markdown]
# ### Salvando CSV do resultado da Regressão Logística

# %%
# # Criar DataFrame com as previsões
# df_predictions = pd.DataFrame({'Sentimento Real': y_test, 'Sentimento Previsto': y_pred})

# # Salvar o DataFrame em um arquivo CSV
# df_predictions.to_csv('predictionsLogisticRegression.csv', index=False)
# print("Salvo com sucesso")

# %% [markdown]
# ### Exportar Modelo de Regressão Logística com pickle

# %%
# # Salvar o modelo RNN em um arquivo PKL
# with open('/content/drive/MyDrive/PROJETO BTG/modelo_logistic_regression.pkl', 'wb') as arquivo:
#     pickle.dump(model, arquivo)

# %% [markdown]
# # Atividade 8 - Aplicação de novas features.
#
# No projeto foram utilizadas as seguintes features: "sentimento" e "frase". Porém neste momento são aplicados novas features ao projeto para testa-lás, sendo elas as colunas "comentário", "marcação" e "resposta", todas elas são provenientes da coluna "tipoInteração" que após a aplicação do método one hot encoding formou as 3 novas features.

# %% [markdown]
# ## 8.1.Base tratada + one hot encodign na coluna tipoInteração
# Abaixo será feito o One hot encoding da coluna "tipoInteração". Nela existem as seguintes classes: comentário, marcação e resposta, após o uso do one hot encoding cada classe será transformada em uma nova coluna.
# O método one-hot é uma técnica para representar variáveis categóricas como vetores binários, onde 1 representa a presença da categoria e 0 representa a ausência. A biblioteca pandas em Python oferece a função get_dummies() para realizar essa codificação.

# %% [markdown]
# ### 8.1.1.Teste isolado

# %%
# Criando um dataframe para o teste
teste_onehot = pd.DataFrame({'tipoInteracao': ['comentário', 'marcação', 'resposta', 'marcação', 'comentário']})
#definindo a função
def teste_one_hot_encoding(df, column):
    one_hot = pd.get_dummies(df[column])
    df = df.drop(column, axis=1)
    df = pd.concat([df, one_hot], axis=1)
    return df
# Aplicação da função
novas_colunas = teste_one_hot_encoding(teste_onehot, 'tipoInteracao')

# Imprimir o dataframe original
print("Dataframe Original:")
print(teste_onehot)

# Imprimir o dataframe codificado com one-hot encoding
print("one hot encoding:")
print(novas_colunas)
# Out:
# Dataframe Original:
#   tipoInteracao
# 0    comentário
# 1      marcação
# 2      resposta
# 3      marcação
# 4    comentário
# one hot encoding:
#    comentário  marcação  resposta
# 0           1         0         0
# 1           0         1         0
# 2           0         0         1
# 3           0         1         0
# 4           1         0         0

# %% [markdown]
# ### 8.1.2.Teste da função

# %%
def one_hot_encoding(df, column):
    one_hot = pd.get_dummies(df[column])
    df = df.drop(column, axis=1)
    df = pd.concat([df, one_hot], axis=1)
    return df

# %% [markdown]
# ### 8.1.3.Aplicação da função

# %%
dados = pd.read_csv('/content/drive/MyDrive/PROJETO BTG/dadosTratados.csv')

# %%
one_hot_dados = one_hot_encoding(dados, 'tipoInteracao')
print(one_hot_dados)
# Out:
#                   autor                                              texto  \
# 0            v8_capital  Confira os resultados dos nossos fundos no mês...
# 1         winthegame_of  A Alvarez & Marsal estará conosco no Sportainm...
# 2            marta_bego  #Repost btgpactual with make_repost ・・・ Entend...
# 3            lmviapiana                               Minuto touro de ouro
# 4          vanilson_dos                                   @ricktolledo Sim
# ...                 ...                                                ...
# 12350       onixcapital  Uma noite de encontros e muito conhecimento on...
# 12351  amgcapitalinvest  Erros financeiros para eliminar antes dos 30 a...
# 12352     jayipacderota  Estou muito grato por todo o esforço que você ...
# 12353   moinho_cultural  "👉GUADAKAN está chegando!!!!  A aula pública e...
# 12354         bfmarilia  @btgpactual pq o morning call não está mais ap...
#
#       sentimento  comentário  marcação  resposta
# 0        NEUTRAL           0         1         0
# 1        NEUTRAL           0         1         0
# 2        NEUTRAL           0         1         0
# 3       POSITIVE           1         0         0
# 4        NEUTRAL           0         0         1
# ...          ...         ...       ...       ...
# 12350    NEUTRAL           0         1         0
# 12351    NEUTRAL           0         1         0
# 12352   POSITIVE           1         0         0
# 12353    NEUTRAL           0         1         0
# 12354   NEGATIVE           1         0         0
#
# [12355 rows x 6 columns]

# %% [markdown]
# ### 8.1.4.Criando dataframe com one hot encoding + Word2Vec

# %%
# Criando o novo dataframe com as mesmas colunas do dfW2V
dfoneHot = pd.DataFrame(dfW2Vmodelo2)

dfoneHot['resposta'] = one_hot_dados['resposta']
dfoneHot['comentário'] = one_hot_dados['comentário']
dfoneHot['marcação'] = one_hot_dados['marcação']

# Especificando o diretório de destino para salvar o arquivo CSV
diretorio_destino = '/content/drive/MyDrive/PROJETO BTG/'

# Salvando o novo dataframe em um arquivo CSV no diretório especificado
caminho_arquivo_csv = diretorio_destino + 'oneHot.csv'
dfoneHot.to_csv(caminho_arquivo_csv, index=False)

print("Arquivo 'oneHot.csv' salvo com sucesso em:", caminho_arquivo_csv)
# Out:
# Arquivo 'oneHot.csv' salvo com sucesso em: /content/drive/MyDrive/PROJETO BTG/oneHot.csv

# %%
dfoneHot
# Out:
#                                                    Frase    Vetor1    Vetor2  \
# 0      ['Confira', 'resultados', 'fundos', 'mes', 'fe... -0.461673  0.625237
# 1      ['Alvarez', 'Marsal', 'estara', 'conosco', 'Sp... -0.391035  1.143772
# 2      ['Repost', 'btgpactual', 'with', 'make_repost'... -0.230138  0.629646
# 3                            ['Minuto', 'touro', 'ouro'] -0.075631  0.185909
# 4                                 ['ricktolledo', 'Sim'] -0.081614  0.200918
# ...                                                  ...       ...       ...
# 11410  ['noite', 'encontros', 'conhecimento', 'onde',... -0.423013  0.845564
# 11411  ['Erros', 'financeiros', 'eliminar', 'antes', ... -0.743068  1.936539
# 11412  ['grato', 'todo', 'esforco', 'voce', 'rendeu',... -0.318595  1.280301
# 11413  ['GUADAKAN', 'chegando', 'aula', 'publica', 'f... -0.245366  0.609202
# 11414  ['btgpactual', 'porque', 'morning', 'call', 'n... -0.354190  1.040188
#
#          Vetor3    Vetor4    Vetor5    Vetor6    Vetor7    Vetor8    Vetor9  \
# 0      0.114453  0.459222  0.306794 -0.586930  0.213955  0.866080 -0.162611
# 1      0.040439  0.572504  0.637657 -0.724342  0.410926  1.422693 -0.067073
# 2      0.091119  0.404625  0.322938 -0.452704  0.183015  0.794990 -0.280394
# 3      0.038363  0.081205  0.048204 -0.109816  0.020094  0.213841 -0.036723
# 4      0.037080  0.084774  0.045994 -0.137323  0.053739  0.255260 -0.032161
# ...         ...       ...       ...       ...       ...       ...       ...
# 11410  0.207318  0.155583  0.332432 -0.672942  0.332869  1.306000 -0.062801
# 11411  0.307477  0.878058  0.368304 -1.239160  0.074150  1.989323 -0.586596
# 11412  0.189564  0.505960  0.160230 -0.578292  0.599425  1.486780 -0.164608
# 11413  0.120352  0.205266  0.196098 -0.370560  0.149205  0.772488 -0.077014
# 11414  0.164758  0.244278  0.277032 -0.704697  0.245273  1.487612 -0.165308
#
#        ...   Vetor45   Vetor46   Vetor47   Vetor48   Vetor49   Vetor50  \
# 0      ...  0.328353  0.068527 -0.489172  0.047712  0.096991  0.001627
# 1      ...  0.683105 -0.003922 -1.008320 -0.058452 -0.029896  0.249026
# 2      ...  0.585429 -0.035896 -0.602881 -0.035103  0.082608  0.141593
# 3      ...  0.116384  0.046445 -0.126920  0.004547 -0.002272  0.051925
# 4      ...  0.118346  0.052154 -0.128393  0.014528  0.014272  0.039189
# ...    ...       ...       ...       ...       ...       ...       ...
# 11410  ...  0.632222  0.012129 -0.734997  0.144942 -0.112458  0.058215
# 11411  ...  1.063905  0.544783 -1.058241 -0.048385  0.070893  0.485264
# 11412  ...  0.703512  0.374952 -0.876997  0.115464  0.033402  0.244219
# 11413  ...  0.395657  0.099649 -0.464842  0.046825 -0.026497  0.142462
# 11414  ...  0.786399  0.162528 -0.877027  0.029790 -0.046383  0.288936
#
#        sentimento2  resposta  comentário  marcação
# 0                2         0           0         1
# 1                2         0           0         1
# 2                2         0           0         1
# 3                1         0           1         0
# 4                2         1           0         0
# ...            ...       ...         ...       ...
# 11410            2         0           0         1
# 11411            2         0           0         1
# 11412            1         0           0         1
# 11413            2         0           0         1
# 11414            0         0           0         1
#
# [11415 rows x 55 columns]

# %% [markdown]
# ## 8.2.Aplicação das novas features nos modelos

# %% [markdown]
# ### 8.2.1 RNN - Três categorias e sem balanceamento

# %% [markdown]
# #### 8.2.2 - Teste da Função

# %%
def classification_rnn(X_test, y_test):
  # Divisão em conjunto de treinamento e teste
  X_train, X_test, y_train, y_test = train_test_split(X_test, y_test, test_size=0.3, random_state=42)

  # Remodelar os dados de entrada
  X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

  # Definindo o modelo
  model = Sequential()
  model.add(LSTM(units=128, input_shape=(1, X_test.shape[2])))
  model.add(Dense(units=3, activation='softmax'))

  model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

  # Treinar o modelo
  model.fit(X_test, y_test, epochs=10, batch_size=32)

  # Avaliar a precisão do modelo
  _, accuracy = model.evaluate(X_test, y_test)
  print('Acurácia: %.2f%%' % (accuracy * 100))

  # Fazer previsões no conjunto de teste
  y_pred_prob = model.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)

  # Calcular o recall
  recall = recall_score(y_test, y_pred, average='macro')
  print('Recall: %.2f%%' % (recall* 100))

  return model, y_test, y_pred

# %% [markdown]
# **USANDO TRÊS CATEGORIAS SEM BALANCEAMENTO DE DADOS**

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from keras.preprocessing.text import Tokenizer
from sklearn.metrics import recall_score

# %%
# Balanceamento dos dados
df_negative = dfoneHot[dfoneHot['sentimento2'] == 0]
df_positive = dfoneHot[dfoneHot['sentimento2'] == 1]
df_neutral = dfoneHot[dfoneHot['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_positive, df_negative, df_neutral])

# Separando os dados de teste em X_test e y_test (balanceados)
X_test = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2', 'comentário', 'resposta', 'marcação'], axis=1))
y_test = np.array(dfrnn_balanced['sentimento2'])

model, y_test, y_pred = classification_rnn(X_test, y_test)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 3s 4ms/step - loss: 0.9976 - accuracy: 0.5104
# Epoch 2/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.9335 - accuracy: 0.5717
# Epoch 3/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.9162 - accuracy: 0.5845
# Epoch 4/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.9000 - accuracy: 0.5915
# Epoch 5/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.8949 - accuracy: 0.5883
# Epoch 6/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.8870 - accuracy: 0.5997
# Epoch 7/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.8789 - accuracy: 0.6053
# Epoch 8/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.8812 - accuracy: 0.5968
# Epoch 9/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.8721 - accuracy: 0.6044
# Epoch 10/10
# 108/108 [==============================] - 0s 4ms/step - loss: 0.8716 - accuracy: 0.6053
# 108/108 [==============================] - 1s 3ms/step - loss: 0.8625 - accuracy: 0.6120
# Acurácia: 61.20%
# 108/108 [==============================] - 1s 2ms/step
# Recall: 58.85%

# %% [markdown]
# #### 8.2.3 - Visualização da Matriz de Confusão de Redes Neurais Recorrentes (RNN)

# %% [markdown]
# **USANDO TRÊS CATEGORIAS SEM BALANCEAMENTO DE DADOS - MATRIZ DE CONFUSÃO**

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Previsões no conjunto de teste
y_test = y_test.astype(int)
y_pred = y_pred.astype(int)

# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Definição dos rótulos das classes
class_labels = ['POSITIVO', 'NEGATIVO', 'NEUTRO']

# Plot da matriz de confusão
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matriz de Confusão da Modelagem de Redes Neurais Recorrentes (RNN)')
plt.colorbar()
tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels)
plt.yticks(tick_marks, class_labels)

# Adição dos valores numéricos na matriz
thresh = cm.max() / 2.0
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'), ha='center', va='center',
             color='white' if cm[i, j] > thresh else 'black')

plt.xlabel('Previsão')
plt.ylabel('Valor Real')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 8.2.4 - Hiperparâmetros com Random Search do RNN

# %%
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from scipy.stats import randint as sp_randint
from sklearn.metrics import recall_score
import tensorflow as tf

# Dados de entrada e rótulos
X_data = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2', 'comentário', 'resposta', 'marcação'], axis=1))
Y_labels = np.array(dfrnn_balanced['sentimento2'])

# Divisão em conjunto de treinamento e teste
X_train, X_val, y_train, y_val = train_test_split(X_data, Y_labels, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Normalização dos dados
X_train_mean = X_train.mean(axis=0)
X_train_std = X_train.std(axis=0)
X_train = (X_train - X_train_mean) / X_train_std
X_val = (X_val - X_train_mean) / X_train_std
X_data = (X_data - X_train_mean) / X_train_std

# Função para criar o modelo RNN
def create_model(num_epochs, batch_size, learning_rate, num_hidden_units):
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(units=num_hidden_units, activation='relu'),
        tf.keras.layers.Dense(units=1, activation='sigmoid')
    ])

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=learning_rate),
                  loss=tf.losses.BinaryCrossentropy(),
                  metrics=[tf.metrics.BinaryAccuracy()])

    model.fit(X_train, y_train, epochs=num_epochs, batch_size=batch_size,
              validation_data=(X_val, y_val))

    y_pred = model.predict(X_data)
    y_pred = np.round(y_pred).flatten()

    recall = recall_score(Y_labels, y_pred, average='macro')
    print('Recall:', recall)

    return model

# Definir a distribuição de valores para cada hiperparâmetro
param_dist = {
    'num_epochs': sp_randint(10, 31),  # Intervalo entre 10 e 30
    'batch_size': sp_randint(32, 129),  # Intervalo entre 32 e 128
    'learning_rate': [0.001, 0.01, 0.1],  # Valores fixos
    'num_hidden_units': sp_randint(64, 257)  # Intervalo entre 64 e 256
}

# Criação do KerasClassifier com a função create_model
keras_classifier = KerasClassifier(build_fn=create_model)

# Realizar a busca aleatória
random_search = RandomizedSearchCV(estimator=keras_classifier, param_distributions=param_dist,
                                   n_iter=10, cv=3, scoring='recall_macro', refit=False, error_score='raise')

random_result = random_search.fit(X_data, Y_labels)

# Obter os resultados da busca aleatória
results = random_result.cv_results_
best_params_idx = results['rank_test_score'].argmin()
best_params = results['params'][best_params_idx]
best_recall = results['mean_test_score'][best_params_idx]

print('Melhores hiperparâmetros:', best_params)
print('Melhor Recall:', best_recall)
# Out:
# Epoch 1/13
# <ipython-input-95-0d6bff0f50cd>:55: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_classifier = KerasClassifier(build_fn=create_model)
# 68/68 [==============================] - 1s 7ms/step - loss: -1.3786 - binary_accuracy: 0.4002 - val_loss: -3.1461 - val_binary_accuracy: 0.4130
# Epoch 2/13
# 68/68 [==============================] - 0s 4ms/step - loss: -6.2663 - binary_accuracy: 0.4069 - val_loss: -9.6647 - val_binary_accuracy: 0.4136
# Epoch 3/13
# 68/68 [==============================] - 0s 4ms/step - loss: -15.7143 - binary_accuracy: 0.4102 - val_loss: -21.1790 - val_binary_accuracy: 0.4193
# Epoch 4/13
# 68/68 [==============================] - 0s 5ms/step - loss: -31.1191 - binary_accuracy: 0.4124 - val_loss: -38.4209 - val_binary_accuracy: 0.4243
# Epoch 5/13
# 68/68 [==============================] - 0s 6ms/step - loss: -52.7176 - binary_accuracy: 0.4129 - val_loss: -61.5648 - val_binary_accuracy: 0.4255
# Epoch 6/13
# 68/68 [==============================] - 0s 6ms/step - loss: -80.5921 - binary_accuracy: 0.4147 - val_loss: -90.3494 - val_binary_accuracy: 0.4237
# Epoch 7/13
# 68/68 [==============================] - 0s 7ms/step - loss: -114.3439 - binary_accuracy: 0.4136 - val_loss: -125.1609 - val_binary_accuracy: 0.4230
# Epoch 8/13
# 68/68 [==============================] - 0s 6ms/step - loss: -154.5352 - binary_accuracy: 0.4141 - val_loss: -165.8243 - val_binary_accuracy: 0.4230
# Epoch 9/13
# 68/68 [==============================] - 0s 5ms/step - loss: -201.1065 - binary_accuracy: 0.4146 - val_loss: -211.5680 - val_binary_accuracy: 0.4230
# Epoch 10/13
# 68/68 [==============================] - 0s 5ms/step - loss: -253.3220 - binary_accuracy: 0.4154 - val_loss: -262.5098 - val_binary_accuracy: 0.4218
# Epoch 11/13
# 68/68 [==============================] - 0s 6ms/step - loss: -311.4999 - binary_accuracy: 0.4163 - val_loss: -319.6143 - val_binary_accuracy: 0.4205
# Epoch 12/13
# 68/68 [==============================] - 0s 6ms/step - loss: -375.2733 - binary_accuracy: 0.4149 - val_loss: -382.7498 - val_binary_accuracy: 0.4168
# Epoch 13/13
# 68/68 [==============================] - 0s 6ms/step - loss: -445.3493 - binary_accuracy: 0.4146 - val_loss: -450.7615 - val_binary_accuracy: 0.4205
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3813447671560921
# 81/81 [==============================] - 0s 3ms/step - loss: -801.3893 - binary_accuracy: 0.1522
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/13
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 68/68 [==============================] - 1s 6ms/step - loss: -1.1032 - binary_accuracy: 0.3853 - val_loss: -2.7213 - val_binary_accuracy: 0.4080
# Epoch 2/13
# 68/68 [==============================] - 0s 4ms/step - loss: -5.6355 - binary_accuracy: 0.4061 - val_loss: -8.6420 - val_binary_accuracy: 0.4111
# Epoch 3/13
# 68/68 [==============================] - 0s 4ms/step - loss: -14.4741 - binary_accuracy: 0.4071 - val_loss: -19.1780 - val_binary_accuracy: 0.4143
# Epoch 4/13
# 68/68 [==============================] - 0s 4ms/step - loss: -28.7825 - binary_accuracy: 0.4105 - val_loss: -35.1104 - val_binary_accuracy: 0.4199
# Epoch 5/13
# 68/68 [==============================] - 0s 5ms/step - loss: -48.8939 - binary_accuracy: 0.4141 - val_loss: -56.2941 - val_binary_accuracy: 0.4186
# Epoch 6/13
# 68/68 [==============================] - 0s 4ms/step - loss: -74.6035 - binary_accuracy: 0.4133 - val_loss: -82.3318 - val_binary_accuracy: 0.4212
# Epoch 7/13
# 68/68 [==============================] - 0s 4ms/step - loss: -106.1601 - binary_accuracy: 0.4129 - val_loss: -114.1966 - val_binary_accuracy: 0.4212
# Epoch 8/13
# 68/68 [==============================] - 0s 4ms/step - loss: -143.2445 - binary_accuracy: 0.4140 - val_loss: -150.5562 - val_binary_accuracy: 0.4224
# Epoch 9/13
# 68/68 [==============================] - 0s 4ms/step - loss: -185.5206 - binary_accuracy: 0.4141 - val_loss: -191.7639 - val_binary_accuracy: 0.4224
# Epoch 10/13
# 68/68 [==============================] - 0s 4ms/step - loss: -233.4147 - binary_accuracy: 0.4158 - val_loss: -237.9003 - val_binary_accuracy: 0.4237
# Epoch 11/13
# 68/68 [==============================] - 0s 4ms/step - loss: -286.5467 - binary_accuracy: 0.4157 - val_loss: -289.5752 - val_binary_accuracy: 0.4218
# Epoch 12/13
# 68/68 [==============================] - 0s 4ms/step - loss: -344.8531 - binary_accuracy: 0.4154 - val_loss: -344.9528 - val_binary_accuracy: 0.4218
# Epoch 13/13
# 68/68 [==============================] - 0s 4ms/step - loss: -409.0116 - binary_accuracy: 0.4143 - val_loss: -408.7380 - val_binary_accuracy: 0.4230
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3843326387971358
# 81/81 [==============================] - 0s 3ms/step - loss: 348.0938 - binary_accuracy: 0.5322
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/13
# 68/68 [==============================] - 1s 6ms/step - loss: -1.4590 - binary_accuracy: 0.3944 - val_loss: -3.3195 - val_binary_accuracy: 0.4074
# Epoch 2/13
# 68/68 [==============================] - 0s 5ms/step - loss: -6.5053 - binary_accuracy: 0.4025 - val_loss: -10.1643 - val_binary_accuracy: 0.4155
# Epoch 3/13
# 68/68 [==============================] - 0s 4ms/step - loss: -16.3997 - binary_accuracy: 0.4064 - val_loss: -22.2793 - val_binary_accuracy: 0.4155
# Epoch 4/13
# 68/68 [==============================] - 0s 6ms/step - loss: -32.1528 - binary_accuracy: 0.4075 - val_loss: -39.9839 - val_binary_accuracy: 0.4199
# Epoch 5/13
# 68/68 [==============================] - 0s 6ms/step - loss: -53.7860 - binary_accuracy: 0.4119 - val_loss: -63.3033 - val_binary_accuracy: 0.4199
# Epoch 6/13
# 68/68 [==============================] - 0s 6ms/step - loss: -81.3875 - binary_accuracy: 0.4154 - val_loss: -91.9135 - val_binary_accuracy: 0.4212
# Epoch 7/13
# 68/68 [==============================] - 0s 6ms/step - loss: -115.1123 - binary_accuracy: 0.4141 - val_loss: -126.4188 - val_binary_accuracy: 0.4230
# Epoch 8/13
# 68/68 [==============================] - 0s 5ms/step - loss: -154.3261 - binary_accuracy: 0.4155 - val_loss: -165.5778 - val_binary_accuracy: 0.4224
# Epoch 9/13
# 68/68 [==============================] - 0s 5ms/step - loss: -198.7450 - binary_accuracy: 0.4151 - val_loss: -209.8116 - val_binary_accuracy: 0.4212
# Epoch 10/13
# 68/68 [==============================] - 0s 6ms/step - loss: -248.3254 - binary_accuracy: 0.4154 - val_loss: -259.2906 - val_binary_accuracy: 0.4168
# Epoch 11/13
# 68/68 [==============================] - 0s 6ms/step - loss: -304.0754 - binary_accuracy: 0.4141 - val_loss: -312.8597 - val_binary_accuracy: 0.4186
# Epoch 12/13
# 68/68 [==============================] - 0s 6ms/step - loss: -365.2685 - binary_accuracy: 0.4127 - val_loss: -373.7761 - val_binary_accuracy: 0.4205
# Epoch 13/13
# 68/68 [==============================] - 0s 4ms/step - loss: -431.6973 - binary_accuracy: 0.4141 - val_loss: -438.0104 - val_binary_accuracy: 0.4180
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.37785330378080634
# 81/81 [==============================] - 0s 3ms/step - loss: 47.5769 - binary_accuracy: 0.6342
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/29
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 92/92 [==============================] - 1s 5ms/step - loss: -2.1135 - binary_accuracy: 0.3966 - val_loss: -5.2540 - val_binary_accuracy: 0.4130
# Epoch 2/29
# 92/92 [==============================] - 0s 4ms/step - loss: -12.0708 - binary_accuracy: 0.4096 - val_loss: -19.7432 - val_binary_accuracy: 0.4174
# Epoch 3/29
# 92/92 [==============================] - 0s 4ms/step - loss: -33.4661 - binary_accuracy: 0.4108 - val_loss: -45.5846 - val_binary_accuracy: 0.4174
# Epoch 4/29
# 92/92 [==============================] - 0s 4ms/step - loss: -66.7535 - binary_accuracy: 0.4115 - val_loss: -82.6909 - val_binary_accuracy: 0.4224
# Epoch 5/29
# 92/92 [==============================] - 0s 4ms/step - loss: -112.8504 - binary_accuracy: 0.4143 - val_loss: -131.4079 - val_binary_accuracy: 0.4237
# Epoch 6/29
# 92/92 [==============================] - 0s 4ms/step - loss: -170.7690 - binary_accuracy: 0.4147 - val_loss: -191.5514 - val_binary_accuracy: 0.4255
# Epoch 7/29
# 92/92 [==============================] - 0s 4ms/step - loss: -241.1735 - binary_accuracy: 0.4147 - val_loss: -262.2572 - val_binary_accuracy: 0.4230
# Epoch 8/29
# 92/92 [==============================] - 0s 4ms/step - loss: -323.8898 - binary_accuracy: 0.4160 - val_loss: -345.2893 - val_binary_accuracy: 0.4230
# Epoch 9/29
# 92/92 [==============================] - 0s 4ms/step - loss: -418.6668 - binary_accuracy: 0.4149 - val_loss: -441.0801 - val_binary_accuracy: 0.4230
# Epoch 10/29
# 92/92 [==============================] - 0s 4ms/step - loss: -524.8723 - binary_accuracy: 0.4140 - val_loss: -544.0052 - val_binary_accuracy: 0.4249
# Epoch 11/29
# 92/92 [==============================] - 0s 4ms/step - loss: -641.0528 - binary_accuracy: 0.4152 - val_loss: -658.1675 - val_binary_accuracy: 0.4186
# Epoch 12/29
# 92/92 [==============================] - 0s 4ms/step - loss: -767.5071 - binary_accuracy: 0.4143 - val_loss: -779.2995 - val_binary_accuracy: 0.4186
# Epoch 13/29
# 92/92 [==============================] - 0s 4ms/step - loss: -902.7253 - binary_accuracy: 0.4132 - val_loss: -910.4033 - val_binary_accuracy: 0.4161
# Epoch 14/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1047.5487 - binary_accuracy: 0.4129 - val_loss: -1051.8481 - val_binary_accuracy: 0.4186
# Epoch 15/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1201.9541 - binary_accuracy: 0.4116 - val_loss: -1199.3395 - val_binary_accuracy: 0.4186
# Epoch 16/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1364.1146 - binary_accuracy: 0.4135 - val_loss: -1354.8456 - val_binary_accuracy: 0.4143
# Epoch 17/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1535.8560 - binary_accuracy: 0.4122 - val_loss: -1517.0061 - val_binary_accuracy: 0.4161
# Epoch 18/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1715.4012 - binary_accuracy: 0.4099 - val_loss: -1689.1483 - val_binary_accuracy: 0.4136
# Epoch 19/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1903.8120 - binary_accuracy: 0.4121 - val_loss: -1870.1201 - val_binary_accuracy: 0.4155
# Epoch 20/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2100.2852 - binary_accuracy: 0.4122 - val_loss: -2058.6375 - val_binary_accuracy: 0.4149
# Epoch 21/29
# 92/92 [==============================] - 1s 5ms/step - loss: -2304.0342 - binary_accuracy: 0.4111 - val_loss: -2251.1936 - val_binary_accuracy: 0.4143
# Epoch 22/29
# 92/92 [==============================] - 0s 5ms/step - loss: -2516.2600 - binary_accuracy: 0.4107 - val_loss: -2454.4182 - val_binary_accuracy: 0.4143
# Epoch 23/29
# 92/92 [==============================] - 1s 6ms/step - loss: -2735.2190 - binary_accuracy: 0.4110 - val_loss: -2664.0220 - val_binary_accuracy: 0.4149
# Epoch 24/29
# 92/92 [==============================] - 0s 5ms/step - loss: -2962.2593 - binary_accuracy: 0.4110 - val_loss: -2877.0845 - val_binary_accuracy: 0.4143
# Epoch 25/29
# 92/92 [==============================] - 0s 5ms/step - loss: -3195.7046 - binary_accuracy: 0.4122 - val_loss: -3100.2925 - val_binary_accuracy: 0.4143
# Epoch 26/29
# 92/92 [==============================] - 1s 6ms/step - loss: -3438.1277 - binary_accuracy: 0.4122 - val_loss: -3328.9636 - val_binary_accuracy: 0.4143
# Epoch 27/29
# 92/92 [==============================] - 0s 5ms/step - loss: -3687.5500 - binary_accuracy: 0.4132 - val_loss: -3565.1958 - val_binary_accuracy: 0.4143
# Epoch 28/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3945.0745 - binary_accuracy: 0.4124 - val_loss: -3807.4722 - val_binary_accuracy: 0.4155
# Epoch 29/29
# 92/92 [==============================] - 0s 4ms/step - loss: -4209.1851 - binary_accuracy: 0.4099 - val_loss: -4058.3391 - val_binary_accuracy: 0.4136
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3740567885202046
# 109/109 [==============================] - 0s 4ms/step - loss: -6739.4404 - binary_accuracy: 0.1503
# 119/119 [==============================] - 0s 2ms/step
# Epoch 1/29
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 92/92 [==============================] - 2s 8ms/step - loss: -2.6554 - binary_accuracy: 0.3982 - val_loss: -6.2784 - val_binary_accuracy: 0.4124
# Epoch 2/29
# 92/92 [==============================] - 1s 6ms/step - loss: -13.4749 - binary_accuracy: 0.4099 - val_loss: -22.0416 - val_binary_accuracy: 0.4174
# Epoch 3/29
# 92/92 [==============================] - 0s 4ms/step - loss: -36.7091 - binary_accuracy: 0.4118 - val_loss: -50.4817 - val_binary_accuracy: 0.4180
# Epoch 4/29
# 92/92 [==============================] - 0s 4ms/step - loss: -73.2796 - binary_accuracy: 0.4144 - val_loss: -91.4975 - val_binary_accuracy: 0.4224
# Epoch 5/29
# 92/92 [==============================] - 0s 4ms/step - loss: -123.2290 - binary_accuracy: 0.4151 - val_loss: -144.6850 - val_binary_accuracy: 0.4230
# Epoch 6/29
# 92/92 [==============================] - 0s 4ms/step - loss: -186.3143 - binary_accuracy: 0.4152 - val_loss: -210.7959 - val_binary_accuracy: 0.4212
# Epoch 7/29
# 92/92 [==============================] - 0s 4ms/step - loss: -264.0974 - binary_accuracy: 0.4158 - val_loss: -290.6958 - val_binary_accuracy: 0.4230
# Epoch 8/29
# 92/92 [==============================] - 0s 4ms/step - loss: -354.3452 - binary_accuracy: 0.4147 - val_loss: -383.8180 - val_binary_accuracy: 0.4224
# Epoch 9/29
# 92/92 [==============================] - 0s 4ms/step - loss: -457.2329 - binary_accuracy: 0.4149 - val_loss: -486.1768 - val_binary_accuracy: 0.4199
# Epoch 10/29
# 92/92 [==============================] - 0s 4ms/step - loss: -571.8873 - binary_accuracy: 0.4135 - val_loss: -600.8168 - val_binary_accuracy: 0.4212
# Epoch 11/29
# 92/92 [==============================] - 0s 4ms/step - loss: -698.1522 - binary_accuracy: 0.4135 - val_loss: -725.0020 - val_binary_accuracy: 0.4218
# Epoch 12/29
# 92/92 [==============================] - 0s 4ms/step - loss: -835.0168 - binary_accuracy: 0.4132 - val_loss: -862.1481 - val_binary_accuracy: 0.4180
# Epoch 13/29
# 92/92 [==============================] - 0s 4ms/step - loss: -982.6212 - binary_accuracy: 0.4127 - val_loss: -1006.2361 - val_binary_accuracy: 0.4193
# Epoch 14/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1139.6190 - binary_accuracy: 0.4118 - val_loss: -1161.2394 - val_binary_accuracy: 0.4161
# Epoch 15/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1307.4835 - binary_accuracy: 0.4118 - val_loss: -1322.4642 - val_binary_accuracy: 0.4124
# Epoch 16/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1484.8145 - binary_accuracy: 0.4132 - val_loss: -1496.0593 - val_binary_accuracy: 0.4136
# Epoch 17/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1672.0452 - binary_accuracy: 0.4115 - val_loss: -1675.1624 - val_binary_accuracy: 0.4149
# Epoch 18/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1867.5812 - binary_accuracy: 0.4124 - val_loss: -1866.9067 - val_binary_accuracy: 0.4143
# Epoch 19/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2072.1108 - binary_accuracy: 0.4113 - val_loss: -2063.8564 - val_binary_accuracy: 0.4136
# Epoch 20/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2283.9380 - binary_accuracy: 0.4111 - val_loss: -2270.9829 - val_binary_accuracy: 0.4143
# Epoch 21/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2504.6057 - binary_accuracy: 0.4113 - val_loss: -2482.9075 - val_binary_accuracy: 0.4155
# Epoch 22/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2732.4424 - binary_accuracy: 0.4127 - val_loss: -2704.0747 - val_binary_accuracy: 0.4130
# Epoch 23/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2970.0737 - binary_accuracy: 0.4116 - val_loss: -2928.4458 - val_binary_accuracy: 0.4149
# Epoch 24/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3214.1445 - binary_accuracy: 0.4122 - val_loss: -3166.4521 - val_binary_accuracy: 0.4155
# Epoch 25/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3465.1208 - binary_accuracy: 0.4121 - val_loss: -3408.0659 - val_binary_accuracy: 0.4143
# Epoch 26/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3723.7668 - binary_accuracy: 0.4116 - val_loss: -3658.0986 - val_binary_accuracy: 0.4136
# Epoch 27/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3991.8711 - binary_accuracy: 0.4107 - val_loss: -3913.2046 - val_binary_accuracy: 0.4149
# Epoch 28/29
# 92/92 [==============================] - 0s 4ms/step - loss: -4266.1650 - binary_accuracy: 0.4118 - val_loss: -4179.3691 - val_binary_accuracy: 0.4155
# Epoch 29/29
# 92/92 [==============================] - 0s 4ms/step - loss: -4547.6172 - binary_accuracy: 0.4100 - val_loss: -4451.6025 - val_binary_accuracy: 0.4143
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3769372649404769
# 109/109 [==============================] - 0s 3ms/step - loss: 3599.9719 - binary_accuracy: 0.5326
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/29
# 92/92 [==============================] - 1s 5ms/step - loss: -2.1836 - binary_accuracy: 0.3931 - val_loss: -5.1257 - val_binary_accuracy: 0.4174
# Epoch 2/29
# 92/92 [==============================] - 0s 4ms/step - loss: -11.6440 - binary_accuracy: 0.4075 - val_loss: -18.6950 - val_binary_accuracy: 0.4186
# Epoch 3/29
# 92/92 [==============================] - 0s 5ms/step - loss: -32.1517 - binary_accuracy: 0.4079 - val_loss: -43.4932 - val_binary_accuracy: 0.4168
# Epoch 4/29
# 92/92 [==============================] - 0s 5ms/step - loss: -65.3390 - binary_accuracy: 0.4118 - val_loss: -80.5464 - val_binary_accuracy: 0.4218
# Epoch 5/29
# 92/92 [==============================] - 0s 5ms/step - loss: -111.7767 - binary_accuracy: 0.4144 - val_loss: -128.6508 - val_binary_accuracy: 0.4218
# Epoch 6/29
# 92/92 [==============================] - 1s 6ms/step - loss: -170.3097 - binary_accuracy: 0.4140 - val_loss: -189.2407 - val_binary_accuracy: 0.4243
# Epoch 7/29
# 92/92 [==============================] - 1s 6ms/step - loss: -241.7852 - binary_accuracy: 0.4157 - val_loss: -260.4806 - val_binary_accuracy: 0.4230
# Epoch 8/29
# 92/92 [==============================] - 1s 6ms/step - loss: -325.9683 - binary_accuracy: 0.4171 - val_loss: -344.1436 - val_binary_accuracy: 0.4243
# Epoch 9/29
# 92/92 [==============================] - 1s 6ms/step - loss: -422.7112 - binary_accuracy: 0.4160 - val_loss: -437.6922 - val_binary_accuracy: 0.4205
# Epoch 10/29
# 92/92 [==============================] - 0s 5ms/step - loss: -530.4780 - binary_accuracy: 0.4157 - val_loss: -543.4940 - val_binary_accuracy: 0.4212
# Epoch 11/29
# 92/92 [==============================] - 0s 4ms/step - loss: -649.3682 - binary_accuracy: 0.4168 - val_loss: -659.5840 - val_binary_accuracy: 0.4224
# Epoch 12/29
# 92/92 [==============================] - 0s 4ms/step - loss: -778.6058 - binary_accuracy: 0.4140 - val_loss: -781.6417 - val_binary_accuracy: 0.4212
# Epoch 13/29
# 92/92 [==============================] - 0s 4ms/step - loss: -917.5856 - binary_accuracy: 0.4127 - val_loss: -914.8561 - val_binary_accuracy: 0.4168
# Epoch 14/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1065.8202 - binary_accuracy: 0.4113 - val_loss: -1056.9873 - val_binary_accuracy: 0.4149
# Epoch 15/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1223.0563 - binary_accuracy: 0.4125 - val_loss: -1204.9332 - val_binary_accuracy: 0.4149
# Epoch 16/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1390.0273 - binary_accuracy: 0.4121 - val_loss: -1364.2938 - val_binary_accuracy: 0.4155
# Epoch 17/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1565.4077 - binary_accuracy: 0.4113 - val_loss: -1529.7979 - val_binary_accuracy: 0.4149
# Epoch 18/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1750.2026 - binary_accuracy: 0.4099 - val_loss: -1704.6487 - val_binary_accuracy: 0.4155
# Epoch 19/29
# 92/92 [==============================] - 0s 4ms/step - loss: -1944.0928 - binary_accuracy: 0.4111 - val_loss: -1886.6523 - val_binary_accuracy: 0.4149
# Epoch 20/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2146.3130 - binary_accuracy: 0.4096 - val_loss: -2076.0837 - val_binary_accuracy: 0.4143
# Epoch 21/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2356.3435 - binary_accuracy: 0.4125 - val_loss: -2275.4087 - val_binary_accuracy: 0.4136
# Epoch 22/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2573.6292 - binary_accuracy: 0.4118 - val_loss: -2479.5137 - val_binary_accuracy: 0.4143
# Epoch 23/29
# 92/92 [==============================] - 0s 4ms/step - loss: -2798.8723 - binary_accuracy: 0.4129 - val_loss: -2692.5059 - val_binary_accuracy: 0.4130
# Epoch 24/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3032.7815 - binary_accuracy: 0.4118 - val_loss: -2909.6863 - val_binary_accuracy: 0.4136
# Epoch 25/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3275.2488 - binary_accuracy: 0.4110 - val_loss: -3138.9148 - val_binary_accuracy: 0.4136
# Epoch 26/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3524.7134 - binary_accuracy: 0.4125 - val_loss: -3368.3940 - val_binary_accuracy: 0.4136
# Epoch 27/29
# 92/92 [==============================] - 0s 4ms/step - loss: -3780.7969 - binary_accuracy: 0.4119 - val_loss: -3613.3740 - val_binary_accuracy: 0.4143
# Epoch 28/29
# 92/92 [==============================] - 0s 4ms/step - loss: -4043.6887 - binary_accuracy: 0.4124 - val_loss: -3856.2034 - val_binary_accuracy: 0.4136
# Epoch 29/29
# 92/92 [==============================] - 0s 4ms/step - loss: -4312.7173 - binary_accuracy: 0.4127 - val_loss: -4111.7456 - val_binary_accuracy: 0.4149
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3750227567175593
# 109/109 [==============================] - 0s 3ms/step - loss: 331.4452 - binary_accuracy: 0.6368
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/14
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 53/53 [==============================] - 1s 7ms/step - loss: -41.3569 - binary_accuracy: 0.4022 - val_loss: -132.9673 - val_binary_accuracy: 0.4199
# Epoch 2/14
# 53/53 [==============================] - 0s 5ms/step - loss: -379.4007 - binary_accuracy: 0.4136 - val_loss: -668.0383 - val_binary_accuracy: 0.4230
# Epoch 3/14
# 53/53 [==============================] - 0s 4ms/step - loss: -1228.7034 - binary_accuracy: 0.4102 - val_loss: -1723.7557 - val_binary_accuracy: 0.4255
# Epoch 4/14
# 53/53 [==============================] - 0s 5ms/step - loss: -2647.8975 - binary_accuracy: 0.4129 - val_loss: -3292.2620 - val_binary_accuracy: 0.4224
# Epoch 5/14
# 53/53 [==============================] - 0s 5ms/step - loss: -4674.2593 - binary_accuracy: 0.4143 - val_loss: -5430.3184 - val_binary_accuracy: 0.4199
# Epoch 6/14
# 53/53 [==============================] - 0s 4ms/step - loss: -7357.1860 - binary_accuracy: 0.4138 - val_loss: -8161.7227 - val_binary_accuracy: 0.4136
# Epoch 7/14
# 53/53 [==============================] - 0s 5ms/step - loss: -10627.1553 - binary_accuracy: 0.4107 - val_loss: -11399.9727 - val_binary_accuracy: 0.4136
# Epoch 8/14
# 53/53 [==============================] - 0s 5ms/step - loss: -14413.4805 - binary_accuracy: 0.4116 - val_loss: -15128.0215 - val_binary_accuracy: 0.4149
# Epoch 9/14
# 53/53 [==============================] - 0s 4ms/step - loss: -18735.6328 - binary_accuracy: 0.4116 - val_loss: -19332.5703 - val_binary_accuracy: 0.4124
# Epoch 10/14
# 53/53 [==============================] - 0s 5ms/step - loss: -23569.7695 - binary_accuracy: 0.4111 - val_loss: -24065.2207 - val_binary_accuracy: 0.4130
# Epoch 11/14
# 53/53 [==============================] - 0s 5ms/step - loss: -28999.4688 - binary_accuracy: 0.4116 - val_loss: -29100.3945 - val_binary_accuracy: 0.4155
# Epoch 12/14
# 53/53 [==============================] - 0s 4ms/step - loss: -34867.1953 - binary_accuracy: 0.4129 - val_loss: -34836.9648 - val_binary_accuracy: 0.4168
# Epoch 13/14
# 53/53 [==============================] - 0s 4ms/step - loss: -41344.7070 - binary_accuracy: 0.4100 - val_loss: -40941.5977 - val_binary_accuracy: 0.4193
# Epoch 14/14
# 53/53 [==============================] - 0s 5ms/step - loss: -48261.7656 - binary_accuracy: 0.4119 - val_loss: -47494.2695 - val_binary_accuracy: 0.4149
# 357/357 [==============================] - 1s 2ms/step
# Recall: 0.37615329160463773
# 63/63 [==============================] - 0s 5ms/step - loss: -85162.9219 - binary_accuracy: 0.1494
# 119/119 [==============================] - 0s 2ms/step
# Epoch 1/14
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 53/53 [==============================] - 2s 7ms/step - loss: -38.2925 - binary_accuracy: 0.3950 - val_loss: -125.9946 - val_binary_accuracy: 0.4118
# Epoch 2/14
# 53/53 [==============================] - 0s 5ms/step - loss: -365.9221 - binary_accuracy: 0.4068 - val_loss: -669.5507 - val_binary_accuracy: 0.4224
# Epoch 3/14
# 53/53 [==============================] - 0s 5ms/step - loss: -1223.8662 - binary_accuracy: 0.4152 - val_loss: -1746.9468 - val_binary_accuracy: 0.4199
# Epoch 4/14
# 53/53 [==============================] - 0s 4ms/step - loss: -2672.8281 - binary_accuracy: 0.4104 - val_loss: -3405.6565 - val_binary_accuracy: 0.4243
# Epoch 5/14
# 53/53 [==============================] - 0s 4ms/step - loss: -4730.7837 - binary_accuracy: 0.4161 - val_loss: -5590.9600 - val_binary_accuracy: 0.4224
# Epoch 6/14
# 53/53 [==============================] - 0s 4ms/step - loss: -7370.9536 - binary_accuracy: 0.4136 - val_loss: -8353.4678 - val_binary_accuracy: 0.4136
# Epoch 7/14
# 53/53 [==============================] - 0s 4ms/step - loss: -10572.6670 - binary_accuracy: 0.4086 - val_loss: -11548.3818 - val_binary_accuracy: 0.4105
# Epoch 8/14
# 53/53 [==============================] - 0s 5ms/step - loss: -14313.1992 - binary_accuracy: 0.4100 - val_loss: -15244.6055 - val_binary_accuracy: 0.4111
# Epoch 9/14
# 53/53 [==============================] - 0s 4ms/step - loss: -18578.0566 - binary_accuracy: 0.4110 - val_loss: -19436.7461 - val_binary_accuracy: 0.4093
# Epoch 10/14
# 53/53 [==============================] - 0s 5ms/step - loss: -23328.9180 - binary_accuracy: 0.4108 - val_loss: -24171.4941 - val_binary_accuracy: 0.4161
# Epoch 11/14
# 53/53 [==============================] - 0s 5ms/step - loss: -28626.2109 - binary_accuracy: 0.4104 - val_loss: -29252.2051 - val_binary_accuracy: 0.4111
# Epoch 12/14
# 53/53 [==============================] - 0s 4ms/step - loss: -34360.7422 - binary_accuracy: 0.4122 - val_loss: -34749.6094 - val_binary_accuracy: 0.4111
# Epoch 13/14
# 53/53 [==============================] - 0s 4ms/step - loss: -40557.1250 - binary_accuracy: 0.4097 - val_loss: -40787.0039 - val_binary_accuracy: 0.4143
# Epoch 14/14
# 53/53 [==============================] - 0s 5ms/step - loss: -47271.0742 - binary_accuracy: 0.4113 - val_loss: -47234.5742 - val_binary_accuracy: 0.4143
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3748985221145837
# 63/63 [==============================] - 0s 3ms/step - loss: 39669.8906 - binary_accuracy: 0.5368
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/14
# 53/53 [==============================] - 1s 7ms/step - loss: -38.5760 - binary_accuracy: 0.4008 - val_loss: -125.2937 - val_binary_accuracy: 0.4136
# Epoch 2/14
# 53/53 [==============================] - 0s 4ms/step - loss: -378.8397 - binary_accuracy: 0.4091 - val_loss: -693.8201 - val_binary_accuracy: 0.4205
# Epoch 3/14
# 53/53 [==============================] - 0s 4ms/step - loss: -1270.0154 - binary_accuracy: 0.4097 - val_loss: -1827.0874 - val_binary_accuracy: 0.4243
# Epoch 4/14
# 53/53 [==============================] - 0s 4ms/step - loss: -2798.4177 - binary_accuracy: 0.4124 - val_loss: -3568.8679 - val_binary_accuracy: 0.4262
# Epoch 5/14
# 53/53 [==============================] - 0s 5ms/step - loss: -5000.8525 - binary_accuracy: 0.4143 - val_loss: -5902.0474 - val_binary_accuracy: 0.4212
# Epoch 6/14
# 53/53 [==============================] - 0s 4ms/step - loss: -7812.3359 - binary_accuracy: 0.4091 - val_loss: -8787.7715 - val_binary_accuracy: 0.4143
# Epoch 7/14
# 53/53 [==============================] - 0s 4ms/step - loss: -11255.7676 - binary_accuracy: 0.4093 - val_loss: -12214.6963 - val_binary_accuracy: 0.4130
# Epoch 8/14
# 53/53 [==============================] - 0s 4ms/step - loss: -15253.1729 - binary_accuracy: 0.4096 - val_loss: -16228.2754 - val_binary_accuracy: 0.4149
# Epoch 9/14
# 53/53 [==============================] - 0s 4ms/step - loss: -19834.8984 - binary_accuracy: 0.4091 - val_loss: -20735.7129 - val_binary_accuracy: 0.4143
# Epoch 10/14
# 53/53 [==============================] - 0s 4ms/step - loss: -24913.4824 - binary_accuracy: 0.4111 - val_loss: -25656.8691 - val_binary_accuracy: 0.4124
# Epoch 11/14
# 53/53 [==============================] - 0s 4ms/step - loss: -30552.0723 - binary_accuracy: 0.4086 - val_loss: -31095.9180 - val_binary_accuracy: 0.4155
# Epoch 12/14
# 53/53 [==============================] - 0s 4ms/step - loss: -36715.8867 - binary_accuracy: 0.4115 - val_loss: -37056.0586 - val_binary_accuracy: 0.4111
# Epoch 13/14
# 53/53 [==============================] - 0s 4ms/step - loss: -43413.8086 - binary_accuracy: 0.4099 - val_loss: -43432.4922 - val_binary_accuracy: 0.4155
# Epoch 14/14
# 53/53 [==============================] - 0s 4ms/step - loss: -50589.9180 - binary_accuracy: 0.4113 - val_loss: -50323.1328 - val_binary_accuracy: 0.4136
# 357/357 [==============================] - 1s 2ms/step
# Recall: 0.3789347924952408
# 63/63 [==============================] - 0s 4ms/step - loss: 4111.9102 - binary_accuracy: 0.6360
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/18
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 72/72 [==============================] - 1s 6ms/step - loss: -71.1642 - binary_accuracy: 0.4003 - val_loss: -227.5588 - val_binary_accuracy: 0.4199
# Epoch 2/18
# 72/72 [==============================] - 0s 4ms/step - loss: -677.8820 - binary_accuracy: 0.4099 - val_loss: -1214.1938 - val_binary_accuracy: 0.4218
# Epoch 3/18
# 72/72 [==============================] - 0s 4ms/step - loss: -2159.4629 - binary_accuracy: 0.4118 - val_loss: -2984.9893 - val_binary_accuracy: 0.4243
# Epoch 4/18
# 72/72 [==============================] - 0s 4ms/step - loss: -4439.9512 - binary_accuracy: 0.4127 - val_loss: -5468.7266 - val_binary_accuracy: 0.4255
# Epoch 5/18
# 72/72 [==============================] - 0s 4ms/step - loss: -7434.1816 - binary_accuracy: 0.4119 - val_loss: -8719.5371 - val_binary_accuracy: 0.4136
# Epoch 6/18
# 72/72 [==============================] - 0s 4ms/step - loss: -11291.7217 - binary_accuracy: 0.4102 - val_loss: -12734.6738 - val_binary_accuracy: 0.4111
# Epoch 7/18
# 72/72 [==============================] - 0s 4ms/step - loss: -16112.8477 - binary_accuracy: 0.4099 - val_loss: -17664.6133 - val_binary_accuracy: 0.4136
# Epoch 8/18
# 72/72 [==============================] - 0s 4ms/step - loss: -21778.9766 - binary_accuracy: 0.4111 - val_loss: -23375.9434 - val_binary_accuracy: 0.4199
# Epoch 9/18
# 72/72 [==============================] - 0s 4ms/step - loss: -28089.7754 - binary_accuracy: 0.4108 - val_loss: -29641.9824 - val_binary_accuracy: 0.4099
# Epoch 10/18
# 72/72 [==============================] - 0s 4ms/step - loss: -35212.2461 - binary_accuracy: 0.4102 - val_loss: -36595.4023 - val_binary_accuracy: 0.4105
# Epoch 11/18
# 72/72 [==============================] - 0s 4ms/step - loss: -42831.4844 - binary_accuracy: 0.4108 - val_loss: -43966.6133 - val_binary_accuracy: 0.4124
# Epoch 12/18
# 72/72 [==============================] - 0s 4ms/step - loss: -51289.9258 - binary_accuracy: 0.4100 - val_loss: -52252.7266 - val_binary_accuracy: 0.4155
# Epoch 13/18
# 72/72 [==============================] - 0s 4ms/step - loss: -60646.6719 - binary_accuracy: 0.4122 - val_loss: -61254.9844 - val_binary_accuracy: 0.4136
# Epoch 14/18
# 72/72 [==============================] - 0s 4ms/step - loss: -70489.6562 - binary_accuracy: 0.4130 - val_loss: -70574.1094 - val_binary_accuracy: 0.4130
# Epoch 15/18
# 72/72 [==============================] - 0s 4ms/step - loss: -80973.3203 - binary_accuracy: 0.4113 - val_loss: -80706.9375 - val_binary_accuracy: 0.4124
# Epoch 16/18
# 72/72 [==============================] - 0s 4ms/step - loss: -92295.4531 - binary_accuracy: 0.4116 - val_loss: -91533.4531 - val_binary_accuracy: 0.4136
# Epoch 17/18
# 72/72 [==============================] - 0s 4ms/step - loss: -104189.5703 - binary_accuracy: 0.4113 - val_loss: -102911.6328 - val_binary_accuracy: 0.4155
# Epoch 18/18
# 72/72 [==============================] - 0s 4ms/step - loss: -116888.4922 - binary_accuracy: 0.4116 - val_loss: -115098.5547 - val_binary_accuracy: 0.4136
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3770031504953251
# 85/85 [==============================] - 0s 3ms/step - loss: -197896.2188 - binary_accuracy: 0.1524
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/18
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 72/72 [==============================] - 2s 9ms/step - loss: -71.2433 - binary_accuracy: 0.4016 - val_loss: -234.8592 - val_binary_accuracy: 0.4155
# Epoch 2/18
# 72/72 [==============================] - 0s 5ms/step - loss: -672.8210 - binary_accuracy: 0.4049 - val_loss: -1242.1205 - val_binary_accuracy: 0.4205
# Epoch 3/18
# 72/72 [==============================] - 0s 5ms/step - loss: -2288.2744 - binary_accuracy: 0.4141 - val_loss: -3358.6370 - val_binary_accuracy: 0.4218
# Epoch 4/18
# 72/72 [==============================] - 0s 6ms/step - loss: -5061.4355 - binary_accuracy: 0.4121 - val_loss: -6515.8628 - val_binary_accuracy: 0.4130
# Epoch 5/18
# 72/72 [==============================] - 0s 5ms/step - loss: -8915.5342 - binary_accuracy: 0.4119 - val_loss: -10600.1406 - val_binary_accuracy: 0.4061
# Epoch 6/18
# 72/72 [==============================] - 0s 6ms/step - loss: -13522.8389 - binary_accuracy: 0.4024 - val_loss: -15377.9922 - val_binary_accuracy: 0.4136
# Epoch 7/18
# 72/72 [==============================] - 0s 6ms/step - loss: -19089.9316 - binary_accuracy: 0.4104 - val_loss: -21080.8438 - val_binary_accuracy: 0.4124
# Epoch 8/18
# 72/72 [==============================] - 0s 6ms/step - loss: -25375.7402 - binary_accuracy: 0.4102 - val_loss: -27493.5215 - val_binary_accuracy: 0.4105
# Epoch 9/18
# 72/72 [==============================] - 0s 4ms/step - loss: -32634.3730 - binary_accuracy: 0.4100 - val_loss: -34703.6133 - val_binary_accuracy: 0.4099
# Epoch 10/18
# 72/72 [==============================] - 0s 4ms/step - loss: -40816.9258 - binary_accuracy: 0.4089 - val_loss: -42950.3320 - val_binary_accuracy: 0.4118
# Epoch 11/18
# 72/72 [==============================] - 0s 4ms/step - loss: -50030.0820 - binary_accuracy: 0.4086 - val_loss: -52027.1680 - val_binary_accuracy: 0.4118
# Epoch 12/18
# 72/72 [==============================] - 0s 4ms/step - loss: -59603.8359 - binary_accuracy: 0.4130 - val_loss: -61384.0312 - val_binary_accuracy: 0.4130
# Epoch 13/18
# 72/72 [==============================] - 0s 4ms/step - loss: -69911.8672 - binary_accuracy: 0.4115 - val_loss: -71489.5234 - val_binary_accuracy: 0.4105
# Epoch 14/18
# 72/72 [==============================] - 0s 4ms/step - loss: -81091.0391 - binary_accuracy: 0.4108 - val_loss: -82418.5859 - val_binary_accuracy: 0.4124
# Epoch 15/18
# 72/72 [==============================] - 0s 4ms/step - loss: -93185.5391 - binary_accuracy: 0.4079 - val_loss: -94341.7188 - val_binary_accuracy: 0.4136
# Epoch 16/18
# 72/72 [==============================] - 0s 4ms/step - loss: -106000.6797 - binary_accuracy: 0.4116 - val_loss: -106451.7031 - val_binary_accuracy: 0.4124
# Epoch 17/18
# 72/72 [==============================] - 0s 4ms/step - loss: -119388.6641 - binary_accuracy: 0.4071 - val_loss: -119530.9375 - val_binary_accuracy: 0.4118
# Epoch 18/18
# 72/72 [==============================] - 0s 4ms/step - loss: -133358.1250 - binary_accuracy: 0.4125 - val_loss: -133249.4219 - val_binary_accuracy: 0.4136
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3758888662008634
# 85/85 [==============================] - 0s 3ms/step - loss: 107547.9766 - binary_accuracy: 0.5318
# 119/119 [==============================] - 0s 2ms/step
# Epoch 1/18
# 72/72 [==============================] - 2s 8ms/step - loss: -68.1358 - binary_accuracy: 0.4033 - val_loss: -217.5834 - val_binary_accuracy: 0.4099
# Epoch 2/18
# 72/72 [==============================] - 0s 6ms/step - loss: -626.3928 - binary_accuracy: 0.4041 - val_loss: -1103.1560 - val_binary_accuracy: 0.4174
# Epoch 3/18
# 72/72 [==============================] - 0s 6ms/step - loss: -2142.7307 - binary_accuracy: 0.4138 - val_loss: -3054.5452 - val_binary_accuracy: 0.4186
# Epoch 4/18
# 72/72 [==============================] - 1s 7ms/step - loss: -4787.8779 - binary_accuracy: 0.4121 - val_loss: -5985.4185 - val_binary_accuracy: 0.4149
# Epoch 5/18
# 72/72 [==============================] - 0s 5ms/step - loss: -8316.4736 - binary_accuracy: 0.4115 - val_loss: -9613.0205 - val_binary_accuracy: 0.4105
# Epoch 6/18
# 72/72 [==============================] - 0s 5ms/step - loss: -12800.2549 - binary_accuracy: 0.4094 - val_loss: -14236.9141 - val_binary_accuracy: 0.4143
# Epoch 7/18
# 72/72 [==============================] - 0s 5ms/step - loss: -18192.7773 - binary_accuracy: 0.4102 - val_loss: -19681.2031 - val_binary_accuracy: 0.4105
# Epoch 8/18
# 72/72 [==============================] - 0s 5ms/step - loss: -24525.0840 - binary_accuracy: 0.4088 - val_loss: -26006.6133 - val_binary_accuracy: 0.4143
# Epoch 9/18
# 72/72 [==============================] - 0s 5ms/step - loss: -31685.4512 - binary_accuracy: 0.4119 - val_loss: -33033.7070 - val_binary_accuracy: 0.4143
# Epoch 10/18
# 72/72 [==============================] - 0s 5ms/step - loss: -39726.6289 - binary_accuracy: 0.4102 - val_loss: -40928.9258 - val_binary_accuracy: 0.4143
# Epoch 11/18
# 72/72 [==============================] - 0s 6ms/step - loss: -48520.8945 - binary_accuracy: 0.4119 - val_loss: -49383.9102 - val_binary_accuracy: 0.4111
# Epoch 12/18
# 72/72 [==============================] - 0s 4ms/step - loss: -57986.7930 - binary_accuracy: 0.4111 - val_loss: -58271.1797 - val_binary_accuracy: 0.4130
# Epoch 13/18
# 72/72 [==============================] - 0s 4ms/step - loss: -68282.8672 - binary_accuracy: 0.4102 - val_loss: -68252.4531 - val_binary_accuracy: 0.4136
# Epoch 14/18
# 72/72 [==============================] - 0s 4ms/step - loss: -79282.7266 - binary_accuracy: 0.4125 - val_loss: -78812.1875 - val_binary_accuracy: 0.4130
# Epoch 15/18
# 72/72 [==============================] - 0s 4ms/step - loss: -91118.6719 - binary_accuracy: 0.4097 - val_loss: -90062.3359 - val_binary_accuracy: 0.4124
# Epoch 16/18
# 72/72 [==============================] - 0s 4ms/step - loss: -103909.3203 - binary_accuracy: 0.4094 - val_loss: -102270.8672 - val_binary_accuracy: 0.4124
# Epoch 17/18
# 72/72 [==============================] - 0s 4ms/step - loss: -117085.4844 - binary_accuracy: 0.4116 - val_loss: -114776.1328 - val_binary_accuracy: 0.4130
# Epoch 18/18
# 72/72 [==============================] - 0s 4ms/step - loss: -130810.2734 - binary_accuracy: 0.4160 - val_loss: -127714.2812 - val_binary_accuracy: 0.4130
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3785957674507225
# 85/85 [==============================] - 0s 3ms/step - loss: 10440.4131 - binary_accuracy: 0.6373
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/11
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 126/126 [==============================] - 2s 5ms/step - loss: -4.0953 - binary_accuracy: 0.3988 - val_loss: -11.0499 - val_binary_accuracy: 0.4093
# Epoch 2/11
# 126/126 [==============================] - 0s 4ms/step - loss: -26.9994 - binary_accuracy: 0.4054 - val_loss: -45.4105 - val_binary_accuracy: 0.4193
# Epoch 3/11
# 126/126 [==============================] - 0s 4ms/step - loss: -77.9587 - binary_accuracy: 0.4122 - val_loss: -107.8427 - val_binary_accuracy: 0.4218
# Epoch 4/11
# 126/126 [==============================] - 0s 4ms/step - loss: -161.1199 - binary_accuracy: 0.4135 - val_loss: -201.7383 - val_binary_accuracy: 0.4262
# Epoch 5/11
# 126/126 [==============================] - 1s 5ms/step - loss: -275.6767 - binary_accuracy: 0.4133 - val_loss: -322.8327 - val_binary_accuracy: 0.4268
# Epoch 6/11
# 126/126 [==============================] - 1s 5ms/step - loss: -419.0747 - binary_accuracy: 0.4158 - val_loss: -469.6630 - val_binary_accuracy: 0.4243
# Epoch 7/11
# 126/126 [==============================] - 1s 6ms/step - loss: -589.4567 - binary_accuracy: 0.4174 - val_loss: -643.8938 - val_binary_accuracy: 0.4237
# Epoch 8/11
# 126/126 [==============================] - 1s 5ms/step - loss: -787.5543 - binary_accuracy: 0.4129 - val_loss: -844.7803 - val_binary_accuracy: 0.4218
# Epoch 9/11
# 126/126 [==============================] - 1s 5ms/step - loss: -1014.5677 - binary_accuracy: 0.4135 - val_loss: -1070.0280 - val_binary_accuracy: 0.4193
# Epoch 10/11
# 126/126 [==============================] - 1s 5ms/step - loss: -1268.4551 - binary_accuracy: 0.4115 - val_loss: -1325.3383 - val_binary_accuracy: 0.4168
# Epoch 11/11
# 126/126 [==============================] - 0s 4ms/step - loss: -1548.4102 - binary_accuracy: 0.4119 - val_loss: -1601.4865 - val_binary_accuracy: 0.4155
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3761448719135356
# 150/150 [==============================] - 0s 3ms/step - loss: -2880.7642 - binary_accuracy: 0.1503
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/11
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 126/126 [==============================] - 1s 5ms/step - loss: -3.9461 - binary_accuracy: 0.4057 - val_loss: -10.2680 - val_binary_accuracy: 0.4155
# Epoch 2/11
# 126/126 [==============================] - 0s 4ms/step - loss: -26.0879 - binary_accuracy: 0.4108 - val_loss: -42.7425 - val_binary_accuracy: 0.4168
# Epoch 3/11
# 126/126 [==============================] - 0s 4ms/step - loss: -76.1545 - binary_accuracy: 0.4133 - val_loss: -103.4300 - val_binary_accuracy: 0.4224
# Epoch 4/11
# 126/126 [==============================] - 0s 4ms/step - loss: -156.1989 - binary_accuracy: 0.4135 - val_loss: -191.9115 - val_binary_accuracy: 0.4243
# Epoch 5/11
# 126/126 [==============================] - 0s 4ms/step - loss: -267.3242 - binary_accuracy: 0.4152 - val_loss: -307.7030 - val_binary_accuracy: 0.4218
# Epoch 6/11
# 126/126 [==============================] - 0s 4ms/step - loss: -407.3116 - binary_accuracy: 0.4140 - val_loss: -449.5279 - val_binary_accuracy: 0.4249
# Epoch 7/11
# 126/126 [==============================] - 0s 4ms/step - loss: -573.8159 - binary_accuracy: 0.4144 - val_loss: -615.8816 - val_binary_accuracy: 0.4193
# Epoch 8/11
# 126/126 [==============================] - 1s 5ms/step - loss: -765.2206 - binary_accuracy: 0.4130 - val_loss: -804.0391 - val_binary_accuracy: 0.4155
# Epoch 9/11
# 126/126 [==============================] - 1s 5ms/step - loss: -980.7027 - binary_accuracy: 0.4111 - val_loss: -1015.2247 - val_binary_accuracy: 0.4118
# Epoch 10/11
# 126/126 [==============================] - 1s 6ms/step - loss: -1219.0820 - binary_accuracy: 0.4089 - val_loss: -1244.3009 - val_binary_accuracy: 0.4130
# Epoch 11/11
# 126/126 [==============================] - 1s 5ms/step - loss: -1479.6227 - binary_accuracy: 0.4107 - val_loss: -1495.8002 - val_binary_accuracy: 0.4143
# 357/357 [==============================] - 1s 2ms/step
# Recall: 0.3723811522329609
# 150/150 [==============================] - 0s 3ms/step - loss: 1191.9292 - binary_accuracy: 0.5403
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/11
# 126/126 [==============================] - 1s 5ms/step - loss: -4.4256 - binary_accuracy: 0.3997 - val_loss: -11.6447 - val_binary_accuracy: 0.4086
# Epoch 2/11
# 126/126 [==============================] - 0s 4ms/step - loss: -28.2316 - binary_accuracy: 0.4072 - val_loss: -47.8329 - val_binary_accuracy: 0.4174
# Epoch 3/11
# 126/126 [==============================] - 0s 4ms/step - loss: -81.5125 - binary_accuracy: 0.4113 - val_loss: -113.4704 - val_binary_accuracy: 0.4212
# Epoch 4/11
# 126/126 [==============================] - 0s 4ms/step - loss: -167.2978 - binary_accuracy: 0.4149 - val_loss: -209.2571 - val_binary_accuracy: 0.4218
# Epoch 5/11
# 126/126 [==============================] - 1s 4ms/step - loss: -285.5593 - binary_accuracy: 0.4144 - val_loss: -336.9014 - val_binary_accuracy: 0.4224
# Epoch 6/11
# 126/126 [==============================] - 0s 4ms/step - loss: -432.9737 - binary_accuracy: 0.4152 - val_loss: -491.3062 - val_binary_accuracy: 0.4199
# Epoch 7/11
# 126/126 [==============================] - 1s 5ms/step - loss: -609.8373 - binary_accuracy: 0.4141 - val_loss: -670.2160 - val_binary_accuracy: 0.4243
# Epoch 8/11
# 126/126 [==============================] - 0s 4ms/step - loss: -814.0146 - binary_accuracy: 0.4146 - val_loss: -880.1787 - val_binary_accuracy: 0.4136
# Epoch 9/11
# 126/126 [==============================] - 0s 4ms/step - loss: -1043.1511 - binary_accuracy: 0.4118 - val_loss: -1105.3079 - val_binary_accuracy: 0.4136
# Epoch 10/11
# 126/126 [==============================] - 0s 4ms/step - loss: -1297.1003 - binary_accuracy: 0.4135 - val_loss: -1360.8561 - val_binary_accuracy: 0.4136
# Epoch 11/11
# 126/126 [==============================] - 0s 4ms/step - loss: -1576.8566 - binary_accuracy: 0.4121 - val_loss: -1632.8563 - val_binary_accuracy: 0.4143
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.37396593828684366
# 150/150 [==============================] - 0s 3ms/step - loss: 201.2035 - binary_accuracy: 0.6363
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/19
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...
# Epoch 6/24
# 87/87 [==============================] - 0s 4ms/step - loss: -66.7789 - binary_accuracy: 0.4155 - val_loss: -75.9002 - val_binary_accuracy: 0.4243
# Epoch 7/24
# 87/87 [==============================] - 0s 4ms/step - loss: -94.8335 - binary_accuracy: 0.4176 - val_loss: -105.0769 - val_binary_accuracy: 0.4218
# Epoch 8/24
# 87/87 [==============================] - 0s 4ms/step - loss: -127.8494 - binary_accuracy: 0.4155 - val_loss: -138.7995 - val_binary_accuracy: 0.4218
# Epoch 9/24
# 87/87 [==============================] - 0s 4ms/step - loss: -165.9033 - binary_accuracy: 0.4144 - val_loss: -177.6142 - val_binary_accuracy: 0.4237
# Epoch 10/24
# 87/87 [==============================] - 0s 4ms/step - loss: -209.4807 - binary_accuracy: 0.4140 - val_loss: -221.4957 - val_binary_accuracy: 0.4205
# Epoch 11/24
# 87/87 [==============================] - 0s 4ms/step - loss: -258.6125 - binary_accuracy: 0.4130 - val_loss: -270.4483 - val_binary_accuracy: 0.4180
# Epoch 12/24
# 87/87 [==============================] - 0s 4ms/step - loss: -313.0935 - binary_accuracy: 0.4130 - val_loss: -324.3987 - val_binary_accuracy: 0.4205
# Epoch 13/24
# 87/87 [==============================] - 0s 4ms/step - loss: -371.8601 - binary_accuracy: 0.4133 - val_loss: -383.7261 - val_binary_accuracy: 0.4168
# Epoch 14/24
# 87/87 [==============================] - 0s 4ms/step - loss: -434.6321 - binary_accuracy: 0.4127 - val_loss: -444.7216 - val_binary_accuracy: 0.4180
# Epoch 15/24
# 87/87 [==============================] - 0s 4ms/step - loss: -501.0587 - binary_accuracy: 0.4130 - val_loss: -510.2123 - val_binary_accuracy: 0.4155
# Epoch 16/24
# 87/87 [==============================] - 0s 4ms/step - loss: -571.9153 - binary_accuracy: 0.4118 - val_loss: -579.0310 - val_binary_accuracy: 0.4130
# Epoch 17/24
# 87/87 [==============================] - 0s 4ms/step - loss: -646.5779 - binary_accuracy: 0.4107 - val_loss: -653.0240 - val_binary_accuracy: 0.4143
# Epoch 18/24
# 87/87 [==============================] - 0s 4ms/step - loss: -725.2230 - binary_accuracy: 0.4104 - val_loss: -728.9327 - val_binary_accuracy: 0.4143
# Epoch 19/24
# 87/87 [==============================] - 0s 4ms/step - loss: -806.8677 - binary_accuracy: 0.4102 - val_loss: -809.1857 - val_binary_accuracy: 0.4143
# Epoch 20/24
# 87/87 [==============================] - 0s 4ms/step - loss: -891.9183 - binary_accuracy: 0.4116 - val_loss: -891.1631 - val_binary_accuracy: 0.4149
# Epoch 21/24
# 87/87 [==============================] - 0s 5ms/step - loss: -980.9013 - binary_accuracy: 0.4107 - val_loss: -978.5449 - val_binary_accuracy: 0.4149
# Epoch 22/24
# 87/87 [==============================] - 0s 5ms/step - loss: -1072.7646 - binary_accuracy: 0.4115 - val_loss: -1067.4447 - val_binary_accuracy: 0.4161
# Epoch 23/24
# 87/87 [==============================] - 0s 5ms/step - loss: -1168.0933 - binary_accuracy: 0.4108 - val_loss: -1158.8082 - val_binary_accuracy: 0.4143
# Epoch 24/24
# 87/87 [==============================] - 1s 6ms/step - loss: -1266.1101 - binary_accuracy: 0.4104 - val_loss: -1254.2670 - val_binary_accuracy: 0.4149
# 357/357 [==============================] - 1s 2ms/step
# Recall: 0.37627693741802576
# 103/103 [==============================] - 0s 4ms/step - loss: 173.5769 - binary_accuracy: 0.6367
# 119/119 [==============================] - 0s 2ms/step
# Epoch 1/22
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 54/54 [==============================] - 1s 7ms/step - loss: -10099.4102 - binary_accuracy: 0.3858 - val_loss: -34073.0000 - val_binary_accuracy: 0.3930
# Epoch 2/22
# 54/54 [==============================] - 0s 4ms/step - loss: -103165.2891 - binary_accuracy: 0.3877 - val_loss: -182630.7500 - val_binary_accuracy: 0.3930
# Epoch 3/22
# 54/54 [==============================] - 0s 4ms/step - loss: -329625.0000 - binary_accuracy: 0.3877 - val_loss: -458544.6562 - val_binary_accuracy: 0.3930
# Epoch 4/22
# 54/54 [==============================] - 0s 4ms/step - loss: -699623.8125 - binary_accuracy: 0.3877 - val_loss: -870898.2500 - val_binary_accuracy: 0.3930
# Epoch 5/22
# 54/54 [==============================] - 0s 4ms/step - loss: -1211741.2500 - binary_accuracy: 0.3877 - val_loss: -1418983.3750 - val_binary_accuracy: 0.3930
# Epoch 6/22
# 54/54 [==============================] - 0s 4ms/step - loss: -1852537.6250 - binary_accuracy: 0.3877 - val_loss: -2067410.8750 - val_binary_accuracy: 0.3930
# Epoch 7/22
# 54/54 [==============================] - 0s 4ms/step - loss: -2627549.7500 - binary_accuracy: 0.3877 - val_loss: -2863815.5000 - val_binary_accuracy: 0.3930
# Epoch 8/22
# 54/54 [==============================] - 0s 4ms/step - loss: -3541076.0000 - binary_accuracy: 0.3877 - val_loss: -3752146.7500 - val_binary_accuracy: 0.3930
# Epoch 9/22
# 54/54 [==============================] - 0s 5ms/step - loss: -4570554.5000 - binary_accuracy: 0.3877 - val_loss: -4787431.5000 - val_binary_accuracy: 0.3930
# Epoch 10/22
# 54/54 [==============================] - 0s 4ms/step - loss: -5734775.0000 - binary_accuracy: 0.3877 - val_loss: -5920752.0000 - val_binary_accuracy: 0.3930
# Epoch 11/22
# 54/54 [==============================] - 0s 5ms/step - loss: -7013979.0000 - binary_accuracy: 0.3877 - val_loss: -7180273.5000 - val_binary_accuracy: 0.3930
# Epoch 12/22
# 54/54 [==============================] - 0s 4ms/step - loss: -8403473.0000 - binary_accuracy: 0.3877 - val_loss: -8527425.0000 - val_binary_accuracy: 0.3930
# Epoch 13/22
# 54/54 [==============================] - 0s 4ms/step - loss: -9926496.0000 - binary_accuracy: 0.3877 - val_loss: -9978360.0000 - val_binary_accuracy: 0.3930
# Epoch 14/22
# 54/54 [==============================] - 0s 4ms/step - loss: -11577075.0000 - binary_accuracy: 0.3877 - val_loss: -11574959.0000 - val_binary_accuracy: 0.3930
# Epoch 15/22
# 54/54 [==============================] - 0s 5ms/step - loss: -13329413.0000 - binary_accuracy: 0.3877 - val_loss: -13251076.0000 - val_binary_accuracy: 0.3930
# Epoch 16/22
# 54/54 [==============================] - 0s 4ms/step - loss: -15197039.0000 - binary_accuracy: 0.3877 - val_loss: -15040160.0000 - val_binary_accuracy: 0.3930
# Epoch 17/22
# 54/54 [==============================] - 0s 5ms/step - loss: -17157180.0000 - binary_accuracy: 0.3877 - val_loss: -16912468.0000 - val_binary_accuracy: 0.3930
# Epoch 18/22
# 54/54 [==============================] - 0s 4ms/step - loss: -19244520.0000 - binary_accuracy: 0.3877 - val_loss: -18868806.0000 - val_binary_accuracy: 0.3930
# Epoch 19/22
# 54/54 [==============================] - 0s 4ms/step - loss: -21402598.0000 - binary_accuracy: 0.3877 - val_loss: -20960682.0000 - val_binary_accuracy: 0.3930
# Epoch 20/22
# 54/54 [==============================] - 0s 4ms/step - loss: -23687578.0000 - binary_accuracy: 0.3877 - val_loss: -23100368.0000 - val_binary_accuracy: 0.3930
# Epoch 21/22
# 54/54 [==============================] - 0s 4ms/step - loss: -26054628.0000 - binary_accuracy: 0.3877 - val_loss: -25335474.0000 - val_binary_accuracy: 0.3930
# Epoch 22/22
# 54/54 [==============================] - 0s 5ms/step - loss: -28519154.0000 - binary_accuracy: 0.3877 - val_loss: -27712832.0000 - val_binary_accuracy: 0.3930
# 357/357 [==============================] - 1s 2ms/step
# Recall: 0.3333333333333333
# 64/64 [==============================] - 0s 5ms/step - loss: -46955216.0000 - binary_accuracy: 0.0895
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/22
# 54/54 [==============================] - 1s 7ms/step - loss: -9633.6611 - binary_accuracy: 0.3946 - val_loss: -36142.0859 - val_binary_accuracy: 0.4161
# Epoch 2/22
# 54/54 [==============================] - 0s 4ms/step - loss: -103194.1562 - binary_accuracy: 0.4071 - val_loss: -196032.7969 - val_binary_accuracy: 0.4111
# Epoch 3/22
# 54/54 [==============================] - 0s 4ms/step - loss: -342957.4688 - binary_accuracy: 0.4085 - val_loss: -503912.9688 - val_binary_accuracy: 0.4143
# Epoch 4/22
# 54/54 [==============================] - 0s 5ms/step - loss: -731048.1875 - binary_accuracy: 0.4072 - val_loss: -952344.4375 - val_binary_accuracy: 0.4030
# Epoch 5/22
# 54/54 [==============================] - 0s 5ms/step - loss: -1261642.2500 - binary_accuracy: 0.4107 - val_loss: -1546205.2500 - val_binary_accuracy: 0.4080
# Epoch 6/22
# 54/54 [==============================] - 0s 5ms/step - loss: -1943808.5000 - binary_accuracy: 0.4104 - val_loss: -2269673.0000 - val_binary_accuracy: 0.4068
# Epoch 7/22
# 54/54 [==============================] - 0s 5ms/step - loss: -2759909.7500 - binary_accuracy: 0.4104 - val_loss: -3138536.2500 - val_binary_accuracy: 0.4149
# Epoch 8/22
# 54/54 [==============================] - 0s 4ms/step - loss: -3710132.7500 - binary_accuracy: 0.4125 - val_loss: -4146416.0000 - val_binary_accuracy: 0.4111
# Epoch 9/22
# 54/54 [==============================] - 0s 4ms/step - loss: -4804548.5000 - binary_accuracy: 0.4110 - val_loss: -5258240.0000 - val_binary_accuracy: 0.4093
# Epoch 10/22
# 54/54 [==============================] - 0s 4ms/step - loss: -6023730.0000 - binary_accuracy: 0.4105 - val_loss: -6510625.5000 - val_binary_accuracy: 0.4124
# Epoch 11/22
# 54/54 [==============================] - 0s 4ms/step - loss: -7381693.5000 - binary_accuracy: 0.4132 - val_loss: -7901341.5000 - val_binary_accuracy: 0.4268
# Epoch 12/22
# 54/54 [==============================] - 0s 4ms/step - loss: -8878427.0000 - binary_accuracy: 0.4113 - val_loss: -9391535.0000 - val_binary_accuracy: 0.4105
# Epoch 13/22
# 54/54 [==============================] - 0s 5ms/step - loss: -10487273.0000 - binary_accuracy: 0.4113 - val_loss: -11012251.0000 - val_binary_accuracy: 0.4099
# Epoch 14/22
# 54/54 [==============================] - 0s 5ms/step - loss: -12216021.0000 - binary_accuracy: 0.4127 - val_loss: -12741199.0000 - val_binary_accuracy: 0.4111
# Epoch 15/22
# 54/54 [==============================] - 0s 4ms/step - loss: -14055421.0000 - binary_accuracy: 0.4100 - val_loss: -14599972.0000 - val_binary_accuracy: 0.4124
# Epoch 16/22
# 54/54 [==============================] - 0s 4ms/step - loss: -16022962.0000 - binary_accuracy: 0.4119 - val_loss: -16553382.0000 - val_binary_accuracy: 0.4174
# Epoch 17/22
# 54/54 [==============================] - 0s 5ms/step - loss: -18104156.0000 - binary_accuracy: 0.4149 - val_loss: -18620260.0000 - val_binary_accuracy: 0.4130
# Epoch 18/22
# 54/54 [==============================] - 0s 4ms/step - loss: -20250358.0000 - binary_accuracy: 0.4161 - val_loss: -20788846.0000 - val_binary_accuracy: 0.4136
# Epoch 19/22
# 54/54 [==============================] - 0s 4ms/step - loss: -22551076.0000 - binary_accuracy: 0.4149 - val_loss: -23035204.0000 - val_binary_accuracy: 0.4149
# Epoch 20/22
# 54/54 [==============================] - 0s 5ms/step - loss: -24930248.0000 - binary_accuracy: 0.4149 - val_loss: -25403200.0000 - val_binary_accuracy: 0.4205
# Epoch 21/22
# 54/54 [==============================] - 0s 4ms/step - loss: -27416634.0000 - binary_accuracy: 0.4138 - val_loss: -27860494.0000 - val_binary_accuracy: 0.4124
# Epoch 22/22
# 54/54 [==============================] - 0s 4ms/step - loss: -30001168.0000 - binary_accuracy: 0.4138 - val_loss: -30411310.0000 - val_binary_accuracy: 0.4237
# 357/357 [==============================] - 1s 2ms/step
# Recall: 0.3919337946146478
# 64/64 [==============================] - 0s 5ms/step - loss: 23655324.0000 - binary_accuracy: 0.5405
# 119/119 [==============================] - 0s 1ms/step
# Epoch 1/22
# 54/54 [==============================] - 1s 6ms/step - loss: -8797.8232 - binary_accuracy: 0.4018 - val_loss: -32476.2402 - val_binary_accuracy: 0.4205
# Epoch 2/22
# 54/54 [==============================] - 0s 5ms/step - loss: -93113.9141 - binary_accuracy: 0.4143 - val_loss: -174920.0312 - val_binary_accuracy: 0.4143
# Epoch 3/22
# 54/54 [==============================] - 0s 5ms/step - loss: -314446.9062 - binary_accuracy: 0.4057 - val_loss: -454186.4062 - val_binary_accuracy: 0.4099
# Epoch 4/22
# 54/54 [==============================] - 0s 4ms/step - loss: -680198.0000 - binary_accuracy: 0.4072 - val_loss: -873089.5000 - val_binary_accuracy: 0.4161
# Epoch 5/22
# 54/54 [==============================] - 0s 4ms/step - loss: -1185314.2500 - binary_accuracy: 0.4097 - val_loss: -1417577.3750 - val_binary_accuracy: 0.4105
# Epoch 6/22
# 54/54 [==============================] - 0s 5ms/step - loss: -1831251.5000 - binary_accuracy: 0.4107 - val_loss: -2105424.5000 - val_binary_accuracy: 0.4149
# Epoch 7/22
# 54/54 [==============================] - 0s 4ms/step - loss: -2622493.0000 - binary_accuracy: 0.4141 - val_loss: -2920435.7500 - val_binary_accuracy: 0.4080
# Epoch 8/22
# 54/54 [==============================] - 0s 4ms/step - loss: -3543539.2500 - binary_accuracy: 0.4086 - val_loss: -3864608.7500 - val_binary_accuracy: 0.4136
# Epoch 9/22
# 54/54 [==============================] - 0s 4ms/step - loss: -4596206.5000 - binary_accuracy: 0.4102 - val_loss: -4910670.5000 - val_binary_accuracy: 0.4143
# Epoch 10/22
# 54/54 [==============================] - 0s 5ms/step - loss: -5777065.0000 - binary_accuracy: 0.4125 - val_loss: -6104206.5000 - val_binary_accuracy: 0.4136
# Epoch 11/22
# 54/54 [==============================] - 0s 5ms/step - loss: -7073794.0000 - binary_accuracy: 0.4110 - val_loss: -7390210.5000 - val_binary_accuracy: 0.4161
# Epoch 12/22
# 54/54 [==============================] - 0s 5ms/step - loss: -8505654.0000 - binary_accuracy: 0.4122 - val_loss: -8810784.0000 - val_binary_accuracy: 0.4205
# Epoch 13/22
# 54/54 [==============================] - 0s 5ms/step - loss: -10048681.0000 - binary_accuracy: 0.4091 - val_loss: -10326531.0000 - val_binary_accuracy: 0.4143
# Epoch 14/22
# 54/54 [==============================] - 0s 4ms/step - loss: -11680530.0000 - binary_accuracy: 0.4129 - val_loss: -11938512.0000 - val_binary_accuracy: 0.4180
# Epoch 15/22
# 54/54 [==============================] - 0s 4ms/step - loss: -13452655.0000 - binary_accuracy: 0.4118 - val_loss: -13673878.0000 - val_binary_accuracy: 0.4174
# Epoch 16/22
# 54/54 [==============================] - 0s 4ms/step - loss: -15333429.0000 - binary_accuracy: 0.4155 - val_loss: -15499845.0000 - val_binary_accuracy: 0.4136
# Epoch 17/22
# 54/54 [==============================] - 0s 4ms/step - loss: -17317820.0000 - binary_accuracy: 0.4132 - val_loss: -17429232.0000 - val_binary_accuracy: 0.4161
# Epoch 18/22
# 54/54 [==============================] - 0s 4ms/step - loss: -19396248.0000 - binary_accuracy: 0.4149 - val_loss: -19460716.0000 - val_binary_accuracy: 0.4143
# Epoch 19/22
# 54/54 [==============================] - 0s 4ms/step - loss: -21572860.0000 - binary_accuracy: 0.4135 - val_loss: -21577118.0000 - val_binary_accuracy: 0.4174
# Epoch 20/22
# 54/54 [==============================] - 0s 5ms/step - loss: -23872588.0000 - binary_accuracy: 0.4152 - val_loss: -23786712.0000 - val_binary_accuracy: 0.4136
# Epoch 21/22
# 54/54 [==============================] - 0s 4ms/step - loss: -26288616.0000 - binary_accuracy: 0.4140 - val_loss: -26098254.0000 - val_binary_accuracy: 0.4174
# Epoch 22/22
# 54/54 [==============================] - 0s 5ms/step - loss: -28766316.0000 - binary_accuracy: 0.4136 - val_loss: -28539784.0000 - val_binary_accuracy: 0.4174
# 357/357 [==============================] - 1s 1ms/step
# Recall: 0.3877495025316775
# 64/64 [==============================] - 0s 3ms/step - loss: 3951871.2500 - binary_accuracy: 0.6313
# 119/119 [==============================] - 0s 1ms/step
# Melhores hiperparâmetros: {'batch_size': 120, 'learning_rate': 0.1, 'num_epochs': 22, 'num_hidden_units': 228}
# Melhor Recall: 0.45768722466960354
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### 8.2.5 - RNN com os Melhores Hiperparâmetros

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
import tensorflow as tf

# Dados de entrada e rótulos
X_test = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2', 'comentário', 'resposta', 'marcação'], axis=1))
y_test = np.array(dfrnn_balanced['sentimento2'])

# Divisão em conjunto de treinamento e teste
X_train, X_val, y_train, y_val = train_test_split(X_test, y_test, test_size=0.3, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Normalização dos dados
X_train_mean = X_train.mean(axis=0)
X_train_std = X_train.std(axis=0)
X_train = (X_train - X_train_mean) / X_train_std
X_val = (X_val - X_train_mean) / X_train_std
X_test = (X_test - X_train_mean) / X_train_std

# Função para criar o modelo RNN com hiperparâmetros otimizados
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(units=125, activation='relu'),
        tf.keras.layers.Dense(units=1, activation='sigmoid')
    ])

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001),
                  loss=tf.losses.BinaryCrossentropy(),
                  metrics=[tf.metrics.BinaryAccuracy()])

    model.fit(X_train, y_train, epochs=14, batch_size=47,
              validation_data=(X_val, y_val))

    return model

# Criação do modelo com hiperparâmetros otimizados
best_model = create_model()

# Previsões do modelo com hiperparâmetros otimizados
y_pred_best_model = best_model.predict(X_test)
y_pred_best_model = np.round(y_pred_best_model).flatten()

# Cálculo do recall geral
recall_best_model = recall_score(y_test, y_pred_best_model, average='weighted')

print('Recall do Melhor Modelo:', recall_best_model)
# Out:
# Epoch 1/14
# 136/136 [==============================] - 2s 6ms/step - loss: -4.1972 - binary_accuracy: 0.4003 - val_loss: -10.4454 - val_binary_accuracy: 0.4130
# Epoch 2/14
# 136/136 [==============================] - 1s 5ms/step - loss: -25.1452 - binary_accuracy: 0.4088 - val_loss: -40.6305 - val_binary_accuracy: 0.4193
# Epoch 3/14
# 136/136 [==============================] - 1s 4ms/step - loss: -69.3024 - binary_accuracy: 0.4125 - val_loss: -93.3380 - val_binary_accuracy: 0.4237
# Epoch 4/14
# 136/136 [==============================] - 1s 4ms/step - loss: -138.2801 - binary_accuracy: 0.4143 - val_loss: -170.0227 - val_binary_accuracy: 0.4230
# Epoch 5/14
# 136/136 [==============================] - 1s 5ms/step - loss: -232.5583 - binary_accuracy: 0.4158 - val_loss: -269.3423 - val_binary_accuracy: 0.4199
# Epoch 6/14
# 136/136 [==============================] - 0s 4ms/step - loss: -350.0424 - binary_accuracy: 0.4154 - val_loss: -389.2177 - val_binary_accuracy: 0.4218
# Epoch 7/14
# 136/136 [==============================] - 0s 3ms/step - loss: -490.5142 - binary_accuracy: 0.4166 - val_loss: -530.0813 - val_binary_accuracy: 0.4186
# Epoch 8/14
# 136/136 [==============================] - 0s 3ms/step - loss: -651.7634 - binary_accuracy: 0.4133 - val_loss: -691.1133 - val_binary_accuracy: 0.4193
# Epoch 9/14
# 136/136 [==============================] - 0s 3ms/step - loss: -831.9399 - binary_accuracy: 0.4133 - val_loss: -869.3008 - val_binary_accuracy: 0.4136
# Epoch 10/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1030.3785 - binary_accuracy: 0.4111 - val_loss: -1062.4243 - val_binary_accuracy: 0.4130
# Epoch 11/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1246.7372 - binary_accuracy: 0.4125 - val_loss: -1270.1898 - val_binary_accuracy: 0.4130
# Epoch 12/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1480.6913 - binary_accuracy: 0.4116 - val_loss: -1497.9706 - val_binary_accuracy: 0.4149
# Epoch 13/14
# 136/136 [==============================] - 0s 3ms/step - loss: -1732.5984 - binary_accuracy: 0.4113 - val_loss: -1742.2472 - val_binary_accuracy: 0.4143
# Epoch 14/14
# 136/136 [==============================] - 0s 3ms/step - loss: -2002.7721 - binary_accuracy: 0.4113 - val_loss: -1999.4934 - val_binary_accuracy: 0.4130
# 357/357 [==============================] - 1s 1ms/step
# Recall do Melhor Modelo: 0.41690757774857645

# %% [markdown]
# ### 8.3.Naive Bayes - Três categorias e sem balanceamento

# %% [markdown]
# #### 8.3.1 - Definição da Função

# %%
# Função de treinamento Naive Bayes
def classification_naive_bayes(X,Y):
    # Divisão do DataFrame em conjuntos de treinamento e teste
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

    # Criação de uma instância do classificador Naive Bayes Gaussiano
    gnb = GaussianNB()

    # Treinamento do classificador utilizando os dados de treinamento
    gnb.fit(X_train, y_train)

    # Previsões nos dados de teste
    y_pred = gnb.predict(X_test)

    # Calculo da precisão do classificador
    accuracy = accuracy_score(y_test, y_pred)

    # Retorno da acurácia, y_test, y_pred
    return accuracy, y_test, y_pred

# %% [markdown]
# #### 8.3.2 - Teste da Função

# %%
# Balanceamento dos dados
df_negativo = dfoneHot[dfoneHot['sentimento2'] == 0]
df_positive = dfoneHot[dfoneHot['sentimento2'] == 1]
df_neutral = dfoneHot[dfoneHot['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_negative, df_positive, df_neutral])

# Separando os dados em X e y (balanceados)
X = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2', 'comentário', 'resposta', 'marcação'], axis=1))
Y = np.array(dfrnn_balanced['sentimento2'])

# Chamada da função com os dados balanceados
accuracy, y_test, y_pred = classification_naive_bayes(X, Y)

# Imprime a acurácia
print(accuracy)
# Out:
# 0.5004379562043796

# %% [markdown]
# A acurácia foi utilizada para avaliar o desempenho do modelo Naive Bayes. O resultado representa a proporção de instâncias classificadas corretamente em relação ao total de instâncias.

# %% [markdown]
# #### 8.3.3 - Visualização da Matriz de Confusão da Modelagem de Naive Bayes

# %%
# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Plot da matriz de confusão
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

# Configurações do gráfico
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=['Negativo', 'Positivo', 'Neutro'],
       yticklabels=['Negativo', 'Positivo', 'Neutro'],
       title='Matriz de Confusão',
       ylabel='Valor Verdadeiro',
       xlabel='Valor Previsto')

# Adiciona os valores nas células da matriz
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

# Mostra o gráfico
plt.show()

# %% [markdown]
# #### 8.3.4 - Hiperparâmetros com Random Search do Naive Bayes

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.naive_bayes import GaussianNB
from scipy.stats import uniform
from sklearn.metrics import recall_score

# Função de treinamento Naive Bayes
def classification_naive_bayes(X, Y):
    # Divisão do DataFrame em conjuntos de treinamento e teste
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

    # Definindo os hiperparâmetros a serem otimizados
    param_dist = {'var_smoothing': uniform(1e-20, 1e-2)}  # Intervalo para o hiperparâmetro var_smoothing

    # Criação do classificador Naive Bayes
    clf = GaussianNB()

    # Realização da busca aleatória com validação cruzada
    random_search = RandomizedSearchCV(clf, param_distributions=param_dist, cv=5, n_iter=10, random_state=42)
    random_search.fit(X_train, y_train)

    # Melhores hiperparâmetros encontrados
    best_params = random_search.best_params_
    print("Melhores hiperparâmetros:", best_params)

    # Treinamento do classificador utilizando os melhores hiperparâmetros
    clf = GaussianNB(**best_params)
    clf.fit(X_train, y_train)

    # Previsões nos dados de teste
    y_pred = clf.predict(X_test)

    # Cálculo do recall
    recall = recall_score(y_test, y_pred, average='weighted')

    # Retorno do recall, y_test, y_pred
    return recall, y_test, y_pred

# Balanceamento dos dados
df_negative = dfoneHot[dfoneHot['sentimento2'] == 0]
df_positive = dfoneHot[dfoneHot['sentimento2'] == 1]
df_neutral = dfoneHot[dfoneHot['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_negative, df_positive, df_neutral])

# Separando os dados em X e y (balanceados)
X = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2', 'comentário', 'resposta', 'marcação'], axis=1))
Y = np.array(dfrnn_balanced['sentimento2'])

# Chamada da função com os dados balanceados
recall, y_test, y_pred = classification_naive_bayes(X, Y)

# Imprime o recall
print("Recall:", recall)
# Out:
# Melhores hiperparâmetros: {'var_smoothing': 0.0005808361216819946}
# Recall: 0.4992700729927007

# %% [markdown]
# #### 8.3.5 - Aplicando o hiperparâmetro

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import recall_score
from imblearn.over_sampling import RandomOverSampler

# Balanceamento dos dados
df_negative = dfoneHot[dfoneHot['sentimento2'] == 0]
df_positive = dfoneHot[dfoneHot['sentimento2'] == 1]
df_neutral = dfoneHot[dfoneHot['sentimento2'] == 2]

# Realizar oversampling
ros = RandomOverSampler(random_state=42)
X_resampled, Y_resampled = ros.fit_resample(X, Y)

# Divisão dos dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X_resampled, Y_resampled, test_size=0.3, random_state=42)

# Criação do classificador Naive Bayes com o melhor hiperparâmetro
clf = GaussianNB(var_smoothing=0.0005808361216819946)

# Treinamento do classificador
clf.fit(X_train, y_train)

# Previsões nos dados de teste
y_pred = clf.predict(X_test)

# Cálculo do recall
recall = recall_score(y_test, y_pred, average='macro')

# Imprimir o resultado do recall
print("Recall:", recall)
# Out:
# Recall: 0.5358134240535136

# %% [markdown]
# ### 8.4 - SVM - Três categorias e sem balanceamento

# %% [markdown]
# #### 8.4.1 - Definição da Função

# %%
def classification_svm(x, y):
  # Dividir o conjunto de dados em treinamento e teste
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

  # Criar e treinar o modelo SVM
  modelo_svm = SVC()
  modelo_svm.fit(x_train, y_train)

  # Fazer previsões no conjunto de teste
  y_pred = modelo_svm.predict(x_test)

  # Calcular a acurácia
  acuracia = accuracy_score(y_test, y_pred)
  print("Acurácia:", acuracia)

  # Calcular o F-score
  fscore = f1_score(y_test, y_pred, average='macro')
  print("F-score:", fscore)

  # Calcular o recall
  recall = recall_score(y_test, y_pred, average='macro')
  print("Recall:", recall)

  # Realizar validação cruzada
  scores = cross_val_score(modelo_svm, x, y, cv=5)  # cv define o número de dobras (folds)
  print("Acurácia da Validação Cruzada:", np.mean(scores))

  return modelo_svm, y_test, y_pred

# %% [markdown]
# #### 8.4.2 - Teste da Função

# %%
# Balanceamento dos dados
df_negativo = dfoneHot[dfoneHot['sentimento2'] == 0]
df_positive = dfoneHot[dfoneHot['sentimento2'] == 1]
df_neutral = dfoneHot[dfoneHot['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_negative, df_positive, df_neutral])

# Definir os arrays x e y
x = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2', 'comentário', 'resposta', 'marcação'], axis=1))
y = np.array(dfrnn_balanced['sentimento2'])

model, y_test, y_pred = classification_svm(x, y)
# Out:
# Acurácia: 0.6037956204379562
# F-score: 0.585549218791849
# Recall: 0.5797738449355753
# Acurácia da Validação Cruzada: 0.6140166447656592

# %% [markdown]
# #### 8.4.3 - Matriz de confusão

# %%
# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Plot da matriz de confusão
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

# Configurações do gráfico
classes = ['Negativo', 'Positivo', 'Neutro']
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes,
       yticklabels=classes,
       title='Matriz de Confusão',
       ylabel='Valor Verdadeiro',
       xlabel='Valor Previsto')

# Adiciona os valores nas células da matriz
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

# Mostra o gráfico
plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import make_scorer, recall_score
from imblearn.over_sampling import RandomOverSampler

def classification_svm(x, y):
    # Balanceamento dos dados
    df_negative = dfoneHot[dfoneHot['sentimento2'] == 0]
    df_positive = dfoneHot[dfoneHot['sentimento2'] == 1]
    df_neutral = dfoneHot[dfoneHot['sentimento2'] == 2]

    # Realizar oversampling
    ros = RandomOverSampler(random_state=42)
    x_resampled, y_resampled = ros.fit_resample(x, y)

    # Dividir o conjunto de dados em treinamento e teste
    x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

    # Definir os hiperparâmetros a serem testados
    param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}

    # Criar o modelo SVM
    svm = SVC()

    # Criar o scorer utilizando o recall como métrica
    scorer = make_scorer(recall_score, average='macro')

    # Realizar a busca de grade com validação cruzada
    grid_search = GridSearchCV(svm, param_grid=param_grid, scoring=scorer, cv=5)
    grid_search.fit(x_train, y_train)

    # Melhores hiperparâmetros encontrados
    best_params = grid_search.best_params_
    print("Melhores hiperparâmetros:", best_params)

    # Acessar o valor específico do melhor hiperparâmetro
    best_C = best_params['C']
    print("Melhor valor de C:", best_C)

    # Treinar o modelo SVM utilizando os melhores hiperparâmetros
    modelo_svm = SVC(**best_params)
    modelo_svm.fit(x_train, y_train)

    # Fazer previsões no conjunto de teste
    y_pred = modelo_svm.predict(x_test)

    # Calcular o recall
    recall = recall_score(y_test, y_pred, average='macro')

    # Imprimir o resultado do recall
    print("Recall:", recall)

    return modelo_svm, y_test, y_pred

# %%
print("Melhores hiperparâmetros:", best_params)
# Out:
# Melhores hiperparâmetros: {'batch_size': 120, 'learning_rate': 0.1, 'num_epochs': 22, 'num_hidden_units': 228}

# %% [markdown]
# #### 8.4.4 - Aplicando os Melhores Hiperparâmetros

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import make_scorer, recall_score
from imblearn.over_sampling import RandomOverSampler

def classification_svm(x, y):
    # Balanceamento dos dados
    df_negative = dfoneHot[dfoneHot['sentimento2'] == 0]
    df_positive = dfoneHot[dfoneHot['sentimento2'] == 1]
    df_neutral = dfoneHot[dfoneHot['sentimento2'] == 2]

    # Realizar oversampling
    ros = RandomOverSampler(random_state=42)
    x_resampled, y_resampled = ros.fit_resample(x, y)

    # Dividir o conjunto de dados em treinamento e teste
    x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.3, random_state=42)

    # Definir os hiperparâmetros a serem testados
    param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}

    # Criar o modelo SVM
    svm = SVC()

    # Criar o scorer utilizando o recall como métrica
    scorer = make_scorer(recall_score, average='macro')

    # Realizar a busca de grade com validação cruzada
    grid_search = GridSearchCV(svm, param_grid=param_grid, scoring=scorer, cv=5)
    grid_search.fit(x_train, y_train)

    # Melhores hiperparâmetros encontrados
    best_params = grid_search.best_params_
    print("Melhores hiperparâmetros:", best_params)

    # Acessar o valor específico do melhor hiperparâmetro
    best_C = best_params['C']
    print("Melhor valor de C:", best_C)

    # Treinar o modelo SVM utilizando os melhores hiperparâmetros
    modelo_svm = SVC(**best_params)
    modelo_svm.fit(x_train, y_train)

    # Fazer previsões no conjunto de teste
    y_pred = modelo_svm.predict(x_test)

    # Calcular o recall
    recall = recall_score(y_test, y_pred, average='macro')

    # Calcular a porcentagem do recall
    recall_percent = recall * 100

    # Imprimir o resultado do recall em porcentagem
    print("Recall: {:.2f}%".format(recall_percent))

    return modelo_svm, y_test, y_pred

# Chamar a função com os dados balanceados
classification_svm(X, Y)
# Out:
# Melhores hiperparâmetros: {'C': 100}
# Melhor valor de C: 100
# Recall: 65.39%
# (SVC(C=100), array([0, 2, 2, ..., 1, 1, 0]), array([0, 2, 2, ..., 1, 1, 0]))

# %% [markdown]
# ### 8.5 - Random forest - Três categorias e sem balanceamento

# %% [markdown]
# #### 8.5.1 - Definição da função

# %%
def classification_random_forest(x, y):
  # Dividir o conjunto de dados em treinamento e teste
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

  # Criar e treinar o modelo Random Forest
  modelo_rf = RandomForestClassifier()
  modelo_rf.fit(x_train, y_train)

  # Fazer previsões no conjunto de teste
  y_pred = modelo_rf.predict(x_test)

  # Calcular a acurácia
  acuracia = accuracy_score(y_test, y_pred)
  print("Acurácia:", acuracia)

  # Calcular o F-score
  fscore = f1_score(y_test, y_pred, average='macro')
  print("F-score:", fscore)

  # Calcular o recall
  recall = recall_score(y_test, y_pred, average='macro')
  print("Recall:", recall)

  # Realizar validação cruzada
  scores = cross_val_score(modelo_rf, x, y, cv=5)  # cv define o número de dobras (folds)
  print("Acurácia da Validação Cruzada:", np.mean(scores))

  return modelo_rf, y_test, y_pred

# %% [markdown]
# #### 8.5.2 - Teste da função

# %%
# Balanceamento dos dados
df_negativo = dfoneHot[dfoneHot['sentimento2'] == 0]
df_positive = dfoneHot[dfoneHot['sentimento2'] == 1]
df_neutral = dfoneHot[dfoneHot['sentimento2'] == 2]

dfrnn_balanced = pd.concat([df_negative, df_positive, df_neutral])

# Definir os arrays x e y
x = np.array(dfrnn_balanced.drop(['Frase', 'sentimento2', 'comentário', 'resposta', 'marcação'], axis=1))
y = np.array(dfrnn_balanced['sentimento2'])

model, y_test, y_pred = classification_random_forest(x, y)
# Out:
# Acurácia: 0.6616058394160584
# F-score: 0.6470530761602004
# Recall: 0.6430922695868967
# Acurácia da Validação Cruzada: 0.6415243101182654

# %% [markdown]
# #### 8.5.3 - Matriz de confusão

# %%
# Cálculo da matriz de confusão
cm = confusion_matrix(y_test, y_pred)

# Plot da matriz de confusão
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

# Configurações do gráfico
classes = ['Negativo', 'Positivo', 'Neutro']
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes,
       yticklabels=classes,
       title='Matriz de Confusão',
       ylabel='Valor Verdadeiro',
       xlabel='Valor Previsto')

# Adiciona os valores nas células da matriz
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

# Mostra o gráfico
plt.show()

# %% [markdown]
# ### 8.6 - Conclusão
# Por fim, foi possível concluir que após a aplicação das novas features não houve melhora dos modelos, mas sim a piora das métricas. Por isso concluímos que vamos manter utilizando as features principais, sendo elas "frase" e "sentimento2".

# %% [markdown]
# ## Gráficos de disperção de sentimento X tipo interação e gráficos comparando os resultados dos modelos (de barra)

# %%
# Valores de revocação para cada modelo
acuracia = [60.34, 66.81, 76.93, 59.16, 77.00, 70.37]

# Rótulos dos modelos
modelos = ['Naive Bayes', 'RNN', 'Random Forest', 'Regressão Logística', 'Embedding Layer', 'SVM']

# Paleta de cores suaves
cores = sns.color_palette('pastel')

# Criar o gráfico de barras
plt.figure(figsize=(12, 6))
plt.bar(modelos, acuracia, color=cores)

# Adicionar os valores de revocação acima das barras
for i in range(len(modelos)):
    plt.text(i, acuracia[i], f'{acuracia[i]:.2f}%', ha='center', va='bottom')

plt.xlabel('Modelos')
plt.ylabel('Acurácia')
plt.title('Comparação de Acurácia entre os Modelos')

# Ajustar os limites dos eixos
plt.ylim(0, 100)

# Mostrar o gráfico
plt.show()

# %%
# Valores de revocação para cada modelo
revocacao = [58.98, 37.81, 76.90, 59.16, 77.00, 70.33]

# Rótulos dos modelos
modelos = ['Naive Bayes', 'RNN', 'Random Forest', 'Regressão Logística', 'Embedding Layer', 'SVM']

# Paleta de cores suaves
cores = sns.color_palette('pastel')

# Criar o gráfico de barras
plt.figure(figsize=(12, 6))
plt.bar(modelos, revocacao, color=cores)

# Adicionar os valores de revocação acima das barras
for i in range(len(modelos)):
    plt.text(i, revocacao[i], f'{revocacao[i]:.2f}%', ha='center', va='bottom')

plt.xlabel('Modelos')
plt.ylabel('Revocação')
plt.title('Comparação de Revocação entre os Modelos')

# Ajustar os limites dos eixos
plt.ylim(0, 100)

# Mostrar o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Contagem dos sentimentos por tipo de interação
sentimento_count = base_tratada.groupby(['tipoInteracao', 'sentimento']).size().unstack()

# Criação do gráfico de barras empilhadas
sentimento_count.plot(kind='bar', stacked=True, figsize=(8, 6), color=['red', 'blue', 'green'])

# Configurações do gráfico
plt.xlabel('Tipo de Interação')
plt.ylabel('Quantidade')
plt.title('Distribuição de Sentimentos por Tipo de Interação')
plt.legend(title='Sentimento', loc='upper right')

# Rotação dos rótulos do eixo x
plt.xticks(rotation=0)

# Exibição do gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-48e1bb8c0c5c> in <cell line: 4>()
#       2
#       3 # Contagem dos sentimentos por tipo de interação
# ----> 4 sentimento_count = base_tratada.groupby(['tipoInteracao', 'sentimento']).size().unstack()
#       5
#       6 # Criação do gráfico de barras empilhadas
#
# NameError: name 'base_tratada' is not defined
